# %% [markdown]
# ### Importación de los módulos
# Se importan los módulos necesarios para el entrenamiento del modelo de control

# %%
import pandas as pd
import torch
import dgl
import torch
import torch.nn as nn
from torch.nn import TransformerEncoder, TransformerEncoderLayer
import torch.nn.functional as F
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import dgl.nn as dglnn
from sklearn.model_selection import train_test_split
import networkx as nx
import random
from statistics import mean
import csv
import time

# %% [markdown]
# ### Función de generación de grafo aleatorio
# Esta función genera un grafo completo ponderado con pesos aleatorios usado en lso ejemplos de la evaluación del coste medio de los caminos generados por el modelo

# %%
def generate_random_tsp_graph(n_cities, min_distance=1, max_distance=100):
    G = nx.Graph()
    for i in range(n_cities):
        G.add_node(i)

    for i in range(n_cities):
        for j in range(i+1, n_cities):
            distance = random.randint(min_distance, max_distance)
            G.add_edge(i, j, weight=distance)

    return G

def graph_to_adjacency_matrix(G):
    return nx.adjacency_matrix(G).todense().tolist()

# %% [markdown]
# Se definen las constantes como el número de clases de la predicción y la longitud de las secuencias.
# Se lee el dataset previamente generado en `dataset_generation_processing.ipynb`

# %%
SEQUENCE_LENGTH = 14
NUM_CLASSES_OUT = 15
BATCH_SIZE = 64

# %%
df = pd.read_csv('dataset_full_adj_matrix_15_nodes_stock.csv')

# %% [markdown]
# ### Función usada para obtener los índices no redundantes de una matriz de adyacencia de tamaño NxN
#
# La función lista los índices de los coeficientes situados bajo la diagonal principal de una matriz

# %%
def below_diagonal_indices(n):
    # List to store the indices of elements below the diagonal
    indices = []

    # Loop through each row
    for i in range(1, n):  # Start from 1 because the first row does not have any elements below the diagonal
        # Loop through each column up to (but not including) the diagonal
        for j in range(i):
            # Compute the index in the flattened matrix and add to the list
            index = i * n + j
            indices.append(index)

    return indices

# %% [markdown]
# ### Obtención de la matriz de adyacencia a partir del dataset
#
# Se leen los coeficientes y se convierten en un tensor que contiene 14000 ejemplos de matrices.

# %%
selected_columns = ['col_' + str(i) for i in range(1, NUM_CLASSES_OUT**2 + 1)]
selected_data = df[selected_columns]

numpy_array = selected_data.values
tensor = torch.tensor(numpy_array).view(df.shape[0], NUM_CLASSES_OUT, NUM_CLASSES_OUT)
adjacency_matrices = tensor
adjacency_matrices.shape
# Out:
# torch.Size([14000, 15, 15])

# %% [markdown]
# Se utiliza la función descrita con anterioridad para obtener los coeficientes bajo la diagonal principal de cada matriz de adyacencia del tesnor.
# Cada matriz de 15x15 genera 105 predictores correspondientes a los coeficientes no repetidos.

# %%
relevant_indices = below_diagonal_indices(NUM_CLASSES_OUT)
flat_matrices = torch.zeros((df.shape[0], (NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2))
for i in range(df.shape[0]):
    for index, j in enumerate(relevant_indices):
        flat_matrices[i][index] = df[f'col_{j+1}'][i]

# %% [markdown]
# ### Normalización de las matrices de adyacencia
#
# Se normalizan los coeficientes de las matrices entre -0.5 y 0.5

# %%
flat_matrices = flat_matrices / 101
flat_matrices
# Out:
# tensor([[0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         [0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         [0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         ...,
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307],
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307],
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307]])

# %%
graph_indices = flat_matrices
graph_indices = graph_indices - 0.5
graph_indices.shape
# Out:
# torch.Size([14000, 105])

# %% [markdown]
# ### Obtención de las secuencias de nodos
# Se obtienen los caminos parciales que componen la parte secuencial de los problemas de clasificación, se leen del dataframe y se convierten en enteros.
# Se forma un tensor de 14.000 ejemplos con las secuencias obtenidas.

# %%
sequence_tensor = torch.zeros((df.shape[0], NUM_CLASSES_OUT - 1))
for i in range(df.shape[0]):
    for j in range(SEQUENCE_LENGTH):
        sequence_tensor[i][j] = df[f'seq_{j+1}'][i]

sequence_tensor = sequence_tensor.long()
sequence_tensor
# Out:
# tensor([[ 0, -1, -1,  ..., -1, -1, -1],
#         [ 0, 12, -1,  ..., -1, -1, -1],
#         [ 0, 12,  4,  ..., -1, -1, -1],
#         ...,
#         [ 0,  2, 10,  ...,  7, -1, -1],
#         [ 0,  2, 10,  ...,  7, 14, -1],
#         [ 0,  2, 10,  ...,  7, 14,  8]])

# %% [markdown]
# ### Codificación de las secuencias
# Se utiliza una combinación de advanced indexing y tensores booleanos (masks) para codificar cada elemento (nodo) de la secuencia con su fila correspondiente en la matriz de adyacencia del ejemplo (grafo) en el que aparece.

# %%
batch_indices = torch.arange(len(sequence_tensor)).view(-1, 1).expand_as(sequence_tensor)
mask = (sequence_tensor == -1)

sequence_tensor = sequence_tensor.masked_fill(mask, 0)

sequence_encodings = adjacency_matrices[batch_indices, sequence_tensor]
sequence_encodings = sequence_encodings.masked_fill(mask.unsqueeze(-1), 0)

sequence_tensor = sequence_tensor.masked_fill(mask, -1)

# %%
sequence_encodings = sequence_encodings / 101
sequence_encodings[sequence_encodings != 0] -= 0.5

# %% [markdown]
# ### Extracción de los objetivos
# Se crea un tensor leyendo los objetivos almacenados en el dataset.

# %%
targets_tensor = torch.tensor(df['next_node'])
targets_tensor.shape
# Out:
# torch.Size([14000])

# %% [markdown]
# ### Definicion del modelo
# El modelo Transformer consiste en:
# 1. Una capa Linear que procesa los coeficientes de las matrices de adyacencia.
# 2. Una o varias capas TransformerEncoder de la clase TransformerEncoder de Pytorch que procesa las secuencias de nodos que componen los caminos parciales.
# 3. Una capa Linear que toma las salidas de las capas anteriores como entrada y devuelve la clasificación final.

# %%
class HybridModel(nn.Module):
    def __init__(self, hidden_size, num_layers, dropout, num_heads):
        super(HybridModel, self).__init__()

        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.num_heads = num_heads

        # Adjacency matrix processing layer
        self.matrix_proc = nn.Linear((NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2, NUM_CLASSES_OUT)
        
        # Transformer Encoder
        encoder_layers = TransformerEncoderLayer(d_model=NUM_CLASSES_OUT, nhead=num_heads, dim_feedforward=hidden_size, dropout=dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layer=encoder_layers, num_layers=num_layers)
        
        # Fully Connected Layer
        self.fc = nn.Linear(NUM_CLASSES_OUT * 2, NUM_CLASSES_OUT)

    def forward(self, flat_matrix, sequence_encoding):
        # Process adjacency matrix through Adjacency matrix processing layer
        matrix_out = self.matrix_proc(flat_matrix)

        # Process input through Transformer Encoder
        transformer_output = self.transformer_encoder(sequence_encoding)
        # Use the output of the last time step
        transformer_output = transformer_output[:, -1, :]

        # Concatenate outputs from matrix_proc and Transformer Encoder
        concat_output = torch.cat((matrix_out, transformer_output), dim=1)
        
        # Feed concatenated output through Fully Connected Layer
        out = self.fc(concat_output)
        return out

# %% [markdown]
# ### Dataset & Dataloader
# Se crea una clase hija de la clase Dataset de Pytorch para almacenar los datos.
# Esto permite mayor flexibilidad para situar la codificación de los datos en distintas partes del código y ha sido extremadamente útil durante el desarrollo de este trabajo.
# Actualmente la implementación del experimento podría hacerse con la clase Dataset directamente pero se deja implementada esta clase por si fuese útil para la continuación futura de la investigación.

# %%
from torch.utils.data import Dataset, DataLoader

# %%
class CustomGraphSequenceDataset(Dataset):
    def __init__(self, sequence_tensor, adj_matrices, targets_tensor):
        self.sequence_tensor = sequence_tensor
        self.adj_matrices = adj_matrices
        self.targets_tensor = targets_tensor

    def __len__(self):
        return len(self.sequence_tensor)

    def __getitem__(self, idx):
        sequence = self.sequence_tensor[idx]
        adj_matrix = self.adj_matrices[idx]
        target = self.targets_tensor[idx]
        # graph = adjacency_matrix_to_dgl(adj_matrix)
        return sequence, adj_matrix, target

# %% [markdown]
# De forma similar a la clase anterior, esta función collate personalizada es extremadamente útil a la hora de hacer pruebas con las diversas posibilidades para transformar los grupos de ejemplos en batches.
# Queda en el código por si viese más utilidad en la investigación futura, a pesar de que actualmente los scripts funcionarían con la función collate por defecto de pytorch.

# %%
def custom_collate_fn(batch):
    sequences, graphs, targets = zip(*batch)
    # Convert sequences to a single tensor
    sequences = torch.stack(sequences)
    # Convert targets to a single tensor
    targets = torch.stack(targets)
    # Batch graphs into a single graph
    batched_graph = torch.stack(graphs) # dgl.batch(graphs)
    return sequences, batched_graph, targets

# %% [markdown]
# ### Train Test split
# Se dividen las codificaciones de las secuencias, las matrices de adyacencia y los objetivos entre conjuntos de entrenamiento y validación.
# Se crean los datasets de entrenamiento y test a partir de los tensores resultantes.

# %%
# Split the data into training and testing sets (80% train, 20% test)
train_sequences, test_sequences, train_adj_matrices, test_adj_matrices, train_targets, test_targets = train_test_split(
    sequence_encodings, graph_indices, targets_tensor, test_size=0.2, random_state=42)

# %%
# Create Custom Dataset for train and test
train_dataset = CustomGraphSequenceDataset(train_sequences, train_adj_matrices, train_targets)
test_dataset = CustomGraphSequenceDataset(test_sequences, test_adj_matrices, test_targets)

# %%
# DataLoader for train and test
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=custom_collate_fn, drop_last=True)

# %% [markdown]
# ### Evaluación del coste medio de los caminos
# Esta función recibe un modelo como parámetro y se ejecuta durante la fase de evaluación para calcular el coste medio del camino generado por este modelo.
#
# Esta función genera un batch de grafos completos ponderados con pesos aleatorios.
# Una vez generados, se obtienen las matrices de adyacencia correspondientes a los grafos y se procesan sus coeficientes tal como se hace en el apartado anterior (Obtención de la matriz de adyacencia a partir del dataset)..
#
# Se generan tensores correspondientes a secuencias de nodos vacías (todas tienen 0 como nodo inicial como en los ejemplos del dataset).
# Se codifican dichas secuencias y se generan los elementos siguientes a partir de predicciones del modelo.

# %%
def path_evaluation(model, batch_size):
    matrices_tensor_batch = torch.zeros((batch_size, (NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2))
    adjacency_matrices = np.ndarray((batch_size, NUM_CLASSES_OUT, NUM_CLASSES_OUT))

    # Generate one batch of adjacency matrices 
    for tensor_row in range(batch_size):
        graph = generate_random_tsp_graph(NUM_CLASSES_OUT)
        adjacency_matrix = graph_to_adjacency_matrix(graph)
        adjacency_matrices[tensor_row] = torch.tensor(adjacency_matrix).view((NUM_CLASSES_OUT, NUM_CLASSES_OUT))
        
        partial_matrix = list()
        for relevant_index in relevant_indices:
            flattened_adj_matrix = [item for sublist in adjacency_matrix for item in sublist]
            partial_matrix.append(flattened_adj_matrix[relevant_index])
        
        matrices_tensor_batch[tensor_row] = torch.tensor(partial_matrix)

    # Normalize
    matrices_tensor_batch = matrices_tensor_batch / 101

    # Generate an empty sequence from a random starting point
    sequences_tensor_batch = torch.zeros((batch_size, NUM_CLASSES_OUT - 1)).long()
    sequences_tensor_batch[:, 0] = torch.tensor(np.random.randint(0, 15, size=(batch_size)))

    # Store the decision cost in each step of the way
    costs = torch.zeros((NUM_CLASSES_OUT - 2, batch_size))
    for i in range(NUM_CLASSES_OUT - 2):
        # Encode the sequence for the model
        batch_indices = torch.arange(len(sequences_tensor_batch)).view(-1, 1).expand_as(sequences_tensor_batch)
        mask = (sequences_tensor_batch == -1)

        sequences_tensor_batch = sequences_tensor_batch.masked_fill(mask, 0)

        sequence_encodings = torch.tensor(adjacency_matrices[batch_indices, sequences_tensor_batch])
        sequence_encodings = sequence_encodings.masked_fill(mask.unsqueeze(-1), 0)

        sequences_tensor_batch = sequences_tensor_batch.masked_fill(mask, -1)

        sequence_encodings = sequence_encodings / 101
        sequence_encodings[sequence_encodings != 0] -= 0.5
        
        sequence_encodings = sequence_encodings.to(torch.float32)

        outputs = model(matrices_tensor_batch, sequence_encodings)
        _, predicted_labels = torch.max(outputs, 1)
        previous_labels = sequences_tensor_batch[:, i]
        costs_this_timestep = list()
        for batch_index in range(batch_size):
            matrix = adjacency_matrices[batch_index]
            # print(len(matrix))
            # print(predicted_labels[batch_index])
            # print(previous_labels[batch_index])
            costs_this_timestep.append(matrix[predicted_labels[batch_index]][previous_labels[batch_index]])

        costs_this_timestep = torch.tensor(costs_this_timestep)
        costs[i] = costs_this_timestep

    # Calculate total cost of each path
    costs = torch.sum(costs, dim=0)

    # Return the mean value from al lthe path costs
    return torch.mean(costs).item()

# %% [markdown]
# ### Instanciamiento y loop
# La siguiente funcion instancia un modelo con los hiperparámetros pasados como argumentos, y lo entrena durante 100 épocas.
# Para ello utiliza el algoritmo de optimización Adam y la función de pérdida CrossEntropyLoss.
# Se crea un archivo de registro con los resultados del modelo en el directorio results, que contiene en el nombre los hiperparámetros usados.
# Durante la fase de evaluación, además de comprobar la precisión del modelo sobre el conjunto de test, se evalúa el coste medio en los caminos generados por este sobre un batch de ejemplos generados aleatoriamente.

# %%
def train_model(train_loader, test_loader, hyperparams, identifier, batch_size):
    num_layers = hyperparams['num_layers']
    hidden_size = hyperparams['hidden_size']
    learning_rate = hyperparams['learning_rate']
    num_heads = hyperparams['num_heads']

    # Initialize new model, optimizer and loss function
    model = HybridModel(num_layers=num_layers, hidden_size=hidden_size, dropout=0, num_heads=num_heads)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)#, weight_decay=1e-5)

    # Number of epochs
    num_epochs = 100
    total_path_costs_mean = list()


    csv_file = open(f"./results/transformer/{batch_size}/{identifier}.csv", mode="a", newline="")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Epoch", "Train_Accuracy", "Test_Accuracy", "Mean_Path_Cost", "Elapsed_Time"])

    # Training loop
    start_time = time.time()
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        total_samples = 0
        correct_predictions = 0

        batch_num = len(train_loader)
        for batch_idx, (sequences, batched_graph, targets) in enumerate(train_loader):
            
            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(batched_graph, sequences)
            
            # Compute the loss
            loss = criterion(outputs, targets)
            
            loss.backward()

            optimizer.step()

            # Update the training accuracy
            _, predicted_labels = torch.max(outputs, 1)
            total_samples += targets.size(0)
            correct_predictions += (predicted_labels == targets).sum().item()
        
        # Compute the training accuracy for the epoch
        accuracy = correct_predictions / total_samples

        # Evaluation phase
        model.eval()
        total_samples = 0
        correct_predictions = 0
        mean_this_epoch = 0

        with torch.no_grad():
            for sequences, batched_graph, targets in test_loader:
                # Forward pass
                outputs = model(batched_graph, sequences)

                # Update the testing accuracy
                _, predicted_labels = torch.max(outputs, 1)
                total_samples += targets.size(0)
                correct_predictions += (predicted_labels == targets).sum().item()

            # Path evaluation
            mean_this_epoch = path_evaluation(model, batch_size)
            total_path_costs_mean.append(mean_this_epoch)

        # Compute the testing accuracy for the epoch
        test_accuracy = correct_predictions / total_samples

        elapsed_time = time.time() - start_time
        csv_writer.writerow([
            epoch + 1,
            round(accuracy * 100, 4),
            round(test_accuracy * 100, 4),
            round(mean_this_epoch, 4),
            round(elapsed_time, 4)
        ])
        csv_file.flush()
        
        print(f'Epoch [{epoch + 1}/{num_epochs}]')
        print(f'Train Accuracy: {accuracy * 100:.2f}%, Testing Accuracy: {test_accuracy * 100:.2f}%')
        print(f'Path cost mean this epoch: {mean_this_epoch:.2f}, Total path cost mean : {mean(total_path_costs_mean):.2f}\n')

# %% [markdown]
# ### Grid de hiperparámetros
# En esta última función se especifican los distintos valores que tendrán los hiperparámetros del grid, y se entrena al modelo previamente definido utilizando todas las combinaciones posibles de hiperparámetros para ello.

# %%
from itertools import product

batch_sizes =  (16, 32, 64)

hyperparameter_grid = {
    'learning_rate': [0.0001, 0.0005, 0.001],
    'hidden_size': [16, 32, 64],
    'num_layers': [1, 2, 3],
    'num_heads': [1, 3, 5]
}

for batch_size in batch_sizes:
    print('current batch size is ' + str(batch_size))

    all_combs = product(*(hyperparameter_grid[hp] for hp in hyperparameter_grid))
    for comb in all_combs:
        hyperparams = dict(zip(hyperparameter_grid.keys(), comb))

        identifier = '_'.join([f"{k}={v}" for k, v in hyperparams.items()])
        
        print(f"Training with {identifier}")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate_fn, drop_last=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn, drop_last=True)
        
        train_model(train_loader, test_loader, hyperparams, identifier, batch_size)
# Out:
# current batch size is 16
# Training with learning_rate=0.0001_hidden_size=16_num_layers=1_num_heads=1
# /tmp/ipykernel_1064/1631721209.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(G).todense().tolist()
# Epoch [1/50]
# Train Accuracy: 7.02%, Testing Accuracy: 7.46%
# Path cost mean this epoch: 637.62, Total path cost mean : 637.62
#
# Epoch [2/50]
# Train Accuracy: 7.07%, Testing Accuracy: 7.07%
# Path cost mean this epoch: 437.12, Total path cost mean : 537.38
#
# Epoch [3/50]
# Train Accuracy: 7.46%, Testing Accuracy: 7.64%
# Path cost mean this epoch: 662.69, Total path cost mean : 579.15
#
# Epoch [4/50]
# Train Accuracy: 7.32%, Testing Accuracy: 7.64%
# Path cost mean this epoch: 769.69, Total path cost mean : 626.78
#
# Epoch [5/50]
# Train Accuracy: 8.02%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 456.56, Total path cost mean : 592.74
#
# Epoch [6/50]
# Train Accuracy: 8.06%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 595.50, Total path cost mean : 593.20
#
# Epoch [7/50]
# Train Accuracy: 8.05%, Testing Accuracy: 7.75%
# Path cost mean this epoch: 573.19, Total path cost mean : 590.34
#
# Epoch [8/50]
# Train Accuracy: 8.29%, Testing Accuracy: 7.43%
# Path cost mean this epoch: 547.69, Total path cost mean : 585.01
#
# Epoch [9/50]
# Train Accuracy: 8.41%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 417.38, Total path cost mean : 566.38
#
# Epoch [10/50]
# Train Accuracy: 8.39%, Testing Accuracy: 7.43%
# Path cost mean this epoch: 655.06, Total path cost mean : 575.25
#
# Epoch [11/50]
# Train Accuracy: 8.69%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 394.19, Total path cost mean : 558.79
#
# Epoch [12/50]
# Train Accuracy: 8.88%, Testing Accuracy: 7.18%
# Path cost mean this epoch: 653.88, Total path cost mean : 566.71
#
# Epoch [13/50]
# Train Accuracy: 9.11%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 499.12, Total path cost mean : 561.51
#
# Epoch [14/50]
# Train Accuracy: 8.98%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 394.62, Total path cost mean : 549.59
#
# Epoch [15/50]
# Train Accuracy: 8.85%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 461.19, Total path cost mean : 543.70
#
# Epoch [16/50]
# Train Accuracy: 8.97%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 413.69, Total path cost mean : 535.57
#
# Epoch [17/50]
# Train Accuracy: 9.51%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 449.88, Total path cost mean : 530.53
#
# Epoch [18/50]
# Train Accuracy: 9.21%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 390.00, Total path cost mean : 522.73
#
# Epoch [19/50]
# Train Accuracy: 9.23%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 423.00, Total path cost mean : 517.48
#
# Epoch [20/50]
# Train Accuracy: 9.21%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 453.00, Total path cost mean : 514.25
#
# Epoch [21/50]
# Train Accuracy: 9.38%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 436.88, Total path cost mean : 510.57
#
# Epoch [22/50]
# Train Accuracy: 9.54%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 463.50, Total path cost mean : 508.43
#
# Epoch [23/50]
# Train Accuracy: 9.10%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 417.56, Total path cost mean : 504.48
#
# Epoch [24/50]
# Train Accuracy: 9.38%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 411.56, Total path cost mean : 500.61
#
# Epoch [25/50]
# Train Accuracy: 9.58%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 369.88, Total path cost mean : 495.38
#
# Epoch [26/50]
# Train Accuracy: 9.53%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 488.75, Total path cost mean : 495.12
#
# Epoch [27/50]
# Train Accuracy: 9.53%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 382.56, Total path cost mean : 490.95
#
# Epoch [28/50]
# Train Accuracy: 9.68%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 382.62, Total path cost mean : 487.08
#
# Epoch [29/50]
# Train Accuracy: 9.68%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 401.88, Total path cost mean : 484.15
#
# Epoch [30/50]
# Train Accuracy: 9.88%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 442.81, Total path cost mean : 482.77
#
# Epoch [31/50]
# Train Accuracy: 9.76%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 409.25, Total path cost mean : 480.40
#
# Epoch [32/50]
# Train Accuracy: 9.88%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 327.19, Total path cost mean : 475.61
#
# Epoch [33/50]
# Train Accuracy: 9.77%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 441.19, Total path cost mean : 474.57
#
# Epoch [34/50]
# Train Accuracy: 10.36%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 427.44, Total path cost mean : 473.18
#
# Epoch [35/50]
# Train Accuracy: 10.17%, Testing Accuracy: 6.82%
# Path cost mean this epoch: 335.12, Total path cost mean : 469.24
#
# Epoch [36/50]
# Train Accuracy: 10.20%, Testing Accuracy: 6.04%
# Path cost mean this epoch: 362.19, Total path cost mean : 466.26
#
# Epoch [37/50]
# Train Accuracy: 9.90%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 389.81, Total path cost mean : 464.20
#
# Epoch [38/50]
# Train Accuracy: 9.91%, Testing Accuracy: 5.79%
# Path cost mean this epoch: 354.25, Total path cost mean : 461.30
#
# Epoch [39/50]
# Train Accuracy: 9.88%, Testing Accuracy: 6.11%
# Path cost mean this epoch: 380.62, Total path cost mean : 459.23
#
# Epoch [40/50]
# Train Accuracy: 10.00%, Testing Accuracy: 5.86%
# Path cost mean this epoch: 452.69, Total path cost mean : 459.07
#
# Epoch [41/50]
# Train Accuracy: 10.18%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 357.12, Total path cost mean : 456.58
#
# Epoch [42/50]
# Train Accuracy: 10.28%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 397.38, Total path cost mean : 455.17
#
# Epoch [43/50]
# Train Accuracy: 10.20%, Testing Accuracy: 5.79%
# Path cost mean this epoch: 298.75, Total path cost mean : 451.54
#
# Epoch [44/50]
# Train Accuracy: 10.57%, Testing Accuracy: 5.75%
# Path cost mean this epoch: 371.12, Total path cost mean : 449.71
#
# Epoch [45/50]
# Train Accuracy: 10.15%, Testing Accuracy: 5.57%
# Path cost mean this epoch: 362.75, Total path cost mean : 447.78
#
# Epoch [46/50]
# Train Accuracy: 10.16%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 245.69, Total path cost mean : 443.38
#
# Epoch [47/50]
# Train Accuracy: 10.16%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 230.62, Total path cost mean : 438.86
#
# Epoch [48/50]
# Train Accuracy: 10.43%, Testing Accuracy: 5.57%
# Path cost mean this epoch: 377.44, Total path cost mean : 437.58
#
# Epoch [49/50]
# Train Accuracy: 10.14%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 362.81, Total path cost mean : 436.05
#
# Epoch [50/50]
# Train Accuracy: 10.46%, Testing Accuracy: 5.18%
# Path cost mean this epoch: 333.00, Total path cost mean : 433.99
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=1_num_heads=3
# Epoch [1/50]
# Train Accuracy: 6.84%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 592.75, Total path cost mean : 592.75
#
# Epoch [2/50]
# Train Accuracy: 7.47%, Testing Accuracy: 6.86%
# Path cost mean this epoch: 638.69, Total path cost mean : 615.72
#
# Epoch [3/50]
# Train Accuracy: 7.26%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 594.31, Total path cost mean : 608.58
#
# Epoch [4/50]
# Train Accuracy: 7.02%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 535.12, Total path cost mean : 590.22
#
# Epoch [5/50]
# Train Accuracy: 7.38%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 679.12, Total path cost mean : 608.00
#
# Epoch [6/50]
# Train Accuracy: 7.59%, Testing Accuracy: 7.07%
# Path cost mean this epoch: 626.06, Total path cost mean : 611.01
#
# Epoch [7/50]
# Train Accuracy: 7.77%, Testing Accuracy: 7.21%
# Path cost mean this epoch: 561.62, Total path cost mean : 603.96
#
# Epoch [8/50]
# Train Accuracy: 8.03%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 438.06, Total path cost mean : 583.22
#
# Epoch [9/50]
# Train Accuracy: 8.04%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 378.12, Total path cost mean : 560.43
#
# Epoch [10/50]
# Train Accuracy: 8.28%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 555.19, Total path cost mean : 559.91
#
# Epoch [11/50]
# Train Accuracy: 8.31%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 445.00, Total path cost mean : 549.46
#
# Epoch [12/50]
# Train Accuracy: 8.47%, Testing Accuracy: 6.86%
# Path cost mean this epoch: 515.06, Total path cost mean : 546.59
#
# Epoch [13/50]
# Train Accuracy: 8.75%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 407.81, Total path cost mean : 535.92
#
# Epoch [14/50]
# Train Accuracy: 9.08%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 401.50, Total path cost mean : 526.32
#
# Epoch [15/50]
# Train Accuracy: 9.50%, Testing Accuracy: 7.39%
# Path cost mean this epoch: 312.31, Total path cost mean : 512.05
#
# Epoch [16/50]
# Train Accuracy: 9.29%, Testing Accuracy: 6.82%
# Path cost mean this epoch: 402.06, Total path cost mean : 505.18
#
# Epoch [17/50]
# Train Accuracy: 9.43%, Testing Accuracy: 7.36%
# Path cost mean this epoch: 367.62, Total path cost mean : 497.08
#
# Epoch [18/50]
# Train Accuracy: 9.85%, Testing Accuracy: 7.14%
# Path cost mean this epoch: 335.25, Total path cost mean : 488.09
#
# Epoch [19/50]
# Train Accuracy: 9.46%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 358.12, Total path cost mean : 481.25
#
# Epoch [20/50]
# Train Accuracy: 9.94%, Testing Accuracy: 7.54%
# Path cost mean this epoch: 419.81, Total path cost mean : 478.18
#
# Epoch [21/50]
# Train Accuracy: 10.12%, Testing Accuracy: 7.07%
# Path cost mean this epoch: 402.06, Total path cost mean : 474.56
#
# Epoch [22/50]
# Train Accuracy: 9.87%, Testing Accuracy: 6.54%
# Path cost mean this epoch: 399.75, Total path cost mean : 471.16
#
# Epoch [23/50]
# Train Accuracy: 10.01%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 284.56, Total path cost mean : 463.04
#
# Epoch [24/50]
# Train Accuracy: 9.63%, Testing Accuracy: 6.54%
# Path cost mean this epoch: 271.88, Total path cost mean : 455.08
#
# Epoch [25/50]
# Train Accuracy: 9.86%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 310.81, Total path cost mean : 449.31
#
# Epoch [26/50]
# Train Accuracy: 9.64%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 253.12, Total path cost mean : 441.76
#
# Epoch [27/50]
# Train Accuracy: 9.66%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 226.88, Total path cost mean : 433.80
#
# Epoch [28/50]
# Train Accuracy: 10.37%, Testing Accuracy: 7.32%
# Path cost mean this epoch: 283.19, Total path cost mean : 428.42
#
# Epoch [29/50]
# Train Accuracy: 10.09%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 328.38, Total path cost mean : 424.97
#
# Epoch [30/50]
# Train Accuracy: 10.04%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 312.25, Total path cost mean : 421.22
#
# Epoch [31/50]
# Train Accuracy: 10.04%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 264.25, Total path cost mean : 416.15
#
# Epoch [32/50]
# Train Accuracy: 10.28%, Testing Accuracy: 6.18%
# Path cost mean this epoch: 229.06, Total path cost mean : 410.31
#
# Epoch [33/50]
# Train Accuracy: 10.08%, Testing Accuracy: 6.18%
# Path cost mean this epoch: 252.75, Total path cost mean : 405.53
#
# Epoch [34/50]
# Train Accuracy: 10.12%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 271.44, Total path cost mean : 401.59
#
# Epoch [35/50]
# Train Accuracy: 9.98%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 353.56, Total path cost mean : 400.22
#
# Epoch [36/50]
# Train Accuracy: 10.23%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 250.94, Total path cost mean : 396.07
#
# Epoch [37/50]
# Train Accuracy: 10.29%, Testing Accuracy: 5.75%
# Path cost mean this epoch: 335.69, Total path cost mean : 394.44
#
# Epoch [38/50]
# Train Accuracy: 10.63%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 287.12, Total path cost mean : 391.61
#
# Epoch [39/50]
# Train Accuracy: 10.13%, Testing Accuracy: 5.96%
# Path cost mean this epoch: 337.69, Total path cost mean : 390.23
#
# Epoch [40/50]
# Train Accuracy: 10.21%, Testing Accuracy: 5.46%
# Path cost mean this epoch: 277.38, Total path cost mean : 387.41
#
# Epoch [41/50]
# Train Accuracy: 10.62%, Testing Accuracy: 5.86%
# Path cost mean this epoch: 318.88, Total path cost mean : 385.74
#
# Epoch [42/50]
# Train Accuracy: 10.38%, Testing Accuracy: 6.00%
# Path cost mean this epoch: 309.06, Total path cost mean : 383.91
#
# Epoch [43/50]
# Train Accuracy: 11.03%, Testing Accuracy: 5.79%
# Path cost mean this epoch: 270.69, Total path cost mean : 381.28
#
# Epoch [44/50]
# Train Accuracy: 10.48%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 210.88, Total path cost mean : 377.41
#
# Epoch [45/50]
# Train Accuracy: 10.49%, Testing Accuracy: 5.61%
# Path cost mean this epoch: 279.00, Total path cost mean : 375.22
#
# Epoch [46/50]
# Train Accuracy: 10.41%, Testing Accuracy: 5.68%
# Path cost mean this epoch: 217.94, Total path cost mean : 371.80
#
# Epoch [47/50]
# Train Accuracy: 10.33%, Testing Accuracy: 5.79%
# Path cost mean this epoch: 339.62, Total path cost mean : 371.12
#
# Epoch [48/50]
# Train Accuracy: 10.55%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 271.62, Total path cost mean : 369.04
#
# Epoch [49/50]
# Train Accuracy: 10.43%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 297.94, Total path cost mean : 367.59
#
# Epoch [50/50]
# Train Accuracy: 10.53%, Testing Accuracy: 5.68%
# Path cost mean this epoch: 265.12, Total path cost mean : 365.54
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=1_num_heads=5
# Epoch [1/50]
# Train Accuracy: 7.46%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 790.62, Total path cost mean : 790.62
#
# Epoch [2/50]
# Train Accuracy: 7.33%, Testing Accuracy: 6.82%
# Path cost mean this epoch: 644.25, Total path cost mean : 717.44
#
# Epoch [3/50]
# Train Accuracy: 7.55%, Testing Accuracy: 6.82%
# Path cost mean this epoch: 613.50, Total path cost mean : 682.79
#
# Epoch [4/50]
# Train Accuracy: 7.25%, Testing Accuracy: 7.21%
# Path cost mean this epoch: 499.88, Total path cost mean : 637.06
#
# Epoch [5/50]
# Train Accuracy: 7.87%, Testing Accuracy: 7.25%
# Path cost mean this epoch: 564.25, Total path cost mean : 622.50
#
# Epoch [6/50]
# Train Accuracy: 7.83%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 560.12, Total path cost mean : 612.10
#
# Epoch [7/50]
# Train Accuracy: 8.04%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 299.38, Total path cost mean : 567.43
#
# Epoch [8/50]
# Train Accuracy: 8.17%, Testing Accuracy: 7.25%
# Path cost mean this epoch: 505.19, Total path cost mean : 559.65
#
# Epoch [9/50]
# Train Accuracy: 8.38%, Testing Accuracy: 6.54%
# Path cost mean this epoch: 671.12, Total path cost mean : 572.03
#
# Epoch [10/50]
# Train Accuracy: 8.54%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 351.44, Total path cost mean : 549.98
#
# Epoch [11/50]
# Train Accuracy: 8.50%, Testing Accuracy: 7.21%
# Path cost mean this epoch: 502.25, Total path cost mean : 545.64
#
# Epoch [12/50]
# Train Accuracy: 9.38%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 378.56, Total path cost mean : 531.71
#
# Epoch [13/50]
# Train Accuracy: 9.12%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 438.12, Total path cost mean : 524.51
#
# Epoch [14/50]
# Train Accuracy: 9.24%, Testing Accuracy: 7.64%
# Path cost mean this epoch: 430.50, Total path cost mean : 517.80
#
# Epoch [15/50]
# Train Accuracy: 9.61%, Testing Accuracy: 7.36%
# Path cost mean this epoch: 359.94, Total path cost mean : 507.27
#
# Epoch [16/50]
# Train Accuracy: 9.42%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 376.69, Total path cost mean : 499.11
#
# Epoch [17/50]
# Train Accuracy: 9.44%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 426.88, Total path cost mean : 494.86
#
# Epoch [18/50]
# Train Accuracy: 9.66%, Testing Accuracy: 6.86%
# Path cost mean this epoch: 309.00, Total path cost mean : 484.54
#
# Epoch [19/50]
# Train Accuracy: 9.62%, Testing Accuracy: 7.25%
# Path cost mean this epoch: 404.12, Total path cost mean : 480.31
#
# Epoch [20/50]
# Train Accuracy: 9.48%, Testing Accuracy: 7.36%
# Path cost mean this epoch: 290.06, Total path cost mean : 470.79
#
# Epoch [21/50]
# Train Accuracy: 9.51%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 320.62, Total path cost mean : 463.64
#
# Epoch [22/50]
# Train Accuracy: 9.77%, Testing Accuracy: 7.18%
# Path cost mean this epoch: 367.50, Total path cost mean : 459.27
#
# Epoch [23/50]
# Train Accuracy: 9.82%, Testing Accuracy: 7.04%
# Path cost mean this epoch: 430.50, Total path cost mean : 458.02
#
# Epoch [24/50]
# Train Accuracy: 9.83%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 308.00, Total path cost mean : 451.77
#
# Epoch [25/50]
# Train Accuracy: 9.98%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 278.88, Total path cost mean : 444.86
#
# Epoch [26/50]
# Train Accuracy: 9.84%, Testing Accuracy: 6.04%
# Path cost mean this epoch: 182.94, Total path cost mean : 434.78
#
# Epoch [27/50]
# Train Accuracy: 9.94%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 241.75, Total path cost mean : 427.63
#
# Epoch [28/50]
# Train Accuracy: 9.95%, Testing Accuracy: 6.82%
# Path cost mean this epoch: 318.50, Total path cost mean : 423.73
#
# Epoch [29/50]
# Train Accuracy: 10.00%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 248.06, Total path cost mean : 417.68
#
# Epoch [30/50]
# Train Accuracy: 10.02%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 308.69, Total path cost mean : 414.04
#
# Epoch [31/50]
# Train Accuracy: 10.01%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 302.56, Total path cost mean : 410.45
#
# Epoch [32/50]
# Train Accuracy: 9.82%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 307.31, Total path cost mean : 407.22
#
# Epoch [33/50]
# Train Accuracy: 10.53%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 266.56, Total path cost mean : 402.96
#
# Epoch [34/50]
# Train Accuracy: 10.21%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 193.69, Total path cost mean : 396.81
#
# Epoch [35/50]
# Train Accuracy: 10.27%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 325.75, Total path cost mean : 394.78
#
# Epoch [36/50]
# Train Accuracy: 10.29%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 322.00, Total path cost mean : 392.76
#
# Epoch [37/50]
# Train Accuracy: 10.38%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 300.06, Total path cost mean : 390.25
#
# Epoch [38/50]
# Train Accuracy: 10.40%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 260.88, Total path cost mean : 386.85
#
# Epoch [39/50]
# Train Accuracy: 10.23%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 260.56, Total path cost mean : 383.61
#
# Epoch [40/50]
# Train Accuracy: 10.23%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 255.75, Total path cost mean : 380.41
#
# Epoch [41/50]
# Train Accuracy: 10.56%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 263.31, Total path cost mean : 377.55
#
# Epoch [42/50]
# Train Accuracy: 10.40%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 222.38, Total path cost mean : 373.86
#
# Epoch [43/50]
# Train Accuracy: 10.43%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 289.06, Total path cost mean : 371.89
#
# Epoch [44/50]
# Train Accuracy: 10.60%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 257.88, Total path cost mean : 369.30
#
# Epoch [45/50]
# Train Accuracy: 10.46%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 257.88, Total path cost mean : 366.82
#
# Epoch [46/50]
# Train Accuracy: 10.29%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 317.56, Total path cost mean : 365.75
#
# Epoch [47/50]
# Train Accuracy: 10.76%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 260.31, Total path cost mean : 363.51
#
# Epoch [48/50]
# Train Accuracy: 10.41%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 244.19, Total path cost mean : 361.02
#
# Epoch [49/50]
# Train Accuracy: 10.76%, Testing Accuracy: 5.75%
# Path cost mean this epoch: 241.19, Total path cost mean : 358.58
#
# Epoch [50/50]
# Train Accuracy: 10.35%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 259.31, Total path cost mean : 356.59
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=2_num_heads=1
# Epoch [1/50]
# Train Accuracy: 7.07%, Testing Accuracy: 7.79%
# Path cost mean this epoch: 671.62, Total path cost mean : 671.62
#
# Epoch [2/50]
# Train Accuracy: 7.40%, Testing Accuracy: 7.25%
# Path cost mean this epoch: 799.69, Total path cost mean : 735.66
#
# Epoch [3/50]
# Train Accuracy: 7.06%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 529.88, Total path cost mean : 667.06
#
# Epoch [4/50]
# Train Accuracy: 7.52%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 536.31, Total path cost mean : 634.38
#
# Epoch [5/50]
# Train Accuracy: 8.21%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 608.19, Total path cost mean : 629.14
#
# Epoch [6/50]
# Train Accuracy: 8.21%, Testing Accuracy: 6.00%
# Path cost mean this epoch: 516.94, Total path cost mean : 610.44
#
# Epoch [7/50]
# Train Accuracy: 8.38%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 516.75, Total path cost mean : 597.05
#
# Epoch [8/50]
# Train Accuracy: 8.36%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 423.19, Total path cost mean : 575.32
#
# Epoch [9/50]
# Train Accuracy: 8.47%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 459.25, Total path cost mean : 562.42
#
# Epoch [10/50]
# Train Accuracy: 8.62%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 494.81, Total path cost mean : 555.66
#
# Epoch [11/50]
# Train Accuracy: 9.03%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 512.44, Total path cost mean : 551.73
#
# Epoch [12/50]
# Train Accuracy: 8.84%, Testing Accuracy: 7.14%
# Path cost mean this epoch: 413.88, Total path cost mean : 540.24
#
# Epoch [13/50]
# Train Accuracy: 9.15%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 501.62, Total path cost mean : 537.27
#
# Epoch [14/50]
# Train Accuracy: 8.82%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 283.44, Total path cost mean : 519.14
#
# Epoch [15/50]
# Train Accuracy: 9.67%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 420.38, Total path cost mean : 512.56
#
# Epoch [16/50]
# Train Accuracy: 9.31%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 424.88, Total path cost mean : 507.08
#
# Epoch [17/50]
# Train Accuracy: 9.47%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 299.25, Total path cost mean : 494.85
#
# Epoch [18/50]
# Train Accuracy: 9.67%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 367.50, Total path cost mean : 487.78
#
# Epoch [19/50]
# Train Accuracy: 9.63%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 321.69, Total path cost mean : 479.04
#
# Epoch [20/50]
# Train Accuracy: 9.88%, Testing Accuracy: 6.29%
# Path cost mean this epoch: 408.69, Total path cost mean : 475.52
#
# Epoch [21/50]
# Train Accuracy: 10.08%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 265.38, Total path cost mean : 465.51
#
# Epoch [22/50]
# Train Accuracy: 10.12%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 300.31, Total path cost mean : 458.00
#
# Epoch [23/50]
# Train Accuracy: 10.02%, Testing Accuracy: 6.29%
# Path cost mean this epoch: 216.19, Total path cost mean : 447.49
#
# Epoch [24/50]
# Train Accuracy: 10.13%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 288.56, Total path cost mean : 440.87
#
# Epoch [25/50]
# Train Accuracy: 9.90%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 306.94, Total path cost mean : 435.51
#
# Epoch [26/50]
# Train Accuracy: 10.55%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 412.19, Total path cost mean : 434.61
#
# Epoch [27/50]
# Train Accuracy: 10.03%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 248.00, Total path cost mean : 427.70
#
# Epoch [28/50]
# Train Accuracy: 10.46%, Testing Accuracy: 6.00%
# Path cost mean this epoch: 329.00, Total path cost mean : 424.18
#
# Epoch [29/50]
# Train Accuracy: 10.14%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 302.62, Total path cost mean : 419.98
#
# Epoch [30/50]
# Train Accuracy: 10.23%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 227.50, Total path cost mean : 413.57
#
# Epoch [31/50]
# Train Accuracy: 10.08%, Testing Accuracy: 5.64%
# Path cost mean this epoch: 281.50, Total path cost mean : 409.31
#
# Epoch [32/50]
# Train Accuracy: 10.42%, Testing Accuracy: 5.36%
# Path cost mean this epoch: 253.75, Total path cost mean : 404.45
#
# Epoch [33/50]
# Train Accuracy: 10.54%, Testing Accuracy: 5.75%
# Path cost mean this epoch: 347.12, Total path cost mean : 402.71
#
# Epoch [34/50]
# Train Accuracy: 10.04%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 290.50, Total path cost mean : 399.41
#
# Epoch [35/50]
# Train Accuracy: 10.21%, Testing Accuracy: 5.54%
# Path cost mean this epoch: 282.88, Total path cost mean : 396.08
#
# Epoch [36/50]
# Train Accuracy: 10.43%, Testing Accuracy: 6.29%
# Path cost mean this epoch: 353.38, Total path cost mean : 394.89
#
# Epoch [37/50]
# Train Accuracy: 10.55%, Testing Accuracy: 5.39%
# Path cost mean this epoch: 264.00, Total path cost mean : 391.36
#
# Epoch [38/50]
# Train Accuracy: 10.69%, Testing Accuracy: 5.86%
# Path cost mean this epoch: 332.62, Total path cost mean : 389.81
#
# Epoch [39/50]
# Train Accuracy: 10.39%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 249.44, Total path cost mean : 386.21
#
# Epoch [40/50]
# Train Accuracy: 10.57%, Testing Accuracy: 5.61%
# Path cost mean this epoch: 307.62, Total path cost mean : 384.25
#
# Epoch [41/50]
# Train Accuracy: 10.52%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 256.75, Total path cost mean : 381.14
#
# Epoch [42/50]
# Train Accuracy: 10.83%, Testing Accuracy: 5.71%
# Path cost mean this epoch: 360.25, Total path cost mean : 380.64
#
# Epoch [43/50]
# Train Accuracy: 10.45%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 276.31, Total path cost mean : 378.21
#
# Epoch [44/50]
# Train Accuracy: 10.79%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 299.00, Total path cost mean : 376.41
#
# Epoch [45/50]
# Train Accuracy: 11.07%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 216.38, Total path cost mean : 372.86
#
# Epoch [46/50]
# Train Accuracy: 10.71%, Testing Accuracy: 5.61%
# Path cost mean this epoch: 255.62, Total path cost mean : 370.31
#
# Epoch [47/50]
# Train Accuracy: 10.95%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 255.94, Total path cost mean : 367.88
#
# Epoch [48/50]
# Train Accuracy: 10.55%, Testing Accuracy: 5.79%
# Path cost mean this epoch: 272.69, Total path cost mean : 365.89
#
# Epoch [49/50]
# Train Accuracy: 10.85%, Testing Accuracy: 5.82%
# Path cost mean this epoch: 286.19, Total path cost mean : 364.27
#
# Epoch [50/50]
# Train Accuracy: 10.58%, Testing Accuracy: 5.54%
# Path cost mean this epoch: 282.50, Total path cost mean : 362.63
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=2_num_heads=3
# Epoch [1/50]
# Train Accuracy: 6.32%, Testing Accuracy: 7.86%
# Path cost mean this epoch: 636.44, Total path cost mean : 636.44
#
# Epoch [2/50]
# Train Accuracy: 6.94%, Testing Accuracy: 7.89%
# Path cost mean this epoch: 643.44, Total path cost mean : 639.94
#
# Epoch [3/50]
# Train Accuracy: 6.83%, Testing Accuracy: 7.54%
# Path cost mean this epoch: 520.69, Total path cost mean : 600.19
#
# Epoch [4/50]
# Train Accuracy: 6.92%, Testing Accuracy: 7.32%
# Path cost mean this epoch: 533.00, Total path cost mean : 583.39
#
# Epoch [5/50]
# Train Accuracy: 6.77%, Testing Accuracy: 7.07%
# Path cost mean this epoch: 618.44, Total path cost mean : 590.40
#
# Epoch [6/50]
# Train Accuracy: 7.11%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 602.12, Total path cost mean : 592.35
#
# Epoch [7/50]
# Train Accuracy: 7.43%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 444.44, Total path cost mean : 571.22
#
# Epoch [8/50]
# Train Accuracy: 7.58%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 591.50, Total path cost mean : 573.76
#
# Epoch [9/50]
# Train Accuracy: 7.61%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 522.50, Total path cost mean : 568.06
#
# Epoch [10/50]
# Train Accuracy: 7.73%, Testing Accuracy: 6.11%
# Path cost mean this epoch: 513.44, Total path cost mean : 562.60
#
# Epoch [11/50]
# Train Accuracy: 7.86%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 502.62, Total path cost mean : 557.15
#
# Epoch [12/50]
# Train Accuracy: 8.00%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 480.44, Total path cost mean : 550.76
#
# Epoch [13/50]
# Train Accuracy: 8.42%, Testing Accuracy: 6.29%
# Path cost mean this epoch: 430.00, Total path cost mean : 541.47
#
# Epoch [14/50]
# Train Accuracy: 8.44%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 340.19, Total path cost mean : 527.09
#
# Epoch [15/50]
# Train Accuracy: 8.55%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 572.81, Total path cost mean : 530.14
#
# Epoch [16/50]
# Train Accuracy: 8.39%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 520.56, Total path cost mean : 529.54
#
# Epoch [17/50]
# Train Accuracy: 8.84%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 401.94, Total path cost mean : 522.03
#
# Epoch [18/50]
# Train Accuracy: 9.02%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 425.25, Total path cost mean : 516.66
#
# Epoch [19/50]
# Train Accuracy: 9.06%, Testing Accuracy: 6.93%
# Path cost mean this epoch: 377.19, Total path cost mean : 509.32
#
# Epoch [20/50]
# Train Accuracy: 9.19%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 338.69, Total path cost mean : 500.78
#
# Epoch [21/50]
# Train Accuracy: 9.32%, Testing Accuracy: 7.68%
# Path cost mean this epoch: 426.12, Total path cost mean : 497.23
#
# Epoch [22/50]
# Train Accuracy: 9.20%, Testing Accuracy: 7.25%
# Path cost mean this epoch: 334.38, Total path cost mean : 489.83
#
# Epoch [23/50]
# Train Accuracy: 9.26%, Testing Accuracy: 6.04%
# Path cost mean this epoch: 278.00, Total path cost mean : 480.62
#
# Epoch [24/50]
# Train Accuracy: 9.29%, Testing Accuracy: 7.04%
# Path cost mean this epoch: 411.19, Total path cost mean : 477.72
#
# Epoch [25/50]
# Train Accuracy: 9.52%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 296.50, Total path cost mean : 470.48
#
# Epoch [26/50]
# Train Accuracy: 9.89%, Testing Accuracy: 7.54%
# Path cost mean this epoch: 415.38, Total path cost mean : 468.36
#
# Epoch [27/50]
# Train Accuracy: 9.65%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 337.88, Total path cost mean : 463.52
#
# Epoch [28/50]
# Train Accuracy: 9.58%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 393.00, Total path cost mean : 461.00
#
# Epoch [29/50]
# Train Accuracy: 9.71%, Testing Accuracy: 7.36%
# Path cost mean this epoch: 380.00, Total path cost mean : 458.21
#
# Epoch [30/50]
# Train Accuracy: 9.90%, Testing Accuracy: 7.43%
# Path cost mean this epoch: 338.19, Total path cost mean : 454.21
#
# Epoch [31/50]
# Train Accuracy: 10.09%, Testing Accuracy: 7.07%
# Path cost mean this epoch: 301.50, Total path cost mean : 449.28
#
# Epoch [32/50]
# Train Accuracy: 9.54%, Testing Accuracy: 7.11%
# Path cost mean this epoch: 354.00, Total path cost mean : 446.31
#
# Epoch [33/50]
# Train Accuracy: 9.78%, Testing Accuracy: 7.18%
# Path cost mean this epoch: 322.31, Total path cost mean : 442.55
#
# Epoch [34/50]
# Train Accuracy: 9.72%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 211.44, Total path cost mean : 435.75
#
# Epoch [35/50]
# Train Accuracy: 9.88%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 228.25, Total path cost mean : 429.82
#
# Epoch [36/50]
# Train Accuracy: 10.16%, Testing Accuracy: 6.93%
# Path cost mean this epoch: 402.06, Total path cost mean : 429.05
#
# Epoch [37/50]
# Train Accuracy: 10.03%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 356.81, Total path cost mean : 427.10
#
# Epoch [38/50]
# Train Accuracy: 10.15%, Testing Accuracy: 6.57%
# Path cost mean this epoch: 324.56, Total path cost mean : 424.40
#
# Epoch [39/50]
# Train Accuracy: 10.38%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 284.94, Total path cost mean : 420.83
#
# Epoch [40/50]
# Train Accuracy: 10.09%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 287.12, Total path cost mean : 417.48
#
# Epoch [41/50]
# Train Accuracy: 10.09%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 375.00, Total path cost mean : 416.45
#
# Epoch [42/50]
# Train Accuracy: 9.98%, Testing Accuracy: 7.04%
# Path cost mean this epoch: 385.56, Total path cost mean : 415.71
#
# Epoch [43/50]
# Train Accuracy: 10.40%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 291.94, Total path cost mean : 412.83
#
# Epoch [44/50]
# Train Accuracy: 10.46%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 406.06, Total path cost mean : 412.68
#
# Epoch [45/50]
# Train Accuracy: 11.00%, Testing Accuracy: 6.11%
# Path cost mean this epoch: 322.25, Total path cost mean : 410.67
#
# Epoch [46/50]
# Train Accuracy: 10.44%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 341.38, Total path cost mean : 409.16
#
# Epoch [47/50]
# Train Accuracy: 10.47%, Testing Accuracy: 6.11%
# Path cost mean this epoch: 431.81, Total path cost mean : 409.64
#
# Epoch [48/50]
# Train Accuracy: 10.14%, Testing Accuracy: 6.11%
# Path cost mean this epoch: 350.62, Total path cost mean : 408.42
#
# Epoch [49/50]
# Train Accuracy: 10.54%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 195.25, Total path cost mean : 404.07
#
# Epoch [50/50]
# Train Accuracy: 10.55%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 376.94, Total path cost mean : 403.52
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=2_num_heads=5
# Epoch [1/50]
# Train Accuracy: 7.29%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 626.38, Total path cost mean : 626.38
#
# Epoch [2/50]
# Train Accuracy: 7.35%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 629.81, Total path cost mean : 628.09
#
# Epoch [3/50]
# Train Accuracy: 7.51%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 595.06, Total path cost mean : 617.08
#
# Epoch [4/50]
# Train Accuracy: 7.57%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 503.19, Total path cost mean : 588.61
#
# Epoch [5/50]
# Train Accuracy: 7.35%, Testing Accuracy: 7.14%
# Path cost mean this epoch: 664.56, Total path cost mean : 603.80
#
# Epoch [6/50]
# Train Accuracy: 7.50%, Testing Accuracy: 6.86%
# Path cost mean this epoch: 495.75, Total path cost mean : 585.79
#
# Epoch [7/50]
# Train Accuracy: 7.54%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 544.69, Total path cost mean : 579.92
#
# Epoch [8/50]
# Train Accuracy: 7.91%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 515.00, Total path cost mean : 571.80
#
# Epoch [9/50]
# Train Accuracy: 8.74%, Testing Accuracy: 6.54%
# Path cost mean this epoch: 392.56, Total path cost mean : 551.89
#
# Epoch [10/50]
# Train Accuracy: 8.38%, Testing Accuracy: 6.86%
# Path cost mean this epoch: 512.56, Total path cost mean : 547.96
#
# Epoch [11/50]
# Train Accuracy: 8.30%, Testing Accuracy: 6.54%
# Path cost mean this epoch: 498.75, Total path cost mean : 543.48
#
# Epoch [12/50]
# Train Accuracy: 8.86%, Testing Accuracy: 6.54%
# Path cost mean this epoch: 410.75, Total path cost mean : 532.42
#
# Epoch [13/50]
# Train Accuracy: 8.97%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 435.88, Total path cost mean : 525.00
#
# Epoch [14/50]
# Train Accuracy: 9.01%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 621.44, Total path cost mean : 531.88
#
# Epoch [15/50]
# Train Accuracy: 9.06%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 376.44, Total path cost mean : 521.52
#
# Epoch [16/50]
# Train Accuracy: 8.95%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 589.62, Total path cost mean : 525.78
#
# Epoch [17/50]
# Train Accuracy: 9.43%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 403.00, Total path cost mean : 518.56
#
# Epoch [18/50]
# Train Accuracy: 9.03%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 468.19, Total path cost mean : 515.76
#
# Epoch [19/50]
# Train Accuracy: 9.49%, Testing Accuracy: 6.04%
# Path cost mean this epoch: 400.56, Total path cost mean : 509.69
#
# Epoch [20/50]
# Train Accuracy: 9.55%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 441.19, Total path cost mean : 506.27
#
# Epoch [21/50]
# Train Accuracy: 9.51%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 334.06, Total path cost mean : 498.07
#
# Epoch [22/50]
# Train Accuracy: 9.51%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 447.38, Total path cost mean : 495.76
#
# Epoch [23/50]
# Train Accuracy: 9.38%, Testing Accuracy: 6.39%
# Path cost mean this epoch: 488.56, Total path cost mean : 495.45
#
# Epoch [24/50]
# Train Accuracy: 9.92%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 367.69, Total path cost mean : 490.13
#
# Epoch [25/50]
# Train Accuracy: 9.63%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 260.56, Total path cost mean : 480.94
#
# Epoch [26/50]
# Train Accuracy: 9.84%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 237.38, Total path cost mean : 471.58
#
# Epoch [27/50]
# Train Accuracy: 9.55%, Testing Accuracy: 6.29%
# Path cost mean this epoch: 377.88, Total path cost mean : 468.11
#
# Epoch [28/50]
# Train Accuracy: 9.47%, Testing Accuracy: 5.61%
# Path cost mean this epoch: 390.44, Total path cost mean : 465.33
#
# Epoch [29/50]
# Train Accuracy: 9.81%, Testing Accuracy: 5.75%
# Path cost mean this epoch: 306.94, Total path cost mean : 459.87
#
# Epoch [30/50]
# Train Accuracy: 9.63%, Testing Accuracy: 5.71%
# Path cost mean this epoch: 300.81, Total path cost mean : 454.57
#
# Epoch [31/50]
# Train Accuracy: 9.89%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 311.44, Total path cost mean : 449.95
#
# Epoch [32/50]
# Train Accuracy: 9.96%, Testing Accuracy: 5.71%
# Path cost mean this epoch: 310.50, Total path cost mean : 445.59
#
# Epoch [33/50]
# Train Accuracy: 9.82%, Testing Accuracy: 5.79%
# Path cost mean this epoch: 281.62, Total path cost mean : 440.62
#
# Epoch [34/50]
# Train Accuracy: 10.00%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 287.75, Total path cost mean : 436.13
#
# Epoch [35/50]
# Train Accuracy: 10.12%, Testing Accuracy: 5.32%
# Path cost mean this epoch: 219.06, Total path cost mean : 429.93
#
# Epoch [36/50]
# Train Accuracy: 9.82%, Testing Accuracy: 5.71%
# Path cost mean this epoch: 225.50, Total path cost mean : 424.25
#
# Epoch [37/50]
# Train Accuracy: 10.09%, Testing Accuracy: 5.54%
# Path cost mean this epoch: 222.06, Total path cost mean : 418.78
#
# Epoch [38/50]
# Train Accuracy: 10.06%, Testing Accuracy: 6.18%
# Path cost mean this epoch: 304.50, Total path cost mean : 415.78
#
# Epoch [39/50]
# Train Accuracy: 10.44%, Testing Accuracy: 5.75%
# Path cost mean this epoch: 264.69, Total path cost mean : 411.90
#
# Epoch [40/50]
# Train Accuracy: 10.46%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 278.94, Total path cost mean : 408.58
#
# Epoch [41/50]
# Train Accuracy: 10.29%, Testing Accuracy: 5.43%
# Path cost mean this epoch: 251.00, Total path cost mean : 404.73
#
# Epoch [42/50]
# Train Accuracy: 10.42%, Testing Accuracy: 5.29%
# Path cost mean this epoch: 240.56, Total path cost mean : 400.83
#
# Epoch [43/50]
# Train Accuracy: 10.12%, Testing Accuracy: 5.32%
# Path cost mean this epoch: 225.19, Total path cost mean : 396.74
#
# Epoch [44/50]
# Train Accuracy: 10.75%, Testing Accuracy: 6.00%
# Path cost mean this epoch: 229.62, Total path cost mean : 392.94
#
# Epoch [45/50]
# Train Accuracy: 10.71%, Testing Accuracy: 5.36%
# Path cost mean this epoch: 273.81, Total path cost mean : 390.30
#
# Epoch [46/50]
# Train Accuracy: 10.34%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 235.19, Total path cost mean : 386.92
#
# Epoch [47/50]
# Train Accuracy: 10.61%, Testing Accuracy: 5.68%
# Path cost mean this epoch: 282.50, Total path cost mean : 384.70
#
# Epoch [48/50]
# Train Accuracy: 10.54%, Testing Accuracy: 6.18%
# Path cost mean this epoch: 190.06, Total path cost mean : 380.65
#
# Epoch [49/50]
# Train Accuracy: 10.52%, Testing Accuracy: 5.21%
# Path cost mean this epoch: 155.31, Total path cost mean : 376.05
#
# Epoch [50/50]
# Train Accuracy: 10.34%, Testing Accuracy: 5.61%
# Path cost mean this epoch: 229.19, Total path cost mean : 373.11
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=3_num_heads=1
# Epoch [1/50]
# Train Accuracy: 6.95%, Testing Accuracy: 7.32%
# Path cost mean this epoch: 773.56, Total path cost mean : 773.56
#
# Epoch [2/50]
# Train Accuracy: 7.46%, Testing Accuracy: 7.39%
# Path cost mean this epoch: 618.31, Total path cost mean : 695.94
#
# Epoch [3/50]
# Train Accuracy: 7.42%, Testing Accuracy: 7.36%
# Path cost mean this epoch: 575.38, Total path cost mean : 655.75
#
# Epoch [4/50]
# Train Accuracy: 7.52%, Testing Accuracy: 7.64%
# Path cost mean this epoch: 579.62, Total path cost mean : 636.72
#
# Epoch [5/50]
# Train Accuracy: 7.68%, Testing Accuracy: 7.54%
# Path cost mean this epoch: 595.88, Total path cost mean : 628.55
#
# Epoch [6/50]
# Train Accuracy: 8.21%, Testing Accuracy: 7.46%
# Path cost mean this epoch: 566.44, Total path cost mean : 618.20
#
# Epoch [7/50]
# Train Accuracy: 7.98%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 591.19, Total path cost mean : 614.34
#
# Epoch [8/50]
# Train Accuracy: 8.19%, Testing Accuracy: 7.32%
# Path cost mean this epoch: 441.50, Total path cost mean : 592.73
#
# Epoch [9/50]
# Train Accuracy: 8.49%, Testing Accuracy: 7.75%
# Path cost mean this epoch: 380.56, Total path cost mean : 569.16
#
# Epoch [10/50]
# Train Accuracy: 8.50%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 624.69, Total path cost mean : 574.71
#
# Epoch [11/50]
# Train Accuracy: 8.87%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 399.62, Total path cost mean : 558.80
#
# Epoch [12/50]
# Train Accuracy: 8.82%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 586.06, Total path cost mean : 561.07
#
# Epoch [13/50]
# Train Accuracy: 8.85%, Testing Accuracy: 7.18%
# Path cost mean this epoch: 269.88, Total path cost mean : 538.67
#
# Epoch [14/50]
# Train Accuracy: 9.14%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 368.19, Total path cost mean : 526.49
#
# Epoch [15/50]
# Train Accuracy: 9.29%, Testing Accuracy: 7.61%
# Path cost mean this epoch: 332.19, Total path cost mean : 513.54
#
# Epoch [16/50]
# Train Accuracy: 9.45%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 316.56, Total path cost mean : 501.23
#
# Epoch [17/50]
# Train Accuracy: 9.72%, Testing Accuracy: 6.79%
# Path cost mean this epoch: 328.00, Total path cost mean : 491.04
#
# Epoch [18/50]
# Train Accuracy: 9.62%, Testing Accuracy: 6.93%
# Path cost mean this epoch: 348.31, Total path cost mean : 483.11
#
# Epoch [19/50]
# Train Accuracy: 9.38%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 244.75, Total path cost mean : 470.56
#
# Epoch [20/50]
# Train Accuracy: 9.61%, Testing Accuracy: 7.86%
# Path cost mean this epoch: 371.81, Total path cost mean : 465.62
#
# Epoch [21/50]
# Train Accuracy: 9.66%, Testing Accuracy: 7.36%
# Path cost mean this epoch: 298.00, Total path cost mean : 457.64
#
# Epoch [22/50]
# Train Accuracy: 9.75%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 288.56, Total path cost mean : 449.96
#
# Epoch [23/50]
# Train Accuracy: 9.89%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 387.06, Total path cost mean : 447.22
#
# Epoch [24/50]
# Train Accuracy: 9.90%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 378.56, Total path cost mean : 444.36
#
# Epoch [25/50]
# Train Accuracy: 9.97%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 264.44, Total path cost mean : 437.17
#
# Epoch [26/50]
# Train Accuracy: 9.71%, Testing Accuracy: 5.93%
# Path cost mean this epoch: 222.44, Total path cost mean : 428.91
#
# Epoch [27/50]
# Train Accuracy: 10.17%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 364.12, Total path cost mean : 426.51
#
# Epoch [28/50]
# Train Accuracy: 9.82%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 250.62, Total path cost mean : 420.23
#
# Epoch [29/50]
# Train Accuracy: 10.26%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 316.12, Total path cost mean : 416.64
#
# Epoch [30/50]
# Train Accuracy: 10.22%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 220.56, Total path cost mean : 410.10
#
# Epoch [31/50]
# Train Accuracy: 9.85%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 240.75, Total path cost mean : 404.64
#
# Epoch [32/50]
# Train Accuracy: 10.17%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 227.19, Total path cost mean : 399.09
#
# Epoch [33/50]
# Train Accuracy: 10.09%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 252.38, Total path cost mean : 394.65
#
# Epoch [34/50]
# Train Accuracy: 10.59%, Testing Accuracy: 6.11%
# Path cost mean this epoch: 301.44, Total path cost mean : 391.90
#
# Epoch [35/50]
# Train Accuracy: 10.39%, Testing Accuracy: 6.00%
# Path cost mean this epoch: 258.50, Total path cost mean : 388.09
#
# Epoch [36/50]
# Train Accuracy: 10.32%, Testing Accuracy: 6.64%
# Path cost mean this epoch: 200.75, Total path cost mean : 382.89
#
# Epoch [37/50]
# Train Accuracy: 10.43%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 203.88, Total path cost mean : 378.05
#
# Epoch [38/50]
# Train Accuracy: 10.55%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 352.44, Total path cost mean : 377.38
#
# Epoch [39/50]
# Train Accuracy: 10.16%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 262.75, Total path cost mean : 374.44
#
# Epoch [40/50]
# Train Accuracy: 10.86%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 228.94, Total path cost mean : 370.80
#
# Epoch [41/50]
# Train Accuracy: 10.75%, Testing Accuracy: 6.04%
# Path cost mean this epoch: 279.12, Total path cost mean : 368.56
#
# Epoch [42/50]
# Train Accuracy: 10.68%, Testing Accuracy: 6.04%
# Path cost mean this epoch: 237.75, Total path cost mean : 365.45
#
# Epoch [43/50]
# Train Accuracy: 10.79%, Testing Accuracy: 5.96%
# Path cost mean this epoch: 319.06, Total path cost mean : 364.37
#
# Epoch [44/50]
# Train Accuracy: 10.62%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 288.62, Total path cost mean : 362.65
#
# Epoch [45/50]
# Train Accuracy: 10.51%, Testing Accuracy: 5.29%
# Path cost mean this epoch: 246.81, Total path cost mean : 360.07
#
# Epoch [46/50]
# Train Accuracy: 10.60%, Testing Accuracy: 5.64%
# Path cost mean this epoch: 236.25, Total path cost mean : 357.38
#
# Epoch [47/50]
# Train Accuracy: 10.67%, Testing Accuracy: 5.46%
# Path cost mean this epoch: 331.88, Total path cost mean : 356.84
#
# Epoch [48/50]
# Train Accuracy: 10.86%, Testing Accuracy: 5.61%
# Path cost mean this epoch: 231.62, Total path cost mean : 354.23
#
# Epoch [49/50]
# Train Accuracy: 10.71%, Testing Accuracy: 6.07%
# Path cost mean this epoch: 217.25, Total path cost mean : 351.44
#
# Epoch [50/50]
# Train Accuracy: 10.57%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 356.06, Total path cost mean : 351.53
#
# Training with learning_rate=0.0001_hidden_size=16_num_layers=3_num_heads=3
# Epoch [1/50]
# Train Accuracy: 6.67%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 613.62, Total path cost mean : 613.62
#
# Epoch [2/50]
# Train Accuracy: 7.53%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 710.19, Total path cost mean : 661.91
#
# Epoch [3/50]
# Train Accuracy: 7.63%, Testing Accuracy: 6.75%
# Path cost mean this epoch: 672.44, Total path cost mean : 665.42
#
# Epoch [4/50]
# Train Accuracy: 7.63%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 627.94, Total path cost mean : 656.05
#
# Epoch [5/50]
# Train Accuracy: 7.83%, Testing Accuracy: 7.25%
# Path cost mean this epoch: 574.75, Total path cost mean : 639.79
#
# Epoch [6/50]
# Train Accuracy: 7.68%, Testing Accuracy: 7.29%
# Path cost mean this epoch: 704.06, Total path cost mean : 650.50
#
# Epoch [7/50]
# Train Accuracy: 8.25%, Testing Accuracy: 6.96%
# Path cost mean this epoch: 620.50, Total path cost mean : 646.21
#
# Epoch [8/50]
# Train Accuracy: 8.34%, Testing Accuracy: 7.18%
# Path cost mean this epoch: 524.19, Total path cost mean : 630.96
#
# Epoch [9/50]
# Train Accuracy: 8.32%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 597.44, Total path cost mean : 627.24
#
# Epoch [10/50]
# Train Accuracy: 8.95%, Testing Accuracy: 6.86%
# Path cost mean this epoch: 556.88, Total path cost mean : 620.20
#
# Epoch [11/50]
# Train Accuracy: 8.86%, Testing Accuracy: 6.68%
# Path cost mean this epoch: 508.25, Total path cost mean : 610.02
#
# Epoch [12/50]
# Train Accuracy: 8.62%, Testing Accuracy: 6.89%
# Path cost mean this epoch: 418.75, Total path cost mean : 594.08
#
# Epoch [13/50]
# Train Accuracy: 9.15%, Testing Accuracy: 7.32%
# Path cost mean this epoch: 634.06, Total path cost mean : 597.16
#
# Epoch [14/50]
# Train Accuracy: 8.93%, Testing Accuracy: 7.00%
# Path cost mean this epoch: 407.00, Total path cost mean : 583.58
#
# Epoch [15/50]
# Train Accuracy: 9.33%, Testing Accuracy: 6.00%
# Path cost mean this epoch: 437.88, Total path cost mean : 573.86
#
# Epoch [16/50]
# Train Accuracy: 9.38%, Testing Accuracy: 6.93%
# Path cost mean this epoch: 409.25, Total path cost mean : 563.57
#
# Epoch [17/50]
# Train Accuracy: 9.01%, Testing Accuracy: 6.36%
# Path cost mean this epoch: 389.56, Total path cost mean : 553.34
#
# Epoch [18/50]
# Train Accuracy: 9.36%, Testing Accuracy: 6.50%
# Path cost mean this epoch: 505.00, Total path cost mean : 550.65
#
# Epoch [19/50]
# Train Accuracy: 9.60%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 425.38, Total path cost mean : 544.06
#
# Epoch [20/50]
# Train Accuracy: 9.63%, Testing Accuracy: 6.71%
# Path cost mean this epoch: 416.75, Total path cost mean : 537.69
#
# Epoch [21/50]
# Train Accuracy: 9.76%, Testing Accuracy: 7.00%
# ...
#
# Epoch [27/50]
# Train Accuracy: 12.72%, Testing Accuracy: 5.27%
# Path cost mean this epoch: 245.80, Total path cost mean : 255.33
#
# Epoch [28/50]
# Train Accuracy: 12.79%, Testing Accuracy: 5.01%
# Path cost mean this epoch: 238.89, Total path cost mean : 254.74
#
# Epoch [29/50]
# Train Accuracy: 13.27%, Testing Accuracy: 5.20%
# Path cost mean this epoch: 218.75, Total path cost mean : 253.50
#
# Epoch [30/50]
# Train Accuracy: 12.99%, Testing Accuracy: 5.09%
# Path cost mean this epoch: 222.36, Total path cost mean : 252.46
#
# Epoch [31/50]
# Train Accuracy: 13.09%, Testing Accuracy: 5.09%
# Path cost mean this epoch: 173.67, Total path cost mean : 249.92
#
# Epoch [32/50]
# Train Accuracy: 13.24%, Testing Accuracy: 4.98%
# Path cost mean this epoch: 242.91, Total path cost mean : 249.70
#
# Epoch [33/50]
# Train Accuracy: 13.46%, Testing Accuracy: 4.76%
# Path cost mean this epoch: 221.70, Total path cost mean : 248.85
#
# Epoch [34/50]
# Train Accuracy: 13.20%, Testing Accuracy: 4.91%
# Path cost mean this epoch: 248.12, Total path cost mean : 248.83
#
# Epoch [35/50]
# Train Accuracy: 13.70%, Testing Accuracy: 5.38%
# Path cost mean this epoch: 229.73, Total path cost mean : 248.29
#
# Epoch [36/50]
# Train Accuracy: 13.71%, Testing Accuracy: 5.27%
# Path cost mean this epoch: 237.75, Total path cost mean : 247.99
#
# Epoch [37/50]
# Train Accuracy: 13.83%, Testing Accuracy: 5.23%
# Path cost mean this epoch: 212.05, Total path cost mean : 247.02
#
# Epoch [38/50]
# Train Accuracy: 13.29%, Testing Accuracy: 5.09%
# Path cost mean this epoch: 281.38, Total path cost mean : 247.93
#
# Epoch [39/50]
# Train Accuracy: 13.94%, Testing Accuracy: 4.83%
# Path cost mean this epoch: 219.25, Total path cost mean : 247.19
#
# Epoch [40/50]
# Train Accuracy: 13.60%, Testing Accuracy: 5.09%
# Path cost mean this epoch: 244.42, Total path cost mean : 247.12
#
# Epoch [41/50]
# Train Accuracy: 13.76%, Testing Accuracy: 4.80%
# Path cost mean this epoch: 222.09, Total path cost mean : 246.51
#
# Epoch [42/50]
# Train Accuracy: 14.32%, Testing Accuracy: 5.20%
# Path cost mean this epoch: 296.84, Total path cost mean : 247.71
#
# Epoch [43/50]
# Train Accuracy: 14.18%, Testing Accuracy: 5.74%
# Path cost mean this epoch: 194.86, Total path cost mean : 246.48
#
# Epoch [44/50]
# Train Accuracy: 14.03%, Testing Accuracy: 4.87%
# Path cost mean this epoch: 218.05, Total path cost mean : 245.83
#
# Epoch [45/50]
# Train Accuracy: 14.49%, Testing Accuracy: 4.47%
# Path cost mean this epoch: 237.95, Total path cost mean : 245.66
#
# Epoch [46/50]
# Train Accuracy: 14.31%, Testing Accuracy: 4.80%
# Path cost mean this epoch: 232.22, Total path cost mean : 245.37
#
# Epoch [47/50]
# Train Accuracy: 14.64%, Testing Accuracy: 4.91%
# Path cost mean this epoch: 259.45, Total path cost mean : 245.67
#
# Epoch [48/50]
# Train Accuracy: 14.52%, Testing Accuracy: 4.72%
# Path cost mean this epoch: 251.80, Total path cost mean : 245.79
#
# Epoch [49/50]
# Train Accuracy: 14.34%, Testing Accuracy: 4.87%
# Path cost mean this epoch: 213.08, Total path cost mean : 245.13
#
# Epoch [50/50]
# Train Accuracy: 14.65%, Testing Accuracy: 4.65%
# Path cost mean this epoch: 252.06, Total path cost mean : 245.27
#
# Training with learning_rate=0.001_hidden_size=64_num_layers=3_num_heads=3
# Epoch [1/50]
# Train Accuracy: 6.90%, Testing Accuracy: 7.52%
# Path cost mean this epoch: 537.36, Total path cost mean : 537.36
#
# Epoch [2/50]
# Train Accuracy: 8.10%, Testing Accuracy: 8.10%
# Path cost mean this epoch: 435.11, Total path cost mean : 486.23
#
# Epoch [3/50]
# Train Accuracy: 8.53%, Testing Accuracy: 6.43%
# Path cost mean this epoch: 361.88, Total path cost mean : 444.78
#
# Epoch [4/50]
# Train Accuracy: 9.14%, Testing Accuracy: 7.38%
# Path cost mean this epoch: 285.27, Total path cost mean : 404.90
#
# Epoch [5/50]
# Train Accuracy: 9.34%, Testing Accuracy: 7.49%
# Path cost mean this epoch: 309.02, Total path cost mean : 385.73
#
# Epoch [6/50]
# Train Accuracy: 9.59%, Testing Accuracy: 7.12%
# Path cost mean this epoch: 270.12, Total path cost mean : 366.46
#
# Epoch [7/50]
# Train Accuracy: 9.91%, Testing Accuracy: 6.98%
# Path cost mean this epoch: 291.88, Total path cost mean : 355.80
#
# Epoch [8/50]
# Train Accuracy: 9.71%, Testing Accuracy: 6.80%
# Path cost mean this epoch: 260.39, Total path cost mean : 343.88
#
# Epoch [9/50]
# Train Accuracy: 10.20%, Testing Accuracy: 7.74%
# Path cost mean this epoch: 220.75, Total path cost mean : 330.20
#
# Epoch [10/50]
# Train Accuracy: 10.27%, Testing Accuracy: 6.32%
# Path cost mean this epoch: 217.03, Total path cost mean : 318.88
#
# Epoch [11/50]
# Train Accuracy: 10.89%, Testing Accuracy: 7.27%
# Path cost mean this epoch: 318.73, Total path cost mean : 318.87
#
# Epoch [12/50]
# Train Accuracy: 10.80%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 266.97, Total path cost mean : 314.54
#
# Epoch [13/50]
# Train Accuracy: 10.94%, Testing Accuracy: 6.58%
# Path cost mean this epoch: 240.30, Total path cost mean : 308.83
#
# Epoch [14/50]
# Train Accuracy: 11.00%, Testing Accuracy: 5.63%
# Path cost mean this epoch: 263.55, Total path cost mean : 305.60
#
# Epoch [15/50]
# Train Accuracy: 11.15%, Testing Accuracy: 5.70%
# Path cost mean this epoch: 268.52, Total path cost mean : 303.12
#
# Epoch [16/50]
# Train Accuracy: 11.38%, Testing Accuracy: 6.10%
# Path cost mean this epoch: 251.83, Total path cost mean : 299.92
#
# Epoch [17/50]
# Train Accuracy: 11.61%, Testing Accuracy: 6.29%
# Path cost mean this epoch: 253.36, Total path cost mean : 297.18
#
# Epoch [18/50]
# Train Accuracy: 11.76%, Testing Accuracy: 5.67%
# Path cost mean this epoch: 243.64, Total path cost mean : 294.20
#
# Epoch [19/50]
# Train Accuracy: 11.33%, Testing Accuracy: 5.67%
# Path cost mean this epoch: 267.36, Total path cost mean : 292.79
#
# Epoch [20/50]
# Train Accuracy: 11.96%, Testing Accuracy: 6.18%
# Path cost mean this epoch: 243.77, Total path cost mean : 290.34
#
# Epoch [21/50]
# Train Accuracy: 12.11%, Testing Accuracy: 5.70%
# Path cost mean this epoch: 227.80, Total path cost mean : 287.36
#
# Epoch [22/50]
# Train Accuracy: 12.43%, Testing Accuracy: 6.25%
# Path cost mean this epoch: 254.61, Total path cost mean : 285.87
#
# Epoch [23/50]
# Train Accuracy: 12.57%, Testing Accuracy: 6.21%
# Path cost mean this epoch: 244.02, Total path cost mean : 284.05
#
# Epoch [24/50]
# Train Accuracy: 12.50%, Testing Accuracy: 5.31%
# Path cost mean this epoch: 238.70, Total path cost mean : 282.16
#
# Epoch [25/50]
# Train Accuracy: 12.46%, Testing Accuracy: 5.81%
# Path cost mean this epoch: 235.22, Total path cost mean : 280.29
#
# Epoch [26/50]
# Train Accuracy: 12.52%, Testing Accuracy: 5.38%
# Path cost mean this epoch: 226.59, Total path cost mean : 278.22
#
# Epoch [27/50]
# Train Accuracy: 12.68%, Testing Accuracy: 5.41%
# Path cost mean this epoch: 282.44, Total path cost mean : 278.38
#
# Epoch [28/50]
# Train Accuracy: 12.68%, Testing Accuracy: 5.27%
# Path cost mean this epoch: 218.56, Total path cost mean : 276.24
#
# Epoch [29/50]
# Train Accuracy: 13.23%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 235.00, Total path cost mean : 274.82
#
# Epoch [30/50]
# Train Accuracy: 13.13%, Testing Accuracy: 4.98%
# Path cost mean this epoch: 248.80, Total path cost mean : 273.95
#
# Epoch [31/50]
# Train Accuracy: 13.24%, Testing Accuracy: 4.98%
# Path cost mean this epoch: 239.67, Total path cost mean : 272.85
#
# Epoch [32/50]
# Train Accuracy: 13.25%, Testing Accuracy: 5.89%
# Path cost mean this epoch: 288.16, Total path cost mean : 273.32
#
# Epoch [33/50]
# Train Accuracy: 13.18%, Testing Accuracy: 4.91%
# Path cost mean this epoch: 237.98, Total path cost mean : 272.25
#
# Epoch [34/50]
# Train Accuracy: 13.76%, Testing Accuracy: 5.92%
# Path cost mean this epoch: 274.52, Total path cost mean : 272.32
#
# Epoch [35/50]
# Train Accuracy: 13.77%, Testing Accuracy: 5.38%
# Path cost mean this epoch: 228.62, Total path cost mean : 271.07
#
# Epoch [36/50]
# Train Accuracy: 13.74%, Testing Accuracy: 5.20%
# Path cost mean this epoch: 228.25, Total path cost mean : 269.88
#
# Epoch [37/50]
# Train Accuracy: 13.66%, Testing Accuracy: 4.83%
# Path cost mean this epoch: 253.36, Total path cost mean : 269.44
#
# Epoch [38/50]
# Train Accuracy: 13.71%, Testing Accuracy: 5.41%
# Path cost mean this epoch: 222.19, Total path cost mean : 268.19
#
# Epoch [39/50]
# Train Accuracy: 13.85%, Testing Accuracy: 5.01%
# Path cost mean this epoch: 270.86, Total path cost mean : 268.26
#
# Epoch [40/50]
# Train Accuracy: 13.88%, Testing Accuracy: 5.16%
# Path cost mean this epoch: 240.81, Total path cost mean : 267.57
#
# Epoch [41/50]
# Train Accuracy: 13.67%, Testing Accuracy: 4.72%
# Path cost mean this epoch: 273.62, Total path cost mean : 267.72
#
# Epoch [42/50]
# Train Accuracy: 13.95%, Testing Accuracy: 4.72%
# Path cost mean this epoch: 277.73, Total path cost mean : 267.96
#
# Epoch [43/50]
# Train Accuracy: 14.12%, Testing Accuracy: 4.83%
# Path cost mean this epoch: 271.56, Total path cost mean : 268.04
#
# Epoch [44/50]
# Train Accuracy: 13.98%, Testing Accuracy: 4.65%
# Path cost mean this epoch: 207.16, Total path cost mean : 266.66
#
# Epoch [45/50]
# Train Accuracy: 14.02%, Testing Accuracy: 5.41%
# Path cost mean this epoch: 236.12, Total path cost mean : 265.98
#
# Epoch [46/50]
# Train Accuracy: 14.29%, Testing Accuracy: 5.01%
# Path cost mean this epoch: 265.03, Total path cost mean : 265.96
#
# Epoch [47/50]
# Train Accuracy: 13.77%, Testing Accuracy: 5.49%
# Path cost mean this epoch: 225.52, Total path cost mean : 265.10
#
# Epoch [48/50]
# Train Accuracy: 14.07%, Testing Accuracy: 5.09%
# Path cost mean this epoch: 271.91, Total path cost mean : 265.24
#
# Epoch [49/50]
# Train Accuracy: 14.00%, Testing Accuracy: 4.91%
# Path cost mean this epoch: 238.48, Total path cost mean : 264.70
#
# Epoch [50/50]
# Train Accuracy: 14.32%, Testing Accuracy: 4.51%
# Path cost mean this epoch: 247.62, Total path cost mean : 264.35
#
# Training with learning_rate=0.001_hidden_size=64_num_layers=3_num_heads=5
# Epoch [1/50]
# Train Accuracy: 7.54%, Testing Accuracy: 8.68%
# Path cost mean this epoch: 484.06, Total path cost mean : 484.06
#
# Epoch [2/50]
# Train Accuracy: 8.44%, Testing Accuracy: 8.58%
# Path cost mean this epoch: 345.28, Total path cost mean : 414.67
#
# Epoch [3/50]
# Train Accuracy: 9.03%, Testing Accuracy: 8.43%
# Path cost mean this epoch: 315.77, Total path cost mean : 381.70
#
# Epoch [4/50]
# Train Accuracy: 9.29%, Testing Accuracy: 8.10%
# Path cost mean this epoch: 355.61, Total path cost mean : 375.18
#
# Epoch [5/50]
# Train Accuracy: 9.42%, Testing Accuracy: 7.27%
# Path cost mean this epoch: 299.62, Total path cost mean : 360.07
#
# Epoch [6/50]
# Train Accuracy: 9.73%, Testing Accuracy: 7.12%
# Path cost mean this epoch: 275.30, Total path cost mean : 345.94
#
# Epoch [7/50]
# Train Accuracy: 10.42%, Testing Accuracy: 9.05%
# Path cost mean this epoch: 253.27, Total path cost mean : 332.70
#
# Epoch [8/50]
# Train Accuracy: 10.65%, Testing Accuracy: 6.87%
# Path cost mean this epoch: 262.11, Total path cost mean : 323.88
#
# Epoch [9/50]
# Train Accuracy: 10.39%, Testing Accuracy: 6.47%
# Path cost mean this epoch: 234.39, Total path cost mean : 313.93
#
# Epoch [10/50]
# Train Accuracy: 10.69%, Testing Accuracy: 7.70%
# Path cost mean this epoch: 244.56, Total path cost mean : 307.00
#
# Epoch [11/50]
# Train Accuracy: 10.70%, Testing Accuracy: 8.61%
# Path cost mean this epoch: 250.53, Total path cost mean : 301.86
#
# Epoch [12/50]
# Train Accuracy: 11.04%, Testing Accuracy: 6.40%
# Path cost mean this epoch: 267.36, Total path cost mean : 298.99
#
# Epoch [13/50]
# Train Accuracy: 10.96%, Testing Accuracy: 6.10%
# Path cost mean this epoch: 240.03, Total path cost mean : 294.45
#
# Epoch [14/50]
# Train Accuracy: 11.09%, Testing Accuracy: 5.74%
# Path cost mean this epoch: 261.47, Total path cost mean : 292.10
#
# Epoch [15/50]
# Train Accuracy: 11.38%, Testing Accuracy: 6.14%
# Path cost mean this epoch: 251.36, Total path cost mean : 289.38
#
# Epoch [16/50]
# Train Accuracy: 11.44%, Testing Accuracy: 5.81%
# Path cost mean this epoch: 261.22, Total path cost mean : 287.62
#
# Epoch [17/50]
# Train Accuracy: 11.57%, Testing Accuracy: 5.20%
# Path cost mean this epoch: 219.42, Total path cost mean : 283.61
#
# Epoch [18/50]
# Train Accuracy: 11.83%, Testing Accuracy: 6.61%
# Path cost mean this epoch: 210.08, Total path cost mean : 279.52
#
# Epoch [19/50]
# Train Accuracy: 12.33%, Testing Accuracy: 5.23%
# Path cost mean this epoch: 252.05, Total path cost mean : 278.08
#
# Epoch [20/50]
# Train Accuracy: 12.24%, Testing Accuracy: 5.05%
# Path cost mean this epoch: 239.84, Total path cost mean : 276.17
#
# Epoch [21/50]
# Train Accuracy: 12.38%, Testing Accuracy: 5.31%
# Path cost mean this epoch: 292.75, Total path cost mean : 276.96
#
# Epoch [22/50]
# Train Accuracy: 12.06%, Testing Accuracy: 5.63%
# Path cost mean this epoch: 278.45, Total path cost mean : 277.02
#
# Epoch [23/50]
# Train Accuracy: 12.25%, Testing Accuracy: 5.05%
# Path cost mean this epoch: 257.95, Total path cost mean : 276.19
#
# Epoch [24/50]
# Train Accuracy: 12.53%, Testing Accuracy: 5.27%
# Path cost mean this epoch: 296.12, Total path cost mean : 277.03
#
# Epoch [25/50]
# Train Accuracy: 12.50%, Testing Accuracy: 5.20%
# Path cost mean this epoch: 236.92, Total path cost mean : 275.42
#
# Epoch [26/50]
# Train Accuracy: 12.55%, Testing Accuracy: 5.38%
# Path cost mean this epoch: 291.67, Total path cost mean : 276.05
#
# Epoch [27/50]
# Train Accuracy: 12.71%, Testing Accuracy: 5.05%
# Path cost mean this epoch: 243.70, Total path cost mean : 274.85
#
# Epoch [28/50]
# Train Accuracy: 12.73%, Testing Accuracy: 4.91%
# Path cost mean this epoch: 236.84, Total path cost mean : 273.49
#
# Epoch [29/50]
# Train Accuracy: 12.96%, Testing Accuracy: 4.80%
# Path cost mean this epoch: 229.91, Total path cost mean : 271.99
#
# Epoch [30/50]
# Train Accuracy: 12.89%, Testing Accuracy: 5.12%
# Path cost mean this epoch: 254.48, Total path cost mean : 271.40
#
# Epoch [31/50]
# Train Accuracy: 12.95%, Testing Accuracy: 5.27%
# Path cost mean this epoch: 346.75, Total path cost mean : 273.84
#
# Epoch [32/50]
# Train Accuracy: 13.49%, Testing Accuracy: 4.51%
# Path cost mean this epoch: 318.59, Total path cost mean : 275.23
#
# Epoch [33/50]
# Train Accuracy: 13.14%, Testing Accuracy: 5.05%
# Path cost mean this epoch: 268.42, Total path cost mean : 275.03
#
# Epoch [34/50]
# Train Accuracy: 13.04%, Testing Accuracy: 5.09%
# Path cost mean this epoch: 278.55, Total path cost mean : 275.13
#
# Epoch [35/50]
# Train Accuracy: 13.34%, Testing Accuracy: 4.83%
# Path cost mean this epoch: 301.67, Total path cost mean : 275.89
#
# Epoch [36/50]
# Train Accuracy: 13.16%, Testing Accuracy: 4.94%
# Path cost mean this epoch: 295.77, Total path cost mean : 276.44
#
# Epoch [37/50]
# Train Accuracy: 13.73%, Testing Accuracy: 4.54%
# Path cost mean this epoch: 235.12, Total path cost mean : 275.32
#
# Epoch [38/50]
# Train Accuracy: 13.57%, Testing Accuracy: 5.63%
# Path cost mean this epoch: 316.97, Total path cost mean : 276.42
#
# Epoch [39/50]
# Train Accuracy: 13.49%, Testing Accuracy: 4.72%
# Path cost mean this epoch: 263.50, Total path cost mean : 276.09
#
# Epoch [40/50]
# Train Accuracy: 13.62%, Testing Accuracy: 4.18%
# Path cost mean this epoch: 283.91, Total path cost mean : 276.28
#
# Epoch [41/50]
# Train Accuracy: 13.63%, Testing Accuracy: 5.31%
# Path cost mean this epoch: 294.84, Total path cost mean : 276.74
#
# Epoch [42/50]
# Train Accuracy: 13.79%, Testing Accuracy: 4.69%
# Path cost mean this epoch: 332.95, Total path cost mean : 278.08
#
# Epoch [43/50]
# Train Accuracy: 13.62%, Testing Accuracy: 4.80%
# Path cost mean this epoch: 308.19, Total path cost mean : 278.78
#
# Epoch [44/50]
# Train Accuracy: 14.30%, Testing Accuracy: 4.98%
# Path cost mean this epoch: 332.53, Total path cost mean : 280.00
#
# Epoch [45/50]
# Train Accuracy: 13.95%, Testing Accuracy: 4.94%
# Path cost mean this epoch: 254.23, Total path cost mean : 279.43
#
# Epoch [46/50]
# Train Accuracy: 14.19%, Testing Accuracy: 4.72%
# Path cost mean this epoch: 295.20, Total path cost mean : 279.77
#
# Epoch [47/50]
# Train Accuracy: 13.96%, Testing Accuracy: 4.69%
# Path cost mean this epoch: 296.31, Total path cost mean : 280.12
#
# Epoch [48/50]
# Train Accuracy: 14.33%, Testing Accuracy: 4.32%
# Path cost mean this epoch: 269.88, Total path cost mean : 279.91
#
# Epoch [49/50]
# Train Accuracy: 14.23%, Testing Accuracy: 4.94%
# Path cost mean this epoch: 279.78, Total path cost mean : 279.90
#
# Epoch [50/50]
# Train Accuracy: 14.46%, Testing Accuracy: 4.65%
# Path cost mean this epoch: 268.08, Total path cost mean : 279.67
