# %% [markdown]
# ### Importación de los módulos
# Se importan los módulos necesarios para el entrenamiento del modelo de control

# %%
import pandas as pd
import torch
import dgl
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import dgl.nn as dglnn
from sklearn.model_selection import train_test_split
import networkx as nx
import random
from statistics import mean
import csv
import time

# %% [markdown]
# ### Función de generación de grafo aleatorio
# Esta función genera un grafo completo ponderado con pesos aleatorios usado en lso ejemplos de la evaluación del coste medio de los caminos generados por el modelo

# %%
def generate_random_tsp_graph(n_cities, min_distance=1, max_distance=100):
    G = nx.Graph()
    for i in range(n_cities):
        G.add_node(i)

    for i in range(n_cities):
        for j in range(i+1, n_cities):
            distance = random.randint(min_distance, max_distance)
            G.add_edge(i, j, weight=distance)

    return G

def graph_to_adjacency_matrix(G):
    return nx.adjacency_matrix(G).todense().tolist()

# %% [markdown]
# Se definen las constantes como el número de clases de la predicción y la longitud de las secuencias.
# Se lee el dataset previamente generado en `dataset_generation_processing.ipynb`

# %%
SEQUENCE_LENGTH = 14
NUM_CLASSES_OUT = 15
BATCH_SIZE = 16

# %%
df = pd.read_csv('dataset_full_adj_matrix_15_nodes_stock.csv')

# %% [markdown]
# ### Función usada para obtener los índices no redundantes de una matriz de adyacencia de tamaño NxN
#
# La función lista los índices de los coeficientes situados bajo la diagonal principal de una matriz

# %%
def below_diagonal_indices(n):
    # List to store the indices of elements below the diagonal
    indices = []

    # Loop through each row
    for i in range(1, n):  # Start from 1 because the first row does not have any elements below the diagonal
        # Loop through each column up to (but not including) the diagonal
        for j in range(i):
            # Compute the index in the flattened matrix and add to the list
            index = i * n + j
            indices.append(index)

    return indices

# %% [markdown]
# ### Obtención de la matriz de adyacencia a partir del dataset
#
# Se leen los coeficientes y se convierten en un tensor que contiene 14000 ejemplos de matrices.

# %%
selected_columns = ['col_' + str(i) for i in range(1, NUM_CLASSES_OUT**2 + 1)]
selected_data = df[selected_columns]

numpy_array = selected_data.values
tensor = torch.tensor(numpy_array).view(df.shape[0], NUM_CLASSES_OUT, NUM_CLASSES_OUT)
adjacency_matrices = tensor
adjacency_matrices.shape
# Out:
# torch.Size([14000, 15, 15])

# %% [markdown]
# Se utiliza la función descrita con anterioridad para obtener los coeficientes bajo la diagonal principal de cada matriz de adyacencia del tesnor.
# Cada matriz de 15x15 genera 105 predictores correspondientes a los coeficientes no repetidos.

# %%
relevant_indices = below_diagonal_indices(NUM_CLASSES_OUT)
flat_matrices = torch.zeros((df.shape[0], (NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2))
for i in range(df.shape[0]):
    for index, j in enumerate(relevant_indices):
        flat_matrices[i][index] = df[f'col_{j+1}'][i]

# %% [markdown]
# ### Normalización de las matrices de adyacencia
#
# Se normalizan los coeficientes de las matrices entre -0.5 y 0.5

# %%
flat_matrices = flat_matrices / 101
flat_matrices
# Out:
# tensor([[0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         [0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         [0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         ...,
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307],
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307],
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307]])

# %%
graph_indices = flat_matrices
graph_indices = graph_indices - 0.5
graph_indices.shape
# Out:
# torch.Size([14000, 105])

# %% [markdown]
# ### Obtención de las secuencias de nodos
# Se obtienen los caminos parciales que componen la parte secuencial de los problemas de clasificación, se leen del dataframe y se convierten en enteros.
# Se forma un tensor de 14.000 ejemplos con las secuencias obtenidas.

# %%
sequence_tensor = torch.zeros((df.shape[0], NUM_CLASSES_OUT - 1))
for i in range(df.shape[0]):
    for j in range(SEQUENCE_LENGTH):
        sequence_tensor[i][j] = df[f'seq_{j+1}'][i]

sequence_tensor = sequence_tensor.long()
sequence_tensor
# Out:
# tensor([[ 0, -1, -1,  ..., -1, -1, -1],
#         [ 0, 12, -1,  ..., -1, -1, -1],
#         [ 0, 12,  4,  ..., -1, -1, -1],
#         ...,
#         [ 0,  2, 10,  ...,  7, -1, -1],
#         [ 0,  2, 10,  ...,  7, 14, -1],
#         [ 0,  2, 10,  ...,  7, 14,  8]])

# %% [markdown]
# ### Codificación de las secuencias
# Se utiliza una combinación de advanced indexing y tensores booleanos (masks) para codificar cada elemento (nodo) de la secuencia con su fila correspondiente en la matriz de adyacencia del ejemplo (grafo) en el que aparece.

# %%
batch_indices = torch.arange(len(sequence_tensor)).view(-1, 1).expand_as(sequence_tensor)
mask = (sequence_tensor == -1)

sequence_tensor = sequence_tensor.masked_fill(mask, 0)

sequence_encodings = adjacency_matrices[batch_indices, sequence_tensor]
sequence_encodings = sequence_encodings.masked_fill(mask.unsqueeze(-1), 0)

sequence_tensor = sequence_tensor.masked_fill(mask, -1)

# %%
sequence_encodings = sequence_encodings / 101
sequence_encodings[sequence_encodings != 0] -= 0.5

# %% [markdown]
# ### Extracción de los objetivos
# Se crea un tensor leyendo los objetivos almacenados en el dataset.

# %%
targets_tensor = torch.tensor(df['next_node'])
targets_tensor.shape
# Out:
# torch.Size([14000])

# %% [markdown]
# ### Definicion del modelo
# El modelo GRU consiste en:
# 1. Una capa Linear que procesa los coeficientes de las matrices de adyacencia.
# 2. Una capa Gated Recurrent Unit de la clase GRU de Pytorch que procesa las secuencias de nodos que componen los caminos parciales.
# 3. Una capa Linear que toma las salidas de las capas anteriores como entrada y devuelve la clasificación final.

# %%
class HybridModel(nn.Module):
    def __init__(self, hidden_size, num_layers, dropout):
        super(HybridModel, self).__init__()

        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # Adjacency matrix processing layer
        self.matrix_proc = nn.Linear((NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2, NUM_CLASSES_OUT)
        
        # Gated Recurrent Unit (GRU)
        self.gru = nn.GRU(input_size=NUM_CLASSES_OUT, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, dropout=dropout)# , dropout=0.1)

        # Fully Connected Layer
        self.fc = nn.Linear(NUM_CLASSES_OUT + hidden_size, NUM_CLASSES_OUT)

    def forward(self, flat_matrix, sequence_encoding):
        # Process adjacency matrix through Adjacency matrix processing layer
        matrix_out = self.matrix_proc(flat_matrix)

        # Process input through GRU
        rnn_output, _ = self.gru(sequence_encoding)  # [batch_size, seq_len, num_classes]
        rnn_output = rnn_output[:, -1, :]

        # Concatenate outputs from matrix_proc and RNN
        concat_output = torch.cat((matrix_out, rnn_output), dim=1)
        
        # Feed concatenated output through Fully Connected Layer
        out = self.fc(concat_output)
        return out

# %% [markdown]
# ### Dataset & Dataloader
# Se crea una clase hija de la clase Dataset de Pytorch para almacenar los datos.
# Esto permite mayor flexibilidad para situar la codificación de los datos en distintas partes del código y ha sido extremadamente útil durante el desarrollo de este trabajo.
# Actualmente la implementación del experimento podría hacerse con la clase Dataset directamente pero se deja implementada esta clase por si fuese útil para la continuación futura de la investigación.

# %%
from torch.utils.data import Dataset, DataLoader

# %%
class CustomGraphSequenceDataset(Dataset):
    def __init__(self, sequence_tensor, adj_matrices, targets_tensor):
        self.sequence_tensor = sequence_tensor
        self.adj_matrices = adj_matrices
        self.targets_tensor = targets_tensor

    def __len__(self):
        return len(self.sequence_tensor)

    def __getitem__(self, idx):
        sequence = self.sequence_tensor[idx]
        adj_matrix = self.adj_matrices[idx]
        target = self.targets_tensor[idx]
        # graph = adjacency_matrix_to_dgl(adj_matrix)
        return sequence, adj_matrix, target

# %% [markdown]
# De forma similar a la clase anterior, esta función collate personalizada es extremadamente útil a la hora de hacer pruebas con las diversas posibilidades para transformar los grupos de ejemplos en batches.
# Queda en el código por si viese más utilidad en la investigación futura, a pesar de que actualmente los scripts funcionarían con la función collate por defecto de pytorch.

# %%
def custom_collate_fn(batch):
    sequences, graphs, targets = zip(*batch)
    # Convert sequences to a single tensor
    sequences = torch.stack(sequences)
    # Convert targets to a single tensor
    targets = torch.stack(targets)
    # Batch graphs into a single graph
    batched_graph = torch.stack(graphs) # dgl.batch(graphs)
    return sequences, batched_graph, targets

# %% [markdown]
# ### Train Test split
# Se dividen las codificaciones de las secuencias, las matrices de adyacencia y los objetivos entre conjuntos de entrenamiento y validación.
# Se crean los datasets de entrenamiento y test a partir de los tensores resultantes.

# %%
# Split the data into training and testing sets (80% train, 20% test)
train_sequences, test_sequences, train_adj_matrices, test_adj_matrices, train_targets, test_targets = train_test_split(
    sequence_encodings, graph_indices, targets_tensor, test_size=0.2, random_state=42)

# %%
# Create Custom Dataset for train and test
train_dataset = CustomGraphSequenceDataset(train_sequences, train_adj_matrices, train_targets)
test_dataset = CustomGraphSequenceDataset(test_sequences, test_adj_matrices, test_targets)

# %%
# DataLoader for train and test
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=custom_collate_fn, drop_last=True)

# %% [markdown]
# ### Evaluación del coste medio de los caminos
# Esta función recibe un modelo como parámetro y se ejecuta durante la fase de evaluación para calcular el coste medio del camino generado por este modelo.
#
# Esta función genera un batch de grafos completos ponderados con pesos aleatorios.
# Una vez generados, se obtienen las matrices de adyacencia correspondientes a los grafos y se procesan sus coeficientes tal como se hace en el apartado anterior (Obtención de la matriz de adyacencia a partir del dataset)..
#
# Se generan tensores correspondientes a secuencias de nodos vacías (todas tienen 0 como nodo inicial como en los ejemplos del dataset).
# Se codifican dichas secuencias y se generan los elementos siguientes a partir de predicciones del modelo.

# %%
def path_evaluation(model, batch_size):
    matrices_tensor_batch = torch.zeros((batch_size, (NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2))
    adjacency_matrices = np.ndarray((batch_size, NUM_CLASSES_OUT, NUM_CLASSES_OUT))

    # Generate one batch of adjacency matrices 
    for tensor_row in range(batch_size):
        graph = generate_random_tsp_graph(NUM_CLASSES_OUT)
        adjacency_matrix = graph_to_adjacency_matrix(graph)
        adjacency_matrices[tensor_row] = torch.tensor(adjacency_matrix).view((NUM_CLASSES_OUT, NUM_CLASSES_OUT))
        
        partial_matrix = list()
        for relevant_index in relevant_indices:
            flattened_adj_matrix = [item for sublist in adjacency_matrix for item in sublist]
            partial_matrix.append(flattened_adj_matrix[relevant_index])
        
        matrices_tensor_batch[tensor_row] = torch.tensor(partial_matrix)

    # Normalize
    matrices_tensor_batch = matrices_tensor_batch / 101

    # Generate an empty sequence from a random starting point
    sequences_tensor_batch = torch.zeros((batch_size, NUM_CLASSES_OUT - 1)).long()
    sequences_tensor_batch[:, 0] = torch.tensor(np.random.randint(0, 15, size=(batch_size)))

    # Store the decision cost in each step of the way
    costs = torch.zeros((NUM_CLASSES_OUT - 2, batch_size))
    for i in range(NUM_CLASSES_OUT - 2):
        # Encode the sequence for the model
        batch_indices = torch.arange(len(sequences_tensor_batch)).view(-1, 1).expand_as(sequences_tensor_batch)
        mask = (sequences_tensor_batch == -1)

        sequences_tensor_batch = sequences_tensor_batch.masked_fill(mask, 0)

        sequence_encodings = torch.tensor(adjacency_matrices[batch_indices, sequences_tensor_batch])
        sequence_encodings = sequence_encodings.masked_fill(mask.unsqueeze(-1), 0)

        sequences_tensor_batch = sequences_tensor_batch.masked_fill(mask, -1)

        sequence_encodings = sequence_encodings / 101
        sequence_encodings[sequence_encodings != 0] -= 0.5
        
        sequence_encodings = sequence_encodings.to(torch.float32)

        outputs = model(matrices_tensor_batch, sequence_encodings)
        _, predicted_labels = torch.max(outputs, 1)
        previous_labels = sequences_tensor_batch[:, i]
        costs_this_timestep = list()
        for batch_index in range(batch_size):
            matrix = adjacency_matrices[batch_index]
            # print(len(matrix))
            # print(predicted_labels[batch_index])
            # print(previous_labels[batch_index])
            costs_this_timestep.append(matrix[predicted_labels[batch_index]][previous_labels[batch_index]])

        costs_this_timestep = torch.tensor(costs_this_timestep)
        costs[i] = costs_this_timestep

    # Calculate total cost of each path
    costs = torch.sum(costs, dim=0)

    # Return the mean value from al lthe path costs
    return torch.mean(costs).item()

# %% [markdown]
# ### Instanciamiento y loop
# La siguiente funcion instancia un modelo con los hiperparámetros pasados como argumentos, y lo entrena durante 100 épocas.
# Para ello utiliza el algoritmo de optimización Adam y la función de pérdida CrossEntropyLoss.
# Se crea un archivo de registro con los resultados del modelo en el directorio results, que contiene en el nombre los hiperparámetros usados.
# Durante la fase de evaluación, además de comprobar la precisión del modelo sobre el conjunto de test, se evalúa el coste medio en los caminos generados por este sobre un batch de ejemplos generados aleatoriamente.

# %%
def train_model(train_loader, test_loader, hyperparams, identifier, batch_size):
    num_layers = hyperparams['num_layers']
    hidden_size = hyperparams['hidden_size']
    learning_rate = hyperparams['learning_rate']
    dropout = hyperparams['dropout']
    decay = hyperparams['decay']

    # Initialize new model, optimizer and loss function
    model = HybridModel(num_layers=num_layers, hidden_size=hidden_size, dropout=dropout)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=decay)#, weight_decay=1e-5)

    # Number of epochs
    num_epochs = 100
    total_path_costs_mean = list()


    csv_file = open(f"./results/gru/{batch_size}/{identifier}.csv", mode="a", newline="")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Epoch", "Train_Accuracy", "Test_Accuracy", "Mean_Path_Cost", "Elapsed_Time"])

    # Training loop
    start_time = time.time()
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        total_samples = 0
        correct_predictions = 0

        batch_num = len(train_loader)
        for batch_idx, (sequences, batched_graph, targets) in enumerate(train_loader):
            
            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(batched_graph, sequences)
            
            # Compute the loss
            loss = criterion(outputs, targets)
            
            loss.backward()

            optimizer.step()

            # Update the training accuracy
            _, predicted_labels = torch.max(outputs, 1)
            total_samples += targets.size(0)
            correct_predictions += (predicted_labels == targets).sum().item()
        
        # Compute the training accuracy for the epoch
        accuracy = correct_predictions / total_samples

        # Evaluation phase
        model.eval()
        total_samples = 0
        correct_predictions = 0
        mean_this_epoch = 0

        with torch.no_grad():
            for sequences, batched_graph, targets in test_loader:
                # Forward pass
                outputs = model(batched_graph, sequences)

                # Update the testing accuracy
                _, predicted_labels = torch.max(outputs, 1)
                total_samples += targets.size(0)
                correct_predictions += (predicted_labels == targets).sum().item()

            # Path evaluation
            mean_this_epoch = path_evaluation(model, batch_size)
            total_path_costs_mean.append(mean_this_epoch)

        # Compute the testing accuracy for the epoch
        test_accuracy = correct_predictions / total_samples

        elapsed_time = time.time() - start_time
        csv_writer.writerow([
            epoch + 1,
            round(accuracy * 100, 4),
            round(test_accuracy * 100, 4),
            round(mean_this_epoch, 4),
            round(elapsed_time, 4)
        ])
        csv_file.flush()
        
        print(f'Epoch [{epoch + 1}/{num_epochs}]')
        print(f'Train Accuracy: {accuracy * 100:.2f}%, Testing Accuracy: {test_accuracy * 100:.2f}%')
        print(f'Path cost mean this epoch: {mean_this_epoch:.2f}, Total path cost mean : {mean(total_path_costs_mean):.2f}\n')

# %% [markdown]
# ### Grid de hiperparámetros
# En esta última función se especifican los distintos valores que tendrán los hiperparámetros del grid, y se entrena al modelo previamente definido utilizando todas las combinaciones posibles de hiperparámetros para ello.

# %%
from itertools import product

batch_sizes =  (16, 32, 64)

hyperparameter_grid = {
    'learning_rate': [0.0001, 0.0005, 0.001],
    'hidden_size': [16, 32, 64],
    'num_layers': [1, 2, 3],
    'dropout': [0.1, 0.2, 0.3],
    'decay': [1e-5, 5e-5, 1e-4]
}

for batch_size in batch_sizes:
    print('current batch size is ' + str(batch_size))

    all_combs = product(*(hyperparameter_grid[hp] for hp in hyperparameter_grid))
    for comb in all_combs:
        hyperparams = dict(zip(hyperparameter_grid.keys(), comb))

        identifier = '_'.join([f"{k}={v}" for k, v in hyperparams.items()])
        
        print(f"Training with {identifier}")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate_fn, drop_last=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn, drop_last=True)
        
        train_model(train_loader, test_loader, hyperparams, identifier, batch_size)
# Out:
# current batch size is 16
# Training with learning_rate=0.001_hidden_size=64_num_layers=3_dropout=0.2_decay=0.0001
# /tmp/ipykernel_289/1631721209.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(G).todense().tolist()
# Epoch [1/250]
# Train Accuracy: 6.34%, Testing Accuracy: 6.46%
# Path cost mean this epoch: 420.12, Total path cost mean : 420.12
#
# Epoch [2/250]
# Train Accuracy: 9.18%, Testing Accuracy: 9.32%
# Path cost mean this epoch: 335.31, Total path cost mean : 377.72
#
# Epoch [3/250]
# Train Accuracy: 14.92%, Testing Accuracy: 19.54%
# Path cost mean this epoch: 305.19, Total path cost mean : 353.54
#
# Epoch [4/250]
# Train Accuracy: 26.78%, Testing Accuracy: 28.21%
# Path cost mean this epoch: 211.44, Total path cost mean : 318.02
#
# Epoch [5/250]
# Train Accuracy: 35.07%, Testing Accuracy: 32.32%
# Path cost mean this epoch: 241.31, Total path cost mean : 302.68
#
# Epoch [6/250]
# Train Accuracy: 40.88%, Testing Accuracy: 35.54%
# Path cost mean this epoch: 227.56, Total path cost mean : 290.16
#
# Epoch [7/250]
# Train Accuracy: 45.81%, Testing Accuracy: 37.54%
# Path cost mean this epoch: 202.94, Total path cost mean : 277.70
#
# Epoch [8/250]
# Train Accuracy: 50.91%, Testing Accuracy: 39.82%
# Path cost mean this epoch: 159.69, Total path cost mean : 262.95
#
# Epoch [9/250]
# Train Accuracy: 55.98%, Testing Accuracy: 40.57%
# Path cost mean this epoch: 197.06, Total path cost mean : 255.62
#
# Epoch [10/250]
# Train Accuracy: 60.07%, Testing Accuracy: 40.75%
# Path cost mean this epoch: 222.00, Total path cost mean : 252.26
#
# Epoch [11/250]
# Train Accuracy: 64.12%, Testing Accuracy: 41.50%
# Path cost mean this epoch: 263.00, Total path cost mean : 253.24
#
# Epoch [12/250]
# Train Accuracy: 68.38%, Testing Accuracy: 42.29%
# Path cost mean this epoch: 160.56, Total path cost mean : 245.52
#
# Epoch [13/250]
# Train Accuracy: 72.41%, Testing Accuracy: 41.50%
# Path cost mean this epoch: 190.50, Total path cost mean : 241.28
#
# Epoch [14/250]
# Train Accuracy: 76.17%, Testing Accuracy: 41.46%
# Path cost mean this epoch: 211.81, Total path cost mean : 239.18
#
# Epoch [15/250]
# Train Accuracy: 79.65%, Testing Accuracy: 42.00%
# Path cost mean this epoch: 154.25, Total path cost mean : 233.52
#
# Epoch [16/250]
# Train Accuracy: 82.67%, Testing Accuracy: 41.50%
# Path cost mean this epoch: 185.12, Total path cost mean : 230.49
#
# Epoch [17/250]
# Train Accuracy: 85.99%, Testing Accuracy: 42.39%
# Path cost mean this epoch: 215.62, Total path cost mean : 229.62
#
# Epoch [18/250]
# Train Accuracy: 89.16%, Testing Accuracy: 41.32%
# Path cost mean this epoch: 208.88, Total path cost mean : 228.47
#
# Epoch [19/250]
# Train Accuracy: 91.70%, Testing Accuracy: 41.00%
# Path cost mean this epoch: 254.12, Total path cost mean : 229.82
#
# Epoch [20/250]
# Train Accuracy: 93.75%, Testing Accuracy: 40.64%
# Path cost mean this epoch: 196.19, Total path cost mean : 228.13
#
# Epoch [21/250]
# Train Accuracy: 94.88%, Testing Accuracy: 40.64%
# Path cost mean this epoch: 209.88, Total path cost mean : 227.26
#
# Epoch [22/250]
# Train Accuracy: 96.58%, Testing Accuracy: 39.82%
# Path cost mean this epoch: 192.44, Total path cost mean : 225.68
#
# Epoch [23/250]
# Train Accuracy: 97.26%, Testing Accuracy: 40.32%
# Path cost mean this epoch: 190.38, Total path cost mean : 224.15
#
# Epoch [24/250]
# Train Accuracy: 97.96%, Testing Accuracy: 40.18%
# Path cost mean this epoch: 274.31, Total path cost mean : 226.24
#
# Epoch [25/250]
# Train Accuracy: 97.96%, Testing Accuracy: 39.82%
# Path cost mean this epoch: 276.44, Total path cost mean : 228.25
#
# Epoch [26/250]
# Train Accuracy: 98.38%, Testing Accuracy: 40.25%
# Path cost mean this epoch: 214.00, Total path cost mean : 227.70
#
# Epoch [27/250]
# Train Accuracy: 97.66%, Testing Accuracy: 39.39%
# Path cost mean this epoch: 224.44, Total path cost mean : 227.58
#
# Epoch [28/250]
# Train Accuracy: 98.71%, Testing Accuracy: 40.11%
# Path cost mean this epoch: 218.88, Total path cost mean : 227.27
#
# Epoch [29/250]
# Train Accuracy: 99.36%, Testing Accuracy: 39.00%
# Path cost mean this epoch: 204.38, Total path cost mean : 226.48
#
# Epoch [30/250]
# Train Accuracy: 99.49%, Testing Accuracy: 39.82%
# Path cost mean this epoch: 196.50, Total path cost mean : 225.48
#
# Epoch [31/250]
# Train Accuracy: 95.56%, Testing Accuracy: 39.75%
# Path cost mean this epoch: 188.50, Total path cost mean : 224.28
#
# Epoch [32/250]
# Train Accuracy: 98.13%, Testing Accuracy: 39.39%
# Path cost mean this epoch: 191.12, Total path cost mean : 223.25
#
# Epoch [33/250]
# Train Accuracy: 99.42%, Testing Accuracy: 39.00%
# Path cost mean this epoch: 184.62, Total path cost mean : 222.08
#
# Epoch [34/250]
# Train Accuracy: 99.73%, Testing Accuracy: 38.43%
# Path cost mean this epoch: 275.88, Total path cost mean : 223.66
#
# Epoch [35/250]
# Train Accuracy: 99.78%, Testing Accuracy: 39.29%
# Path cost mean this epoch: 223.38, Total path cost mean : 223.65
#
# Epoch [36/250]
# Train Accuracy: 96.01%, Testing Accuracy: 38.68%
# Path cost mean this epoch: 221.81, Total path cost mean : 223.60
#
# Epoch [37/250]
# Train Accuracy: 94.95%, Testing Accuracy: 38.54%
# Path cost mean this epoch: 162.94, Total path cost mean : 221.96
#
# Epoch [38/250]
# Train Accuracy: 99.41%, Testing Accuracy: 39.79%
# Path cost mean this epoch: 238.81, Total path cost mean : 222.40
#
# Epoch [39/250]
# Train Accuracy: 99.94%, Testing Accuracy: 39.57%
# Path cost mean this epoch: 245.88, Total path cost mean : 223.01
#
# Epoch [40/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.29%
# Path cost mean this epoch: 155.69, Total path cost mean : 221.32
#
# Epoch [41/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.46%
# Path cost mean this epoch: 242.44, Total path cost mean : 221.84
#
# Epoch [42/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.39%
# Path cost mean this epoch: 248.69, Total path cost mean : 222.48
#
# Epoch [43/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.14%
# Path cost mean this epoch: 213.94, Total path cost mean : 222.28
#
# Epoch [44/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.50%
# Path cost mean this epoch: 234.88, Total path cost mean : 222.57
#
# Epoch [45/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.29%
# Path cost mean this epoch: 233.06, Total path cost mean : 222.80
#
# Epoch [46/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.14%
# Path cost mean this epoch: 177.94, Total path cost mean : 221.82
#
# Epoch [47/250]
# Train Accuracy: 100.00%, Testing Accuracy: 40.04%
# Path cost mean this epoch: 281.56, Total path cost mean : 223.09
#
# Epoch [48/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.75%
# Path cost mean this epoch: 233.88, Total path cost mean : 223.32
#
# Epoch [49/250]
# Train Accuracy: 97.49%, Testing Accuracy: 33.11%
# Path cost mean this epoch: 240.38, Total path cost mean : 223.67
#
# Epoch [50/250]
# Train Accuracy: 86.85%, Testing Accuracy: 38.21%
# Path cost mean this epoch: 207.38, Total path cost mean : 223.34
#
# Epoch [51/250]
# Train Accuracy: 98.11%, Testing Accuracy: 39.18%
# Path cost mean this epoch: 241.94, Total path cost mean : 223.71
#
# Epoch [52/250]
# Train Accuracy: 99.67%, Testing Accuracy: 38.61%
# Path cost mean this epoch: 261.38, Total path cost mean : 224.43
#
# Epoch [53/250]
# Train Accuracy: 100.00%, Testing Accuracy: 38.79%
# Path cost mean this epoch: 215.12, Total path cost mean : 224.25
#
# Epoch [54/250]
# Train Accuracy: 99.96%, Testing Accuracy: 38.39%
# Path cost mean this epoch: 276.50, Total path cost mean : 225.22
#
# Epoch [55/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.29%
# Path cost mean this epoch: 249.25, Total path cost mean : 225.66
#
# Epoch [56/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.14%
# Path cost mean this epoch: 234.19, Total path cost mean : 225.81
#
# Epoch [57/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.21%
# Path cost mean this epoch: 194.19, Total path cost mean : 225.26
#
# Epoch [58/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.32%
# Path cost mean this epoch: 223.19, Total path cost mean : 225.22
#
# Epoch [59/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.46%
# Path cost mean this epoch: 232.62, Total path cost mean : 225.35
#
# Epoch [60/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.21%
# Path cost mean this epoch: 232.56, Total path cost mean : 225.47
#
# Epoch [61/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.21%
# Path cost mean this epoch: 184.94, Total path cost mean : 224.80
#
# Epoch [62/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.00%
# Path cost mean this epoch: 211.75, Total path cost mean : 224.59
#
# Epoch [63/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.32%
# Path cost mean this epoch: 266.94, Total path cost mean : 225.26
#
# Epoch [64/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.04%
# Path cost mean this epoch: 180.06, Total path cost mean : 224.56
#
# Epoch [65/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.57%
# Path cost mean this epoch: 227.19, Total path cost mean : 224.60
#
# Epoch [66/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.07%
# Path cost mean this epoch: 247.88, Total path cost mean : 224.95
#
# Epoch [67/250]
# Train Accuracy: 100.00%, Testing Accuracy: 39.57%
# Path cost mean this epoch: 314.06, Total path cost mean : 226.28
#
# Epoch [68/250]
# Train Accuracy: 85.87%, Testing Accuracy: 37.96%
# Path cost mean this epoch: 247.56, Total path cost mean : 226.59
#
# Epoch [69/250]
# Train Accuracy: 96.58%, Testing Accuracy: 38.36%
# Path cost mean this epoch: 238.62, Total path cost mean : 226.77
#
# Epoch [70/250]
# Train Accuracy: 99.28%, Testing Accuracy: 38.93%
# Path cost mean this epoch: 232.25, Total path cost mean : 226.85
#
# Epoch [71/250]
# Train Accuracy: 99.59%, Testing Accuracy: 38.50%
# Path cost mean this epoch: 221.38, Total path cost mean : 226.77
#
# Epoch [72/250]
# Train Accuracy: 98.71%, Testing Accuracy: 38.21%
# Path cost mean this epoch: 264.56, Total path cost mean : 227.29
#
# Epoch [73/250]
# Train Accuracy: 96.46%, Testing Accuracy: 38.04%
# Path cost mean this epoch: 232.38, Total path cost mean : 227.36
#
# Epoch [74/250]
# Train Accuracy: 97.81%, Testing Accuracy: 37.32%
# Path cost mean this epoch: 233.06, Total path cost mean : 227.44
#
# Epoch [75/250]
# Train Accuracy: 98.57%, Testing Accuracy: 38.11%
# Path cost mean this epoch: 246.31, Total path cost mean : 227.69
#
# Epoch [76/250]
# Train Accuracy: 98.50%, Testing Accuracy: 37.64%
# Path cost mean this epoch: 286.06, Total path cost mean : 228.46
#
# Epoch [77/250]
# Train Accuracy: 97.78%, Testing Accuracy: 38.04%
# Path cost mean this epoch: 216.94, Total path cost mean : 228.31
#
# Epoch [78/250]
# Train Accuracy: 97.77%, Testing Accuracy: 37.21%
# Path cost mean this epoch: 260.88, Total path cost mean : 228.73
#
# Epoch [79/250]
# Train Accuracy: 98.54%, Testing Accuracy: 37.86%
# Path cost mean this epoch: 275.38, Total path cost mean : 229.32
#
# Epoch [80/250]
# Train Accuracy: 99.40%, Testing Accuracy: 38.36%
# Path cost mean this epoch: 271.50, Total path cost mean : 229.85
#
# Epoch [81/250]
# Train Accuracy: 98.23%, Testing Accuracy: 37.79%
# Path cost mean this epoch: 273.12, Total path cost mean : 230.38
#
# Epoch [82/250]
# Train Accuracy: 96.96%, Testing Accuracy: 38.25%
# Path cost mean this epoch: 253.81, Total path cost mean : 230.67
#
# Epoch [83/250]
# Train Accuracy: 98.95%, Testing Accuracy: 39.07%
# Path cost mean this epoch: 289.44, Total path cost mean : 231.37
#
# Epoch [84/250]
# Train Accuracy: 98.54%, Testing Accuracy: 38.43%
# Path cost mean this epoch: 244.94, Total path cost mean : 231.54
#
# Epoch [85/250]
# Train Accuracy: 98.76%, Testing Accuracy: 38.96%
# Path cost mean this epoch: 233.25, Total path cost mean : 231.56
#
# Epoch [86/250]
# Train Accuracy: 98.18%, Testing Accuracy: 38.57%
# Path cost mean this epoch: 273.81, Total path cost mean : 232.05
#
# Epoch [87/250]
# Train Accuracy: 98.04%, Testing Accuracy: 38.18%
# Path cost mean this epoch: 284.81, Total path cost mean : 232.65
#
# Epoch [88/250]
# Train Accuracy: 98.63%, Testing Accuracy: 38.11%
# Path cost mean this epoch: 197.62, Total path cost mean : 232.26
#
# Epoch [89/250]
# Train Accuracy: 98.75%, Testing Accuracy: 38.79%
# Path cost mean this epoch: 279.00, Total path cost mean : 232.78
#
# Epoch [90/250]
# Train Accuracy: 98.60%, Testing Accuracy: 38.86%
# Path cost mean this epoch: 154.00, Total path cost mean : 231.91
#
# Epoch [91/250]
# Train Accuracy: 98.99%, Testing Accuracy: 38.64%
# Path cost mean this epoch: 205.75, Total path cost mean : 231.62
#
# Epoch [92/250]
# Train Accuracy: 98.49%, Testing Accuracy: 37.39%
# Path cost mean this epoch: 251.19, Total path cost mean : 231.83
#
# Epoch [93/250]
# Train Accuracy: 97.06%, Testing Accuracy: 38.57%
# Path cost mean this epoch: 319.12, Total path cost mean : 232.77
#
# Epoch [94/250]
# Train Accuracy: 98.32%, Testing Accuracy: 38.25%
# Path cost mean this epoch: 201.12, Total path cost mean : 232.43
#
# Epoch [95/250]
# Train Accuracy: 99.26%, Testing Accuracy: 38.39%
# Path cost mean this epoch: 325.06, Total path cost mean : 233.41
#
# Epoch [96/250]
# Train Accuracy: 99.29%, Testing Accuracy: 38.18%
# Path cost mean this epoch: 255.38, Total path cost mean : 233.64
#
# Epoch [97/250]
# Train Accuracy: 98.59%, Testing Accuracy: 39.14%
# Path cost mean this epoch: 277.69, Total path cost mean : 234.09
#
# Epoch [98/250]
# Train Accuracy: 97.38%, Testing Accuracy: 37.82%
# Path cost mean this epoch: 175.25, Total path cost mean : 233.49
#
# Epoch [99/250]
# Train Accuracy: 97.99%, Testing Accuracy: 37.39%
# Path cost mean this epoch: 270.38, Total path cost mean : 233.86
#
# Epoch [100/250]
# Train Accuracy: 99.21%, Testing Accuracy: 38.57%
# Path cost mean this epoch: 229.50, Total path cost mean : 233.82
#
# Epoch [101/250]
# Train Accuracy: 99.18%, Testing Accuracy: 37.50%
# Path cost mean this epoch: 228.38, Total path cost mean : 233.77
#
# Epoch [102/250]
# Train Accuracy: 98.52%, Testing Accuracy: 38.29%
# Path cost mean this epoch: 299.88, Total path cost mean : 234.41
#
# Epoch [103/250]
# Train Accuracy: 98.88%, Testing Accuracy: 38.82%
# Path cost mean this epoch: 254.81, Total path cost mean : 234.61
#
# Epoch [104/250]
# Train Accuracy: 99.14%, Testing Accuracy: 38.46%
# Path cost mean this epoch: 193.12, Total path cost mean : 234.21
#
# Epoch [105/250]
# Train Accuracy: 97.25%, Testing Accuracy: 39.21%
# Path cost mean this epoch: 268.62, Total path cost mean : 234.54
#
# Epoch [106/250]
# Train Accuracy: 97.85%, Testing Accuracy: 37.18%
# Path cost mean this epoch: 113.19, Total path cost mean : 233.40
#
# Epoch [107/250]
# Train Accuracy: 98.71%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 188.25, Total path cost mean : 232.97
#
# Epoch [108/250]
# Train Accuracy: 99.14%, Testing Accuracy: 36.75%
# Path cost mean this epoch: 291.06, Total path cost mean : 233.51
#
# Epoch [109/250]
# Train Accuracy: 98.94%, Testing Accuracy: 37.82%
# Path cost mean this epoch: 117.25, Total path cost mean : 232.44
#
# Epoch [110/250]
# Train Accuracy: 99.04%, Testing Accuracy: 38.04%
# Path cost mean this epoch: 245.81, Total path cost mean : 232.57
#
# Epoch [111/250]
# Train Accuracy: 97.43%, Testing Accuracy: 38.43%
# Path cost mean this epoch: 241.12, Total path cost mean : 232.64
#
# Epoch [112/250]
# Train Accuracy: 98.50%, Testing Accuracy: 37.96%
# Path cost mean this epoch: 245.00, Total path cost mean : 232.75
#
# Epoch [113/250]
# Train Accuracy: 98.88%, Testing Accuracy: 38.21%
# Path cost mean this epoch: 239.06, Total path cost mean : 232.81
#
# Epoch [114/250]
# Train Accuracy: 98.86%, Testing Accuracy: 37.93%
# Path cost mean this epoch: 275.19, Total path cost mean : 233.18
#
# Epoch [115/250]
# Train Accuracy: 98.79%, Testing Accuracy: 38.46%
# Path cost mean this epoch: 224.31, Total path cost mean : 233.10
#
# Epoch [116/250]
# Train Accuracy: 98.22%, Testing Accuracy: 37.50%
# Path cost mean this epoch: 319.88, Total path cost mean : 233.85
#
# Epoch [117/250]
# Train Accuracy: 97.96%, Testing Accuracy: 38.46%
# Path cost mean this epoch: 244.00, Total path cost mean : 233.94
#
# Epoch [118/250]
# Train Accuracy: 98.81%, Testing Accuracy: 39.14%
# Path cost mean this epoch: 267.69, Total path cost mean : 234.23
#
# Epoch [119/250]
# Train Accuracy: 98.82%, Testing Accuracy: 38.11%
# Path cost mean this epoch: 282.00, Total path cost mean : 234.63
#
# Epoch [120/250]
# Train Accuracy: 98.43%, Testing Accuracy: 38.39%
# Path cost mean this epoch: 259.50, Total path cost mean : 234.83
#
# Epoch [121/250]
# Train Accuracy: 98.30%, Testing Accuracy: 37.46%
# Path cost mean this epoch: 267.19, Total path cost mean : 235.10
#
# Epoch [122/250]
# Train Accuracy: 99.45%, Testing Accuracy: 38.57%
# Path cost mean this epoch: 277.94, Total path cost mean : 235.45
#
# Epoch [123/250]
# Train Accuracy: 98.34%, Testing Accuracy: 35.82%
# Path cost mean this epoch: 224.00, Total path cost mean : 235.36
#
# Epoch [124/250]
# Train Accuracy: 98.35%, Testing Accuracy: 37.79%
# Path cost mean this epoch: 249.00, Total path cost mean : 235.47
#
# Epoch [125/250]
# Train Accuracy: 98.54%, Testing Accuracy: 37.07%
# Path cost mean this epoch: 331.25, Total path cost mean : 236.24
#
# Epoch [126/250]
# Train Accuracy: 98.49%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 221.69, Total path cost mean : 236.12
#
# Epoch [127/250]
# Train Accuracy: 98.71%, Testing Accuracy: 37.43%
# Path cost mean this epoch: 243.75, Total path cost mean : 236.18
#
# Epoch [128/250]
# Train Accuracy: 98.65%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 220.69, Total path cost mean : 236.06
#
# Epoch [129/250]
# Train Accuracy: 98.69%, Testing Accuracy: 37.61%
# Path cost mean this epoch: 231.88, Total path cost mean : 236.03
#
# Epoch [130/250]
# Train Accuracy: 99.04%, Testing Accuracy: 37.93%
# Path cost mean this epoch: 171.75, Total path cost mean : 235.53
#
# Epoch [131/250]
# Train Accuracy: 98.40%, Testing Accuracy: 38.18%
# Path cost mean this epoch: 264.62, Total path cost mean : 235.75
#
# Epoch [132/250]
# Train Accuracy: 97.97%, Testing Accuracy: 38.82%
# Path cost mean this epoch: 229.00, Total path cost mean : 235.70
#
# Epoch [133/250]
# Train Accuracy: 98.71%, Testing Accuracy: 37.79%
# Path cost mean this epoch: 227.44, Total path cost mean : 235.64
#
# Epoch [134/250]
# Train Accuracy: 98.98%, Testing Accuracy: 37.29%
# Path cost mean this epoch: 243.50, Total path cost mean : 235.70
#
# Epoch [135/250]
# Train Accuracy: 98.24%, Testing Accuracy: 36.82%
# Path cost mean this epoch: 183.69, Total path cost mean : 235.31
#
# Epoch [136/250]
# Train Accuracy: 98.46%, Testing Accuracy: 38.32%
# Path cost mean this epoch: 254.88, Total path cost mean : 235.46
#
# Epoch [137/250]
# Train Accuracy: 99.06%, Testing Accuracy: 37.64%
# Path cost mean this epoch: 321.31, Total path cost mean : 236.08
#
# Epoch [138/250]
# Train Accuracy: 99.62%, Testing Accuracy: 36.89%
# Path cost mean this epoch: 267.69, Total path cost mean : 236.31
#
# Epoch [139/250]
# Train Accuracy: 99.21%, Testing Accuracy: 37.18%
# Path cost mean this epoch: 263.69, Total path cost mean : 236.51
#
# Epoch [140/250]
# Train Accuracy: 96.90%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 199.62, Total path cost mean : 236.25
#
# Epoch [141/250]
# Train Accuracy: 98.25%, Testing Accuracy: 36.46%
# Path cost mean this epoch: 315.88, Total path cost mean : 236.81
#
# Epoch [142/250]
# Train Accuracy: 98.84%, Testing Accuracy: 36.82%
# Path cost mean this epoch: 212.19, Total path cost mean : 236.64
#
# Epoch [143/250]
# Train Accuracy: 99.52%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 322.69, Total path cost mean : 237.24
#
# Epoch [144/250]
# Train Accuracy: 98.90%, Testing Accuracy: 37.54%
# Path cost mean this epoch: 216.19, Total path cost mean : 237.09
#
# Epoch [145/250]
# Train Accuracy: 97.09%, Testing Accuracy: 37.57%
# Path cost mean this epoch: 254.81, Total path cost mean : 237.22
#
# Epoch [146/250]
# Train Accuracy: 98.83%, Testing Accuracy: 37.86%
# Path cost mean this epoch: 236.50, Total path cost mean : 237.21
#
# Epoch [147/250]
# Train Accuracy: 99.54%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 213.81, Total path cost mean : 237.05
#
# Epoch [148/250]
# Train Accuracy: 99.62%, Testing Accuracy: 38.04%
# Path cost mean this epoch: 216.00, Total path cost mean : 236.91
#
# Epoch [149/250]
# Train Accuracy: 97.86%, Testing Accuracy: 37.32%
# Path cost mean this epoch: 279.94, Total path cost mean : 237.20
#
# Epoch [150/250]
# Train Accuracy: 97.50%, Testing Accuracy: 37.21%
# Path cost mean this epoch: 204.12, Total path cost mean : 236.98
#
# Epoch [151/250]
# Train Accuracy: 99.10%, Testing Accuracy: 37.29%
# Path cost mean this epoch: 301.50, Total path cost mean : 237.41
#
# Epoch [152/250]
# Train Accuracy: 99.49%, Testing Accuracy: 37.39%
# Path cost mean this epoch: 231.38, Total path cost mean : 237.37
#
# Epoch [153/250]
# Train Accuracy: 99.23%, Testing Accuracy: 36.75%
# Path cost mean this epoch: 275.62, Total path cost mean : 237.62
#
# Epoch [154/250]
# Train Accuracy: 98.23%, Testing Accuracy: 36.71%
# Path cost mean this epoch: 214.38, Total path cost mean : 237.47
#
# Epoch [155/250]
# Train Accuracy: 97.78%, Testing Accuracy: 36.50%
# Path cost mean this epoch: 346.56, Total path cost mean : 238.17
#
# Epoch [156/250]
# Train Accuracy: 98.58%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 284.75, Total path cost mean : 238.47
#
# Epoch [157/250]
# Train Accuracy: 99.08%, Testing Accuracy: 36.86%
# Path cost mean this epoch: 221.00, Total path cost mean : 238.36
#
# Epoch [158/250]
# Train Accuracy: 98.99%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 199.19, Total path cost mean : 238.11
#
# Epoch [159/250]
# Train Accuracy: 98.46%, Testing Accuracy: 35.89%
# Path cost mean this epoch: 214.62, Total path cost mean : 237.96
#
# Epoch [160/250]
# Train Accuracy: 97.99%, Testing Accuracy: 36.61%
# Path cost mean this epoch: 224.81, Total path cost mean : 237.88
#
# Epoch [161/250]
# Train Accuracy: 98.34%, Testing Accuracy: 36.29%
# Path cost mean this epoch: 243.06, Total path cost mean : 237.91
#
# Epoch [162/250]
# Train Accuracy: 99.49%, Testing Accuracy: 36.29%
# Path cost mean this epoch: 242.81, Total path cost mean : 237.94
#
# Epoch [163/250]
# Train Accuracy: 99.21%, Testing Accuracy: 36.96%
# Path cost mean this epoch: 204.38, Total path cost mean : 237.74
#
# Epoch [164/250]
# Train Accuracy: 97.76%, Testing Accuracy: 37.00%
# Path cost mean this epoch: 215.81, Total path cost mean : 237.60
#
# Epoch [165/250]
# Train Accuracy: 98.42%, Testing Accuracy: 37.71%
# Path cost mean this epoch: 268.81, Total path cost mean : 237.79
#
# Epoch [166/250]
# Train Accuracy: 98.85%, Testing Accuracy: 37.75%
# Path cost mean this epoch: 228.75, Total path cost mean : 237.74
#
# Epoch [167/250]
# Train Accuracy: 99.31%, Testing Accuracy: 37.18%
# Path cost mean this epoch: 212.19, Total path cost mean : 237.58
#
# Epoch [168/250]
# Train Accuracy: 98.88%, Testing Accuracy: 37.39%
# Path cost mean this epoch: 233.44, Total path cost mean : 237.56
#
# Epoch [169/250]
# Train Accuracy: 98.62%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 278.62, Total path cost mean : 237.80
#
# Epoch [170/250]
# Train Accuracy: 98.09%, Testing Accuracy: 38.07%
# Path cost mean this epoch: 314.06, Total path cost mean : 238.25
#
# Epoch [171/250]
# Train Accuracy: 98.21%, Testing Accuracy: 38.21%
# Path cost mean this epoch: 251.69, Total path cost mean : 238.33
#
# Epoch [172/250]
# Train Accuracy: 98.98%, Testing Accuracy: 37.43%
# Path cost mean this epoch: 237.12, Total path cost mean : 238.32
#
# Epoch [173/250]
# Train Accuracy: 99.12%, Testing Accuracy: 37.68%
# Path cost mean this epoch: 199.94, Total path cost mean : 238.10
#
# Epoch [174/250]
# Train Accuracy: 99.19%, Testing Accuracy: 37.89%
# Path cost mean this epoch: 209.31, Total path cost mean : 237.93
#
# Epoch [175/250]
# Train Accuracy: 98.71%, Testing Accuracy: 36.96%
# Path cost mean this epoch: 271.62, Total path cost mean : 238.13
#
# Epoch [176/250]
# Train Accuracy: 97.71%, Testing Accuracy: 36.89%
# Path cost mean this epoch: 200.44, Total path cost mean : 237.91
#
# Epoch [177/250]
# Train Accuracy: 98.35%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 201.50, Total path cost mean : 237.71
#
# Epoch [178/250]
# Train Accuracy: 99.33%, Testing Accuracy: 36.14%
# Path cost mean this epoch: 327.69, Total path cost mean : 238.21
#
# Epoch [179/250]
# Train Accuracy: 99.44%, Testing Accuracy: 37.46%
# Path cost mean this epoch: 267.12, Total path cost mean : 238.37
#
# Epoch [180/250]
# Train Accuracy: 99.06%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 198.31, Total path cost mean : 238.15
#
# Epoch [181/250]
# Train Accuracy: 97.78%, Testing Accuracy: 36.79%
# Path cost mean this epoch: 228.25, Total path cost mean : 238.10
#
# Epoch [182/250]
# Train Accuracy: 98.23%, Testing Accuracy: 36.79%
# Path cost mean this epoch: 201.81, Total path cost mean : 237.90
#
# Epoch [183/250]
# Train Accuracy: 98.68%, Testing Accuracy: 37.46%
# Path cost mean this epoch: 237.31, Total path cost mean : 237.89
#
# Epoch [184/250]
# Train Accuracy: 99.00%, Testing Accuracy: 36.93%
# Path cost mean this epoch: 262.50, Total path cost mean : 238.03
#
# Epoch [185/250]
# Train Accuracy: 98.52%, Testing Accuracy: 37.68%
# Path cost mean this epoch: 249.88, Total path cost mean : 238.09
#
# Epoch [186/250]
# Train Accuracy: 98.83%, Testing Accuracy: 38.54%
# Path cost mean this epoch: 238.38, Total path cost mean : 238.09
#
# Epoch [187/250]
# Train Accuracy: 98.70%, Testing Accuracy: 37.54%
# Path cost mean this epoch: 264.56, Total path cost mean : 238.23
#
# Epoch [188/250]
# Train Accuracy: 99.30%, Testing Accuracy: 37.64%
# Path cost mean this epoch: 257.50, Total path cost mean : 238.34
#
# Epoch [189/250]
# Train Accuracy: 98.68%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 264.31, Total path cost mean : 238.47
#
# Epoch [190/250]
# Train Accuracy: 98.12%, Testing Accuracy: 37.21%
# Path cost mean this epoch: 270.12, Total path cost mean : 238.64
#
# Epoch [191/250]
# Train Accuracy: 98.29%, Testing Accuracy: 37.36%
# Path cost mean this epoch: 282.62, Total path cost mean : 238.87
#
# Epoch [192/250]
# Train Accuracy: 98.57%, Testing Accuracy: 37.61%
# Path cost mean this epoch: 273.12, Total path cost mean : 239.05
#
# Epoch [193/250]
# Train Accuracy: 99.29%, Testing Accuracy: 36.18%
# Path cost mean this epoch: 240.38, Total path cost mean : 239.06
#
# Epoch [194/250]
# Train Accuracy: 98.86%, Testing Accuracy: 37.36%
# Path cost mean this epoch: 189.31, Total path cost mean : 238.80
#
# Epoch [195/250]
# Train Accuracy: 98.54%, Testing Accuracy: 36.29%
# Path cost mean this epoch: 196.00, Total path cost mean : 238.58
#
# Epoch [196/250]
# Train Accuracy: 98.44%, Testing Accuracy: 36.71%
# Path cost mean this epoch: 195.25, Total path cost mean : 238.36
#
# Epoch [197/250]
# Train Accuracy: 98.76%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 262.00, Total path cost mean : 238.48
#
# Epoch [198/250]
# Train Accuracy: 99.21%, Testing Accuracy: 36.43%
# Path cost mean this epoch: 367.75, Total path cost mean : 239.13
#
# Epoch [199/250]
# Train Accuracy: 99.00%, Testing Accuracy: 36.04%
# Path cost mean this epoch: 330.31, Total path cost mean : 239.59
#
# Epoch [200/250]
# Train Accuracy: 97.72%, Testing Accuracy: 36.89%
# Path cost mean this epoch: 217.62, Total path cost mean : 239.48
#
# Epoch [201/250]
# Train Accuracy: 97.90%, Testing Accuracy: 37.50%
# Path cost mean this epoch: 184.69, Total path cost mean : 239.21
#
# Epoch [202/250]
# Train Accuracy: 98.88%, Testing Accuracy: 36.29%
# Path cost mean this epoch: 278.06, Total path cost mean : 239.40
#
# Epoch [203/250]
# Train Accuracy: 99.12%, Testing Accuracy: 36.64%
# Path cost mean this epoch: 240.38, Total path cost mean : 239.41
#
# Epoch [204/250]
# Train Accuracy: 99.44%, Testing Accuracy: 36.79%
# Path cost mean this epoch: 272.31, Total path cost mean : 239.57
#
# Epoch [205/250]
# Train Accuracy: 99.40%, Testing Accuracy: 37.00%
# Path cost mean this epoch: 211.25, Total path cost mean : 239.43
#
# Epoch [206/250]
# Train Accuracy: 97.94%, Testing Accuracy: 38.04%
# Path cost mean this epoch: 246.12, Total path cost mean : 239.46
#
# Epoch [207/250]
# Train Accuracy: 97.98%, Testing Accuracy: 37.43%
# Path cost mean this epoch: 241.19, Total path cost mean : 239.47
#
# Epoch [208/250]
# Train Accuracy: 99.19%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 208.38, Total path cost mean : 239.32
#
# Epoch [209/250]
# Train Accuracy: 99.24%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 279.31, Total path cost mean : 239.51
#
# Epoch [210/250]
# Train Accuracy: 98.85%, Testing Accuracy: 37.89%
# Path cost mean this epoch: 180.19, Total path cost mean : 239.23
#
# Epoch [211/250]
# Train Accuracy: 98.27%, Testing Accuracy: 37.86%
# Path cost mean this epoch: 229.50, Total path cost mean : 239.18
#
# Epoch [212/250]
# Train Accuracy: 98.52%, Testing Accuracy: 37.00%
# Path cost mean this epoch: 247.38, Total path cost mean : 239.22
#
# Epoch [213/250]
# Train Accuracy: 98.90%, Testing Accuracy: 37.18%
# Path cost mean this epoch: 198.12, Total path cost mean : 239.03
#
# Epoch [214/250]
# Train Accuracy: 98.65%, Testing Accuracy: 37.14%
# Path cost mean this epoch: 267.44, Total path cost mean : 239.16
#
# Epoch [215/250]
# Train Accuracy: 99.12%, Testing Accuracy: 37.36%
# Path cost mean this epoch: 354.31, Total path cost mean : 239.70
#
# Epoch [216/250]
# Train Accuracy: 99.23%, Testing Accuracy: 36.96%
# Path cost mean this epoch: 226.69, Total path cost mean : 239.64
#
# Epoch [217/250]
# Train Accuracy: 98.20%, Testing Accuracy: 36.75%
# Path cost mean this epoch: 161.62, Total path cost mean : 239.28
#
# Epoch [218/250]
# Train Accuracy: 98.54%, Testing Accuracy: 37.86%
# Path cost mean this epoch: 266.00, Total path cost mean : 239.40
#
# Epoch [219/250]
# Train Accuracy: 98.47%, Testing Accuracy: 37.00%
# Path cost mean this epoch: 213.44, Total path cost mean : 239.28
#
# Epoch [220/250]
# Train Accuracy: 98.85%, Testing Accuracy: 36.89%
# Path cost mean this epoch: 157.19, Total path cost mean : 238.91
#
# Epoch [221/250]
# Train Accuracy: 99.29%, Testing Accuracy: 37.04%
# Path cost mean this epoch: 277.00, Total path cost mean : 239.08
#
# Epoch [222/250]
# Train Accuracy: 98.91%, Testing Accuracy: 36.61%
# Path cost mean this epoch: 352.50, Total path cost mean : 239.59
#
# Epoch [223/250]
# Train Accuracy: 98.04%, Testing Accuracy: 37.00%
# Path cost mean this epoch: 260.88, Total path cost mean : 239.69
#
# Epoch [224/250]
# Train Accuracy: 98.62%, Testing Accuracy: 36.68%
# Path cost mean this epoch: 286.19, Total path cost mean : 239.89
#
# Epoch [225/250]
# Train Accuracy: 99.10%, Testing Accuracy: 37.68%
# Path cost mean this epoch: 272.56, Total path cost mean : 240.04
#
# Epoch [226/250]
# Train Accuracy: 98.84%, Testing Accuracy: 37.07%
# Path cost mean this epoch: 338.88, Total path cost mean : 240.48
#
# Epoch [227/250]
# Train Accuracy: 98.45%, Testing Accuracy: 36.29%
# Path cost mean this epoch: 236.44, Total path cost mean : 240.46
#
# Epoch [228/250]
# Train Accuracy: 98.54%, Testing Accuracy: 37.18%
# Path cost mean this epoch: 206.25, Total path cost mean : 240.31
#
# Epoch [229/250]
# Train Accuracy: 99.18%, Testing Accuracy: 37.25%
# Path cost mean this epoch: 198.94, Total path cost mean : 240.13
#
# Epoch [230/250]
# Train Accuracy: 98.66%, Testing Accuracy: 36.86%
# Path cost mean this epoch: 244.19, Total path cost mean : 240.15
#
# Epoch [231/250]
# Train Accuracy: 98.62%, Testing Accuracy: 36.75%
# Path cost mean this epoch: 270.50, Total path cost mean : 240.28
#
# Epoch [232/250]
# Train Accuracy: 98.61%, Testing Accuracy: 36.82%
# Path cost mean this epoch: 222.81, Total path cost mean : 240.20
#
# Epoch [233/250]
# Train Accuracy: 99.19%, Testing Accuracy: 36.54%
# Path cost mean this epoch: 266.50, Total path cost mean : 240.32
#
# Epoch [234/250]
# Train Accuracy: 98.11%, Testing Accuracy: 36.46%
# Path cost mean this epoch: 280.38, Total path cost mean : 240.49
#
# Epoch [235/250]
# Train Accuracy: 98.41%, Testing Accuracy: 36.93%
# Path cost mean this epoch: 294.06, Total path cost mean : 240.71
#
# Epoch [236/250]
# Train Accuracy: 99.22%, Testing Accuracy: 37.11%
# Path cost mean this epoch: 308.94, Total path cost mean : 241.00
#
# Epoch [237/250]
# Train Accuracy: 99.05%, Testing Accuracy: 37.79%
# Path cost mean this epoch: 247.69, Total path cost mean : 241.03
#
# Epoch [238/250]
# Train Accuracy: 98.07%, Testing Accuracy: 36.71%
# Path cost mean this epoch: 202.44, Total path cost mean : 240.87
#
# Epoch [239/250]
# Train Accuracy: 97.96%, Testing Accuracy: 37.54%
# Path cost mean this epoch: 259.31, Total path cost mean : 240.95
#
# Epoch [240/250]
# Train Accuracy: 98.92%, Testing Accuracy: 37.64%
# Path cost mean this epoch: 305.44, Total path cost mean : 241.22
#
# Epoch [241/250]
# Train Accuracy: 99.66%, Testing Accuracy: 37.36%
# Path cost mean this epoch: 269.62, Total path cost mean : 241.33
#
# Epoch [242/250]
# Train Accuracy: 99.48%, Testing Accuracy: 37.71%
# Path cost mean this epoch: 290.44, Total path cost mean : 241.54
#
# Epoch [243/250]
# Train Accuracy: 98.27%, Testing Accuracy: 37.32%
# Path cost mean this epoch: 257.69, Total path cost mean : 241.60
#
# Epoch [244/250]
# Train Accuracy: 97.39%, Testing Accuracy: 37.07%
# Path cost mean this epoch: 315.56, Total path cost mean : 241.91
#
# Epoch [245/250]
# Train Accuracy: 99.00%, Testing Accuracy: 36.32%
# Path cost mean this epoch: 193.50, Total path cost mean : 241.71
#
# Epoch [246/250]
# Train Accuracy: 99.22%, Testing Accuracy: 37.86%
# Path cost mean this epoch: 196.12, Total path cost mean : 241.52
#
# Epoch [247/250]
# Train Accuracy: 99.10%, Testing Accuracy: 35.75%
# Path cost mean this epoch: 170.88, Total path cost mean : 241.24
#
# Epoch [248/250]
# Train Accuracy: 98.22%, Testing Accuracy: 37.43%
# Path cost mean this epoch: 253.50, Total path cost mean : 241.29
#
# Epoch [249/250]
# Train Accuracy: 98.44%, Testing Accuracy: 35.68%
# Path cost mean this epoch: 262.44, Total path cost mean : 241.37
#
# Epoch [250/250]
# Train Accuracy: 98.72%, Testing Accuracy: 36.11%
# Path cost mean this epoch: 308.56, Total path cost mean : 241.64
