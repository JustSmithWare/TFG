# %% [markdown]
# ### Importación de los módulos

# %% [markdown]
# Se importan los módulos necesarios para el entrenamiento del modelo de control

# %%
import pandas as pd
import torch
import dgl
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import dgl.nn as dglnn
from sklearn.model_selection import train_test_split
import networkx as nx
import random
from statistics import mean
import csv
import time
from torch.utils.data import Dataset, DataLoader
from itertools import product

# %% [markdown]
# ### Función de generación de grafo aleatorio

# %% [markdown]
# Esta función genera un grafo completo ponderado con pesos aleatorios usado en lso ejemplos de la evaluación del coste medio de los caminos generados por el modelo

# %%
def generate_random_tsp_graph(n_cities, min_distance=1, max_distance=100):
    G = nx.Graph()
    for i in range(n_cities):
        G.add_node(i)

    for i in range(n_cities):
        for j in range(i+1, n_cities):
            distance = random.randint(min_distance, max_distance)
            G.add_edge(i, j, weight=distance)

    return G

def graph_to_adjacency_matrix(G):
    return nx.adjacency_matrix(G).todense().tolist()

# %% [markdown]
# Se definen las constantes como el número de clases de la predicción y la longitud de las secuencias.
# Se lee el dataset previamente generado en `dataset_generation_processing.ipynb`

# %%
SEQUENCE_LENGTH = 14
NUM_CLASSES_OUT = 15

# %%
df = pd.read_csv('dataset_full_adj_matrix_15_nodes_stock.csv')

# %% [markdown]
# ### Función usada para obtener los índices no redundantes de una matriz de adyacencia de tamaño NxN

# %% [markdown]
# La función lista los índices de los coeficientes situados bajo la diagonal principal de una matriz

# %%
def below_diagonal_indices(n):
    # List to store the indices of elements below the diagonal
    indices = []

    # Loop through each row
    for i in range(1, n):  # Start from 1 because the first row does not have any elements below the diagonal
        # Loop through each column up to (but not including) the diagonal
        for j in range(i):
            # Compute the index in the flattened matrix and add to the list
            index = i * n + j
            indices.append(index)

    return indices

# %% [markdown]
# ### Obtención de la matriz de adyacencia a partir del dataset
#
# Se leen los coeficientes y se convierten en un tensor que contiene 14000 ejemplos de matrices.

# %%
selected_columns = ['col_' + str(i) for i in range(1, NUM_CLASSES_OUT**2 + 1)]
selected_data = df[selected_columns]

numpy_array = selected_data.values
tensor = torch.tensor(numpy_array).view(df.shape[0], NUM_CLASSES_OUT, NUM_CLASSES_OUT)
adjacency_matrices = tensor
adjacency_matrices.shape
# Out:
# torch.Size([14000, 15, 15])

# %% [markdown]
# Se utiliza la función descrita con anterioridad para obtener los coeficientes bajo la diagonal principal de cada matriz de adyacencia del tesnor.
# Cada matriz de 15x15 genera 105 predictores correspondientes a los coeficientes no repetidos.

# %%
relevant_indices = below_diagonal_indices(NUM_CLASSES_OUT)
flat_matrices = torch.zeros((df.shape[0], (NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2))
for i in range(df.shape[0]):
    for index, j in enumerate(relevant_indices):
        flat_matrices[i][index] = df[f'col_{j+1}'][i]

# %% [markdown]
# ### Normalización de las matrices de adyacencia
#
# Se normalizan los coeficientes de las matrices entre -0.5 y 0.5

# %%
flat_matrices = flat_matrices / 101
flat_matrices
# Out:
# tensor([[0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         [0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         [0.9010, 0.5842, 0.9208,  ..., 0.7129, 0.3960, 0.9010],
#         ...,
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307],
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307],
#         [0.7723, 0.1683, 0.4851,  ..., 0.7822, 0.8812, 0.9307]])

# %%
graph_indices = flat_matrices
graph_indices = graph_indices - 0.5
graph_indices.shape
# Out:
# torch.Size([14000, 105])

# %% [markdown]
# ### Obtención de las secuencias de nodos
# Se obtienen los caminos parciales que componen la parte secuencial de los problemas de clasificación, se leen del dataframe y se convierten en enteros.
# Se forma un tensor de 14.000 ejemplos con las secuencias obtenidas.

# %%
sequence_tensor = torch.zeros((df.shape[0], NUM_CLASSES_OUT - 1))
for i in range(df.shape[0]):
    for j in range(SEQUENCE_LENGTH):
        sequence_tensor[i][j] = df[f'seq_{j+1}'][i]

sequence_tensor = sequence_tensor.long()
sequence_tensor
# Out:
# tensor([[ 0, -1, -1,  ..., -1, -1, -1],
#         [ 0, 12, -1,  ..., -1, -1, -1],
#         [ 0, 12,  4,  ..., -1, -1, -1],
#         ...,
#         [ 0,  2, 10,  ...,  7, -1, -1],
#         [ 0,  2, 10,  ...,  7, 14, -1],
#         [ 0,  2, 10,  ...,  7, 14,  8]])

# %% [markdown]
# ### Codificación de las secuencias
# Se utiliza una combinación de advanced indexing y tensores booleanos (masks) para codificar cada elemento (nodo) de la secuencia con su fila correspondiente en la matriz de adyacencia del ejemplo (grafo) en el que aparece.

# %%
batch_indices = torch.arange(len(sequence_tensor)).view(-1, 1).expand_as(sequence_tensor)
mask = (sequence_tensor == -1)

sequence_tensor = sequence_tensor.masked_fill(mask, 0)

sequence_encodings = adjacency_matrices[batch_indices, sequence_tensor]
sequence_encodings = sequence_encodings.masked_fill(mask.unsqueeze(-1), 0)

sequence_tensor = sequence_tensor.masked_fill(mask, -1)

# %%
sequence_encodings = sequence_encodings / 101
sequence_encodings[sequence_encodings != 0] -= 0.5

# %% [markdown]
# ### Extracción de los objetivos
# Se crea un tensor leyendo los objetivos almacenados en el dataset.

# %%
targets_tensor = torch.tensor(df['next_node'])
targets_tensor.shape
# Out:
# torch.Size([14000])

# %% [markdown]
# ### Definicion del modelo
# El modelo RNN consiste en:
# 1. Una capa Linear que procesa los coeficientes de las matrices de adyacencia.
# 2. Una capa Red Neuronal Recurrente de la clase RNN de Pytorch que procesa las secuencias de nodos que componen los caminos parciales.
# 3. Una capa Linear que toma las salidas de las capas anteriores como entrada y devuelve la clasificación final.

# %%
class HybridModel(nn.Module):
    def __init__(self, hidden_size, num_layers, dropout):
        super(HybridModel, self).__init__()

        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # Adjacency matrix processing layer
        self.matrix_proc = nn.Linear((NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2, NUM_CLASSES_OUT)
        
        # Recurrent Neural Network (RNN)
        self.rnn = nn.RNN(input_size=NUM_CLASSES_OUT, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, dropout=dropout)# , dropout=0.1)

        # Fully Connected Layer
        self.fc = nn.Linear(NUM_CLASSES_OUT + hidden_size, NUM_CLASSES_OUT)

    def forward(self, flat_matrix, sequence_encoding):
        # Process adjacency matrix through Adjacency matrix processing layer
        matrix_out = self.matrix_proc(flat_matrix)

        # Process input through RNN
        rnn_output, _ = self.rnn(sequence_encoding)  # [batch_size, seq_len, num_classes]
        rnn_output = rnn_output[:, -1, :]

        # Concatenate outputs from adjacency matrix and RNN
        concat_output = torch.cat((matrix_out, rnn_output), dim=1)
        
        # Feed concatenated output through Fully Connected Layer
        out = self.fc(concat_output)
        return out

# %% [markdown]
# ### Dataset & Dataloader
# Se crea una clase hija de la clase Dataset de Pytorch para almacenar los datos.
# Esto permite mayor flexibilidad para situar la codificación de los datos en distintas partes del código y ha sido extremadamente útil durante el desarrollo de este trabajo.
# Actualmente la implementación del experimento podría hacerse con la clase Dataset directamente pero se deja implementada esta clase por si fuese útil para la continuación futura de la investigación.

# %%
class CustomGraphSequenceDataset(Dataset):
    def __init__(self, sequence_tensor, adj_matrices, targets_tensor):
        self.sequence_tensor = sequence_tensor
        self.adj_matrices = adj_matrices
        self.targets_tensor = targets_tensor

    def __len__(self):
        return len(self.sequence_tensor)

    def __getitem__(self, idx):
        sequence = self.sequence_tensor[idx]
        adj_matrix = self.adj_matrices[idx]
        target = self.targets_tensor[idx]
        return sequence, adj_matrix, target

# %% [markdown]
# De forma similar a la clase anterior, esta función collate personalizada es extremadamente útil a la hora de hacer pruebas con las diversas posibilidades para transformar los grupos de ejemplos en batches.
# Queda en el código por si viese más utilidad en la investigación futura, a pesar de que actualmente los scripts funcionarían con la función collate por defecto de pytorch.

# %%
def custom_collate_fn(batch):
    sequences, graphs, targets = zip(*batch)
    # Convert sequences to a single tensor
    sequences = torch.stack(sequences)
    # Convert targets to a single tensor
    targets = torch.stack(targets)
    # Batch graphs into a single graph
    batched_graph = torch.stack(graphs) # dgl.batch(graphs)
    return sequences, batched_graph, targets

# %% [markdown]
# ### Train Test split
# Se dividen las codificaciones de las secuencias, las matrices de adyacencia y los objetivos entre conjuntos de entrenamiento y validación.
# Se crean los datasets de entrenamiento y test a partir de los tensores resultantes.

# %%
# Split the data into training and testing sets (80% train, 20% test)
train_sequences, test_sequences, train_adj_matrices, test_adj_matrices, train_targets, test_targets = train_test_split(
    sequence_encodings, graph_indices, targets_tensor, test_size=0.2, random_state=42)

# %%
# Create Custom Dataset for train and test
train_dataset = CustomGraphSequenceDataset(train_sequences, train_adj_matrices, train_targets)
test_dataset = CustomGraphSequenceDataset(test_sequences, test_adj_matrices, test_targets)

# %% [markdown]
# ### Evaluación del coste medio de los caminos
# Esta función recibe un modelo como parámetro y se ejecuta durante la fase de evaluación para calcular el coste medio del camino generado por este modelo.
#
# Esta función genera un batch de grafos completos ponderados con pesos aleatorios.
# Una vez generados, se obtienen las matrices de adyacencia correspondientes a los grafos y se procesan sus coeficientes tal como se hace en el apartado anterior (Obtención de la matriz de adyacencia a partir del dataset)..
#
# Se generan tensores correspondientes a secuencias de nodos vacías (todas tienen 0 como nodo inicial como en los ejemplos del dataset).
# Se codifican dichas secuencias y se generan los elementos siguientes a partir de predicciones del modelo.

# %%
def path_evaluation(model, batch_size):
    matrices_tensor_batch = torch.zeros((batch_size, (NUM_CLASSES_OUT**2 - NUM_CLASSES_OUT) // 2))
    adjacency_matrices = np.ndarray((batch_size, NUM_CLASSES_OUT, NUM_CLASSES_OUT))

    # Generate one batch of adjacency matrices 
    for tensor_row in range(batch_size):
        graph = generate_random_tsp_graph(NUM_CLASSES_OUT)
        adjacency_matrix = graph_to_adjacency_matrix(graph)
        adjacency_matrices[tensor_row] = torch.tensor(adjacency_matrix).view((NUM_CLASSES_OUT, NUM_CLASSES_OUT))
        
        partial_matrix = list()
        for relevant_index in relevant_indices:
            flattened_adj_matrix = [item for sublist in adjacency_matrix for item in sublist]
            partial_matrix.append(flattened_adj_matrix[relevant_index])
        
        matrices_tensor_batch[tensor_row] = torch.tensor(partial_matrix)

    # Normalize
    matrices_tensor_batch = matrices_tensor_batch / 101

    # Generate an empty sequence from a random starting point
    sequences_tensor_batch = torch.zeros((batch_size, NUM_CLASSES_OUT - 1)).long()
    sequences_tensor_batch[:, 0] = torch.tensor(np.random.randint(0, 15, size=(batch_size)))

    # Store the decision cost in each step of the way
    costs = torch.zeros((NUM_CLASSES_OUT - 2, batch_size))
    for i in range(NUM_CLASSES_OUT - 2):
        # Encode the sequence for the model
        batch_indices = torch.arange(len(sequences_tensor_batch)).view(-1, 1).expand_as(sequences_tensor_batch)
        mask = (sequences_tensor_batch == -1)

        sequences_tensor_batch = sequences_tensor_batch.masked_fill(mask, 0)

        sequence_encodings = torch.tensor(adjacency_matrices[batch_indices, sequences_tensor_batch])
        sequence_encodings = sequence_encodings.masked_fill(mask.unsqueeze(-1), 0)

        sequences_tensor_batch = sequences_tensor_batch.masked_fill(mask, -1)

        sequence_encodings = sequence_encodings / 101
        sequence_encodings[sequence_encodings != 0] -= 0.5
        
        sequence_encodings = sequence_encodings.to(torch.float32)

        outputs = model(matrices_tensor_batch, sequence_encodings)
        _, predicted_labels = torch.max(outputs, 1)
        previous_labels = sequences_tensor_batch[:, i]
        costs_this_timestep = list()
        for batch_index in range(batch_size):
            matrix = adjacency_matrices[batch_index]
            # print(len(matrix))
            # print(predicted_labels[batch_index])
            # print(previous_labels[batch_index])
            costs_this_timestep.append(matrix[predicted_labels[batch_index]][previous_labels[batch_index]])

        costs_this_timestep = torch.tensor(costs_this_timestep)
        costs[i] = costs_this_timestep

    # Calculate total cost of each path
    costs = torch.sum(costs, dim=0)

    # Return the mean value from all the path costs
    return torch.mean(costs).item()

# %% [markdown]
# ### Instanciamiento y loop
# La siguiente funcion instancia un modelo con los hiperparámetros pasados como argumentos, y lo entrena durante 100 épocas.
# Para ello utiliza el algoritmo de optimización Adam y la función de pérdida CrossEntropyLoss.
# Se crea un archivo de registro con los resultados del modelo en el directorio results, que contiene en el nombre los hiperparámetros usados.
# Durante la fase de evaluación, además de comprobar la precisión del modelo sobre el conjunto de test, se evalúa el coste medio en los caminos generados por este sobre un batch de ejemplos generados aleatoriamente.

# %%
def train_model(train_loader, test_loader, hyperparams, identifier, batch_size):
    num_layers = hyperparams['num_layers']
    hidden_size = hyperparams['hidden_size']
    learning_rate = hyperparams['learning_rate']
    dropout = hyperparams['dropout']
    decay = hyperparams['decay']


    # Initialize new model, optimizer and loss function
    model = HybridModel(num_layers=num_layers, hidden_size=hidden_size, dropout=dropout)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=decay)#, weight_decay=1e-5)

    # Number of epochs
    num_epochs = 100
    total_path_costs_mean = list()


    csv_file = open(f"./results/rnn/{batch_size}/{identifier}.csv", mode="a", newline="")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Epoch", "Train_Accuracy", "Test_Accuracy", "Mean_Path_Cost", "Elapsed_Time"])

    # Training loop
    start_time = time.time()
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        total_samples = 0
        correct_predictions = 0

        batch_num = len(train_loader)
        for batch_idx, (sequences, batched_graph, targets) in enumerate(train_loader):
            
            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(batched_graph, sequences)
            
            # Compute the loss
            loss = criterion(outputs, targets)
            
            loss.backward()

            optimizer.step()

            # Update the training accuracy
            _, predicted_labels = torch.max(outputs, 1)
            total_samples += targets.size(0)
            correct_predictions += (predicted_labels == targets).sum().item()
        
        # Compute the training accuracy for the epoch
        accuracy = correct_predictions / total_samples

        # Evaluation phase
        model.eval()
        total_samples = 0
        correct_predictions = 0
        mean_this_epoch = 0

        with torch.no_grad():
            for sequences, batched_graph, targets in test_loader:
                # Forward pass
                outputs = model(batched_graph, sequences)

                # Update the testing accuracy
                _, predicted_labels = torch.max(outputs, 1)
                total_samples += targets.size(0)
                correct_predictions += (predicted_labels == targets).sum().item()

            # Path evaluation
            mean_this_epoch = path_evaluation(model, batch_size)
            total_path_costs_mean.append(mean_this_epoch)

        # Compute the testing accuracy for the epoch
        test_accuracy = correct_predictions / total_samples

        elapsed_time = time.time() - start_time
        csv_writer.writerow([
            epoch + 1,
            round(accuracy * 100, 4),
            round(test_accuracy * 100, 4),
            round(mean_this_epoch, 4),
            round(elapsed_time, 4)
        ])
        csv_file.flush()
        
        print(f'Epoch [{epoch + 1}/{num_epochs}]')
        print(f'Train Accuracy: {accuracy * 100:.2f}%, Testing Accuracy: {test_accuracy * 100:.2f}%')
        print(f'Path cost mean this epoch: {mean_this_epoch:.2f}, Total path cost mean : {mean(total_path_costs_mean):.2f}\n')

# %% [markdown]
# ### Grid de hiperparámetros
# En esta última función se especifican los distintos valores que tendrán los hiperparámetros del grid, y se entrena al modelo previamente definido utilizando todas las combinaciones posibles de hiperparámetros para ello.

# %%
batch_sizes =  (16, 32, 64)

hyperparameter_grid = {
    'learning_rate': [0.0001, 0.0005, 0.001],
    'hidden_size': [16, 32, 64],
    'num_layers': [1, 2, 3],
    'dropout': [0.1, 0.2, 0.3],
    'decay': [1e-5, 5e-5, 1e-4]
}

for batch_size in batch_sizes:
    print('current batch size is ' + str(batch_size))

    all_combs = product(*(hyperparameter_grid[hp] for hp in hyperparameter_grid))
    for comb in all_combs:
        hyperparams = dict(zip(hyperparameter_grid.keys(), comb))

        identifier = '_'.join([f"{k}={v:.0e}" if k == 'decay' else f"{k}={v}" for k, v in hyperparams.items()])    
            
        print(f"Training with {identifier}")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate_fn, drop_last=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn, drop_last=True)
        
        train_model(train_loader, test_loader, hyperparams, identifier, batch_size)
# Out:
# current batch size is 64
# Training with learning_rate=0.0005_hidden_size=64_num_layers=2_dropout=0_decay=0e+00
# /tmp/ipykernel_462/1631721209.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(G).todense().tolist()
# Epoch [1/250]
# Train Accuracy: 6.84%, Testing Accuracy: 6.98%
# Path cost mean this epoch: 482.50, Total path cost mean : 482.50
#
# Epoch [2/250]
# Train Accuracy: 7.25%, Testing Accuracy: 7.85%
# Path cost mean this epoch: 375.72, Total path cost mean : 429.11
#
# Epoch [3/250]
# Train Accuracy: 7.64%, Testing Accuracy: 6.72%
# Path cost mean this epoch: 394.92, Total path cost mean : 417.71
#
# Epoch [4/250]
# Train Accuracy: 8.96%, Testing Accuracy: 7.38%
# Path cost mean this epoch: 323.28, Total path cost mean : 394.11
#
# Epoch [5/250]
# Train Accuracy: 9.28%, Testing Accuracy: 7.81%
# Path cost mean this epoch: 322.97, Total path cost mean : 379.88
#
# Epoch [6/250]
# Train Accuracy: 9.92%, Testing Accuracy: 7.70%
# Path cost mean this epoch: 321.56, Total path cost mean : 370.16
#
# Epoch [7/250]
# Train Accuracy: 10.46%, Testing Accuracy: 8.43%
# Path cost mean this epoch: 277.81, Total path cost mean : 356.97
#
# Epoch [8/250]
# Train Accuracy: 10.97%, Testing Accuracy: 8.94%
# Path cost mean this epoch: 280.36, Total path cost mean : 347.39
#
# Epoch [9/250]
# Train Accuracy: 11.40%, Testing Accuracy: 9.23%
# Path cost mean this epoch: 261.38, Total path cost mean : 337.83
#
# Epoch [10/250]
# Train Accuracy: 12.46%, Testing Accuracy: 9.27%
# Path cost mean this epoch: 223.72, Total path cost mean : 326.42
#
# Epoch [11/250]
# Train Accuracy: 12.67%, Testing Accuracy: 9.77%
# Path cost mean this epoch: 215.19, Total path cost mean : 316.31
#
# Epoch [12/250]
# Train Accuracy: 13.70%, Testing Accuracy: 10.54%
# Path cost mean this epoch: 260.03, Total path cost mean : 311.62
#
# Epoch [13/250]
# Train Accuracy: 14.74%, Testing Accuracy: 11.26%
# Path cost mean this epoch: 247.09, Total path cost mean : 306.66
#
# Epoch [14/250]
# Train Accuracy: 15.41%, Testing Accuracy: 11.77%
# Path cost mean this epoch: 234.59, Total path cost mean : 301.51
#
# Epoch [15/250]
# Train Accuracy: 17.07%, Testing Accuracy: 13.92%
# Path cost mean this epoch: 246.69, Total path cost mean : 297.85
#
# Epoch [16/250]
# Train Accuracy: 18.15%, Testing Accuracy: 14.93%
# Path cost mean this epoch: 235.02, Total path cost mean : 293.93
#
# Epoch [17/250]
# Train Accuracy: 19.14%, Testing Accuracy: 15.92%
# Path cost mean this epoch: 219.89, Total path cost mean : 289.57
#
# Epoch [18/250]
# Train Accuracy: 19.97%, Testing Accuracy: 15.26%
# Path cost mean this epoch: 260.95, Total path cost mean : 287.98
#
# Epoch [19/250]
# Train Accuracy: 21.21%, Testing Accuracy: 15.92%
# Path cost mean this epoch: 261.45, Total path cost mean : 286.59
#
# Epoch [20/250]
# Train Accuracy: 22.06%, Testing Accuracy: 16.82%
# Path cost mean this epoch: 244.28, Total path cost mean : 284.47
#
# Epoch [21/250]
# Train Accuracy: 22.99%, Testing Accuracy: 17.33%
# Path cost mean this epoch: 242.08, Total path cost mean : 282.45
#
# Epoch [22/250]
# Train Accuracy: 23.80%, Testing Accuracy: 17.95%
# Path cost mean this epoch: 238.17, Total path cost mean : 280.44
#
# Epoch [23/250]
# Train Accuracy: 24.61%, Testing Accuracy: 17.88%
# Path cost mean this epoch: 281.31, Total path cost mean : 280.48
#
# Epoch [24/250]
# Train Accuracy: 25.47%, Testing Accuracy: 19.15%
# Path cost mean this epoch: 229.55, Total path cost mean : 278.35
#
# Epoch [25/250]
# Train Accuracy: 26.71%, Testing Accuracy: 19.73%
# Path cost mean this epoch: 257.66, Total path cost mean : 277.53
#
# Epoch [26/250]
# Train Accuracy: 27.25%, Testing Accuracy: 20.42%
# Path cost mean this epoch: 233.39, Total path cost mean : 275.83
#
# Epoch [27/250]
# Train Accuracy: 28.46%, Testing Accuracy: 21.55%
# Path cost mean this epoch: 225.64, Total path cost mean : 273.97
#
# Epoch [28/250]
# Train Accuracy: 28.92%, Testing Accuracy: 21.37%
# Path cost mean this epoch: 244.12, Total path cost mean : 272.90
#
# Epoch [29/250]
# Train Accuracy: 29.43%, Testing Accuracy: 21.73%
# Path cost mean this epoch: 234.53, Total path cost mean : 271.58
#
# Epoch [30/250]
# Train Accuracy: 30.35%, Testing Accuracy: 22.17%
# Path cost mean this epoch: 231.08, Total path cost mean : 270.23
#
# Epoch [31/250]
# Train Accuracy: 31.08%, Testing Accuracy: 22.42%
# Path cost mean this epoch: 233.53, Total path cost mean : 269.05
#
# Epoch [32/250]
# Train Accuracy: 31.61%, Testing Accuracy: 23.04%
# Path cost mean this epoch: 265.66, Total path cost mean : 268.94
#
# Epoch [33/250]
# Train Accuracy: 32.44%, Testing Accuracy: 22.86%
# Path cost mean this epoch: 246.36, Total path cost mean : 268.26
#
# Epoch [34/250]
# Train Accuracy: 32.76%, Testing Accuracy: 22.46%
# Path cost mean this epoch: 237.45, Total path cost mean : 267.35
#
# Epoch [35/250]
# Train Accuracy: 33.21%, Testing Accuracy: 22.78%
# Path cost mean this epoch: 247.33, Total path cost mean : 266.78
#
# Epoch [36/250]
# Train Accuracy: 33.52%, Testing Accuracy: 23.22%
# Path cost mean this epoch: 224.91, Total path cost mean : 265.62
#
# Epoch [37/250]
# Train Accuracy: 33.90%, Testing Accuracy: 23.40%
# Path cost mean this epoch: 221.20, Total path cost mean : 264.42
#
# Epoch [38/250]
# Train Accuracy: 33.92%, Testing Accuracy: 23.26%
# Path cost mean this epoch: 237.41, Total path cost mean : 263.70
#
# Epoch [39/250]
# Train Accuracy: 35.50%, Testing Accuracy: 23.29%
# Path cost mean this epoch: 231.80, Total path cost mean : 262.89
#
# Epoch [40/250]
# Train Accuracy: 35.55%, Testing Accuracy: 23.76%
# Path cost mean this epoch: 213.42, Total path cost mean : 261.65
#
# Epoch [41/250]
# Train Accuracy: 35.79%, Testing Accuracy: 23.36%
# Path cost mean this epoch: 239.95, Total path cost mean : 261.12
#
# Epoch [42/250]
# Train Accuracy: 35.72%, Testing Accuracy: 24.02%
# Path cost mean this epoch: 220.36, Total path cost mean : 260.15
#
# Epoch [43/250]
# Train Accuracy: 36.61%, Testing Accuracy: 22.86%
# Path cost mean this epoch: 219.44, Total path cost mean : 259.20
#
# Epoch [44/250]
# Train Accuracy: 37.38%, Testing Accuracy: 23.84%
# Path cost mean this epoch: 242.61, Total path cost mean : 258.83
#
# Epoch [45/250]
# Train Accuracy: 37.02%, Testing Accuracy: 24.49%
# Path cost mean this epoch: 229.58, Total path cost mean : 258.18
#
# Epoch [46/250]
# Train Accuracy: 37.54%, Testing Accuracy: 23.51%
# Path cost mean this epoch: 251.81, Total path cost mean : 258.04
#
# Epoch [47/250]
# Train Accuracy: 37.28%, Testing Accuracy: 24.20%
# Path cost mean this epoch: 246.30, Total path cost mean : 257.79
#
# Epoch [48/250]
# Train Accuracy: 37.93%, Testing Accuracy: 24.53%
# Path cost mean this epoch: 222.47, Total path cost mean : 257.05
#
# Epoch [49/250]
# Train Accuracy: 38.88%, Testing Accuracy: 24.96%
# Path cost mean this epoch: 254.53, Total path cost mean : 257.00
#
# Epoch [50/250]
# Train Accuracy: 38.49%, Testing Accuracy: 23.91%
# Path cost mean this epoch: 207.92, Total path cost mean : 256.02
#
# Epoch [51/250]
# Train Accuracy: 39.21%, Testing Accuracy: 24.13%
# Path cost mean this epoch: 217.45, Total path cost mean : 255.26
#
# Epoch [52/250]
# Train Accuracy: 39.37%, Testing Accuracy: 23.91%
# Path cost mean this epoch: 266.44, Total path cost mean : 255.48
#
# Epoch [53/250]
# Train Accuracy: 39.61%, Testing Accuracy: 24.71%
# Path cost mean this epoch: 265.88, Total path cost mean : 255.67
#
# Epoch [54/250]
# Train Accuracy: 40.35%, Testing Accuracy: 24.78%
# Path cost mean this epoch: 238.33, Total path cost mean : 255.35
#
# Epoch [55/250]
# Train Accuracy: 40.66%, Testing Accuracy: 24.78%
# Path cost mean this epoch: 253.86, Total path cost mean : 255.33
#
# Epoch [56/250]
# Train Accuracy: 41.00%, Testing Accuracy: 24.78%
# Path cost mean this epoch: 238.09, Total path cost mean : 255.02
#
# Epoch [57/250]
# Train Accuracy: 40.74%, Testing Accuracy: 23.95%
# Path cost mean this epoch: 246.02, Total path cost mean : 254.86
#
# Epoch [58/250]
# Train Accuracy: 41.43%, Testing Accuracy: 23.91%
# Path cost mean this epoch: 234.56, Total path cost mean : 254.51
#
# Epoch [59/250]
# Train Accuracy: 41.95%, Testing Accuracy: 24.89%
# Path cost mean this epoch: 216.73, Total path cost mean : 253.87
#
# Epoch [60/250]
# Train Accuracy: 42.03%, Testing Accuracy: 23.84%
# Path cost mean this epoch: 219.03, Total path cost mean : 253.29
#
# Epoch [61/250]
# Train Accuracy: 42.02%, Testing Accuracy: 24.71%
# Path cost mean this epoch: 209.73, Total path cost mean : 252.58
#
# Epoch [62/250]
# Train Accuracy: 42.43%, Testing Accuracy: 25.18%
# Path cost mean this epoch: 225.92, Total path cost mean : 252.15
#
# Epoch [63/250]
# Train Accuracy: 42.39%, Testing Accuracy: 24.67%
# Path cost mean this epoch: 256.81, Total path cost mean : 252.22
#
# Epoch [64/250]
# Train Accuracy: 43.24%, Testing Accuracy: 24.42%
# Path cost mean this epoch: 261.47, Total path cost mean : 252.36
#
# Epoch [65/250]
# Train Accuracy: 43.38%, Testing Accuracy: 24.64%
# Path cost mean this epoch: 243.47, Total path cost mean : 252.23
#
# Epoch [66/250]
# Train Accuracy: 43.46%, Testing Accuracy: 24.60%
# Path cost mean this epoch: 236.38, Total path cost mean : 251.99
#
# Epoch [67/250]
# Train Accuracy: 43.88%, Testing Accuracy: 25.00%
# Path cost mean this epoch: 200.53, Total path cost mean : 251.22
#
# Epoch [68/250]
# Train Accuracy: 44.48%, Testing Accuracy: 25.73%
# Path cost mean this epoch: 251.58, Total path cost mean : 251.22
#
# Epoch [69/250]
# Train Accuracy: 44.29%, Testing Accuracy: 24.89%
# Path cost mean this epoch: 231.88, Total path cost mean : 250.94
#
# Epoch [70/250]
# Train Accuracy: 45.25%, Testing Accuracy: 25.04%
# Path cost mean this epoch: 235.98, Total path cost mean : 250.73
#
# Epoch [71/250]
# Train Accuracy: 45.03%, Testing Accuracy: 25.44%
# Path cost mean this epoch: 241.55, Total path cost mean : 250.60
#
# Epoch [72/250]
# Train Accuracy: 45.27%, Testing Accuracy: 24.42%
# Path cost mean this epoch: 252.36, Total path cost mean : 250.63
#
# Epoch [73/250]
# Train Accuracy: 45.77%, Testing Accuracy: 24.53%
# Path cost mean this epoch: 234.97, Total path cost mean : 250.41
#
# Epoch [74/250]
# Train Accuracy: 46.47%, Testing Accuracy: 25.51%
# Path cost mean this epoch: 236.98, Total path cost mean : 250.23
#
# Epoch [75/250]
# Train Accuracy: 46.31%, Testing Accuracy: 25.55%
# Path cost mean this epoch: 206.53, Total path cost mean : 249.65
#
# Epoch [76/250]
# Train Accuracy: 46.66%, Testing Accuracy: 25.00%
# Path cost mean this epoch: 246.28, Total path cost mean : 249.60
#
# Epoch [77/250]
# Train Accuracy: 46.72%, Testing Accuracy: 25.15%
# Path cost mean this epoch: 235.42, Total path cost mean : 249.42
#
# Epoch [78/250]
# Train Accuracy: 46.71%, Testing Accuracy: 25.65%
# Path cost mean this epoch: 241.22, Total path cost mean : 249.31
#
# Epoch [79/250]
# Train Accuracy: 46.90%, Testing Accuracy: 25.47%
# Path cost mean this epoch: 215.83, Total path cost mean : 248.89
#
# Epoch [80/250]
# Train Accuracy: 47.78%, Testing Accuracy: 25.76%
# Path cost mean this epoch: 219.69, Total path cost mean : 248.52
#
# Epoch [81/250]
# Train Accuracy: 47.63%, Testing Accuracy: 25.58%
# Path cost mean this epoch: 261.19, Total path cost mean : 248.68
#
# Epoch [82/250]
# Train Accuracy: 48.17%, Testing Accuracy: 24.71%
# Path cost mean this epoch: 220.02, Total path cost mean : 248.33
#
# Epoch [83/250]
# Train Accuracy: 47.96%, Testing Accuracy: 25.33%
# Path cost mean this epoch: 271.28, Total path cost mean : 248.61
#
# Epoch [84/250]
# Train Accuracy: 48.46%, Testing Accuracy: 26.38%
# Path cost mean this epoch: 240.11, Total path cost mean : 248.51
#
# Epoch [85/250]
# Train Accuracy: 48.82%, Testing Accuracy: 25.62%
# Path cost mean this epoch: 256.33, Total path cost mean : 248.60
#
# Epoch [86/250]
# Train Accuracy: 49.07%, Testing Accuracy: 25.55%
# Path cost mean this epoch: 226.20, Total path cost mean : 248.34
#
# Epoch [87/250]
# Train Accuracy: 49.24%, Testing Accuracy: 25.94%
# Path cost mean this epoch: 236.52, Total path cost mean : 248.20
#
# Epoch [88/250]
# Train Accuracy: 49.48%, Testing Accuracy: 25.69%
# Path cost mean this epoch: 247.67, Total path cost mean : 248.20
#
# Epoch [89/250]
# Train Accuracy: 49.73%, Testing Accuracy: 24.93%
# Path cost mean this epoch: 200.50, Total path cost mean : 247.66
#
# Epoch [90/250]
# Train Accuracy: 49.78%, Testing Accuracy: 25.98%
# Path cost mean this epoch: 245.28, Total path cost mean : 247.63
#
# Epoch [91/250]
# Train Accuracy: 49.88%, Testing Accuracy: 25.76%
# Path cost mean this epoch: 264.50, Total path cost mean : 247.82
#
# Epoch [92/250]
# Train Accuracy: 50.39%, Testing Accuracy: 25.55%
# Path cost mean this epoch: 257.48, Total path cost mean : 247.92
#
# Epoch [93/250]
# Train Accuracy: 50.79%, Testing Accuracy: 25.36%
# Path cost mean this epoch: 261.09, Total path cost mean : 248.07
#
# Epoch [94/250]
# Train Accuracy: 50.46%, Testing Accuracy: 25.84%
# Path cost mean this epoch: 235.56, Total path cost mean : 247.93
#
# Epoch [95/250]
# Train Accuracy: 51.13%, Testing Accuracy: 25.91%
# Path cost mean this epoch: 257.09, Total path cost mean : 248.03
#
# Epoch [96/250]
# Train Accuracy: 51.40%, Testing Accuracy: 24.85%
# Path cost mean this epoch: 234.84, Total path cost mean : 247.89
#
# Epoch [97/250]
# Train Accuracy: 51.28%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 282.38, Total path cost mean : 248.25
#
# Epoch [98/250]
# Train Accuracy: 52.23%, Testing Accuracy: 25.76%
# Path cost mean this epoch: 217.22, Total path cost mean : 247.93
#
# Epoch [99/250]
# Train Accuracy: 52.27%, Testing Accuracy: 25.25%
# Path cost mean this epoch: 236.19, Total path cost mean : 247.81
#
# Epoch [100/250]
# Train Accuracy: 52.49%, Testing Accuracy: 25.47%
# Path cost mean this epoch: 239.62, Total path cost mean : 247.73
#
# Epoch [101/250]
# Train Accuracy: 53.14%, Testing Accuracy: 25.33%
# Path cost mean this epoch: 239.92, Total path cost mean : 247.65
#
# Epoch [102/250]
# Train Accuracy: 52.93%, Testing Accuracy: 25.51%
# Path cost mean this epoch: 231.06, Total path cost mean : 247.49
#
# Epoch [103/250]
# Train Accuracy: 53.26%, Testing Accuracy: 25.76%
# Path cost mean this epoch: 243.56, Total path cost mean : 247.45
#
# Epoch [104/250]
# Train Accuracy: 53.47%, Testing Accuracy: 26.13%
# Path cost mean this epoch: 278.92, Total path cost mean : 247.75
#
# Epoch [105/250]
# Train Accuracy: 53.84%, Testing Accuracy: 24.75%
# Path cost mean this epoch: 250.28, Total path cost mean : 247.78
#
# Epoch [106/250]
# Train Accuracy: 53.96%, Testing Accuracy: 25.07%
# Path cost mean this epoch: 235.77, Total path cost mean : 247.67
#
# Epoch [107/250]
# Train Accuracy: 54.09%, Testing Accuracy: 24.85%
# Path cost mean this epoch: 223.70, Total path cost mean : 247.44
#
# Epoch [108/250]
# Train Accuracy: 54.53%, Testing Accuracy: 25.00%
# Path cost mean this epoch: 255.33, Total path cost mean : 247.51
#
# Epoch [109/250]
# Train Accuracy: 54.83%, Testing Accuracy: 25.80%
# Path cost mean this epoch: 253.05, Total path cost mean : 247.57
#
# Epoch [110/250]
# Train Accuracy: 54.97%, Testing Accuracy: 25.36%
# Path cost mean this epoch: 233.80, Total path cost mean : 247.44
#
# Epoch [111/250]
# Train Accuracy: 55.12%, Testing Accuracy: 25.11%
# Path cost mean this epoch: 259.12, Total path cost mean : 247.55
#
# Epoch [112/250]
# Train Accuracy: 55.28%, Testing Accuracy: 24.85%
# Path cost mean this epoch: 246.08, Total path cost mean : 247.53
#
# Epoch [113/250]
# Train Accuracy: 55.34%, Testing Accuracy: 25.55%
# Path cost mean this epoch: 226.58, Total path cost mean : 247.35
#
# Epoch [114/250]
# Train Accuracy: 56.26%, Testing Accuracy: 25.62%
# Path cost mean this epoch: 250.88, Total path cost mean : 247.38
#
# Epoch [115/250]
# Train Accuracy: 56.46%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 206.81, Total path cost mean : 247.03
#
# Epoch [116/250]
# Train Accuracy: 56.08%, Testing Accuracy: 24.93%
# Path cost mean this epoch: 225.69, Total path cost mean : 246.84
#
# Epoch [117/250]
# Train Accuracy: 56.67%, Testing Accuracy: 24.35%
# Path cost mean this epoch: 238.55, Total path cost mean : 246.77
#
# Epoch [118/250]
# Train Accuracy: 56.65%, Testing Accuracy: 25.15%
# Path cost mean this epoch: 252.81, Total path cost mean : 246.82
#
# Epoch [119/250]
# Train Accuracy: 56.81%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 230.97, Total path cost mean : 246.69
#
# Epoch [120/250]
# Train Accuracy: 57.05%, Testing Accuracy: 24.64%
# Path cost mean this epoch: 228.19, Total path cost mean : 246.53
#
# Epoch [121/250]
# Train Accuracy: 57.59%, Testing Accuracy: 25.98%
# Path cost mean this epoch: 275.75, Total path cost mean : 246.78
#
# Epoch [122/250]
# Train Accuracy: 57.43%, Testing Accuracy: 24.89%
# Path cost mean this epoch: 257.55, Total path cost mean : 246.86
#
# Epoch [123/250]
# Train Accuracy: 57.89%, Testing Accuracy: 24.64%
# Path cost mean this epoch: 230.19, Total path cost mean : 246.73
#
# Epoch [124/250]
# Train Accuracy: 58.88%, Testing Accuracy: 24.27%
# Path cost mean this epoch: 222.30, Total path cost mean : 246.53
#
# Epoch [125/250]
# Train Accuracy: 58.40%, Testing Accuracy: 24.93%
# Path cost mean this epoch: 263.50, Total path cost mean : 246.67
#
# Epoch [126/250]
# Train Accuracy: 59.09%, Testing Accuracy: 24.89%
# Path cost mean this epoch: 253.94, Total path cost mean : 246.72
#
# Epoch [127/250]
# Train Accuracy: 59.06%, Testing Accuracy: 23.87%
# Path cost mean this epoch: 285.14, Total path cost mean : 247.03
#
# Epoch [128/250]
# Train Accuracy: 59.42%, Testing Accuracy: 24.96%
# Path cost mean this epoch: 238.58, Total path cost mean : 246.96
#
# Epoch [129/250]
# Train Accuracy: 59.01%, Testing Accuracy: 24.78%
# Path cost mean this epoch: 214.05, Total path cost mean : 246.71
#
# Epoch [130/250]
# Train Accuracy: 59.57%, Testing Accuracy: 25.11%
# Path cost mean this epoch: 241.70, Total path cost mean : 246.67
#
# Epoch [131/250]
# Train Accuracy: 60.33%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 230.77, Total path cost mean : 246.55
#
# Epoch [132/250]
# Train Accuracy: 59.81%, Testing Accuracy: 24.35%
# Path cost mean this epoch: 258.19, Total path cost mean : 246.63
#
# Epoch [133/250]
# Train Accuracy: 60.21%, Testing Accuracy: 25.07%
# Path cost mean this epoch: 228.58, Total path cost mean : 246.50
#
# Epoch [134/250]
# Train Accuracy: 60.25%, Testing Accuracy: 24.56%
# Path cost mean this epoch: 264.62, Total path cost mean : 246.63
#
# Epoch [135/250]
# Train Accuracy: 60.46%, Testing Accuracy: 24.60%
# Path cost mean this epoch: 262.25, Total path cost mean : 246.75
#
# Epoch [136/250]
# Train Accuracy: 60.95%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 235.59, Total path cost mean : 246.67
#
# Epoch [137/250]
# Train Accuracy: 61.04%, Testing Accuracy: 24.53%
# Path cost mean this epoch: 271.56, Total path cost mean : 246.85
#
# Epoch [138/250]
# Train Accuracy: 61.62%, Testing Accuracy: 23.73%
# Path cost mean this epoch: 224.88, Total path cost mean : 246.69
#
# Epoch [139/250]
# Train Accuracy: 61.44%, Testing Accuracy: 24.24%
# Path cost mean this epoch: 251.16, Total path cost mean : 246.72
#
# Epoch [140/250]
# Train Accuracy: 61.80%, Testing Accuracy: 24.13%
# Path cost mean this epoch: 207.11, Total path cost mean : 246.44
#
# Epoch [141/250]
# Train Accuracy: 61.94%, Testing Accuracy: 24.31%
# Path cost mean this epoch: 261.16, Total path cost mean : 246.54
#
# Epoch [142/250]
# Train Accuracy: 62.25%, Testing Accuracy: 24.56%
# Path cost mean this epoch: 222.52, Total path cost mean : 246.37
#
# Epoch [143/250]
# Train Accuracy: 62.54%, Testing Accuracy: 23.55%
# Path cost mean this epoch: 297.91, Total path cost mean : 246.73
#
# Epoch [144/250]
# Train Accuracy: 61.97%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 223.31, Total path cost mean : 246.57
#
# Epoch [145/250]
# Train Accuracy: 62.62%, Testing Accuracy: 24.75%
# Path cost mean this epoch: 251.55, Total path cost mean : 246.61
#
# Epoch [146/250]
# Train Accuracy: 62.44%, Testing Accuracy: 24.31%
# Path cost mean this epoch: 234.30, Total path cost mean : 246.52
#
# Epoch [147/250]
# Train Accuracy: 62.96%, Testing Accuracy: 24.42%
# Path cost mean this epoch: 241.73, Total path cost mean : 246.49
#
# Epoch [148/250]
# Train Accuracy: 62.85%, Testing Accuracy: 23.98%
# Path cost mean this epoch: 225.05, Total path cost mean : 246.34
#
# Epoch [149/250]
# Train Accuracy: 63.26%, Testing Accuracy: 24.49%
# Path cost mean this epoch: 235.64, Total path cost mean : 246.27
#
# Epoch [150/250]
# Train Accuracy: 63.41%, Testing Accuracy: 23.80%
# Path cost mean this epoch: 259.41, Total path cost mean : 246.36
#
# Epoch [151/250]
# Train Accuracy: 63.62%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 198.28, Total path cost mean : 246.04
#
# Epoch [152/250]
# Train Accuracy: 64.01%, Testing Accuracy: 24.53%
# Path cost mean this epoch: 250.20, Total path cost mean : 246.07
#
# Epoch [153/250]
# Train Accuracy: 64.17%, Testing Accuracy: 24.27%
# Path cost mean this epoch: 244.42, Total path cost mean : 246.06
#
# Epoch [154/250]
# Train Accuracy: 64.54%, Testing Accuracy: 23.73%
# Path cost mean this epoch: 257.22, Total path cost mean : 246.13
#
# Epoch [155/250]
# Train Accuracy: 64.05%, Testing Accuracy: 24.20%
# Path cost mean this epoch: 227.78, Total path cost mean : 246.01
#
# Epoch [156/250]
# Train Accuracy: 64.85%, Testing Accuracy: 24.85%
# Path cost mean this epoch: 258.50, Total path cost mean : 246.09
#
# Epoch [157/250]
# Train Accuracy: 65.09%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 224.88, Total path cost mean : 245.96
#
# Epoch [158/250]
# Train Accuracy: 65.17%, Testing Accuracy: 24.75%
# Path cost mean this epoch: 261.97, Total path cost mean : 246.06
#
# Epoch [159/250]
# Train Accuracy: 65.23%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 247.02, Total path cost mean : 246.06
#
# Epoch [160/250]
# Train Accuracy: 65.42%, Testing Accuracy: 24.06%
# Path cost mean this epoch: 220.62, Total path cost mean : 245.91
#
# Epoch [161/250]
# Train Accuracy: 66.10%, Testing Accuracy: 24.13%
# Path cost mean this epoch: 249.03, Total path cost mean : 245.93
#
# Epoch [162/250]
# Train Accuracy: 66.37%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 238.22, Total path cost mean : 245.88
#
# Epoch [163/250]
# Train Accuracy: 66.64%, Testing Accuracy: 23.73%
# Path cost mean this epoch: 263.72, Total path cost mean : 245.99
#
# Epoch [164/250]
# Train Accuracy: 66.24%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 235.19, Total path cost mean : 245.92
#
# Epoch [165/250]
# Train Accuracy: 66.32%, Testing Accuracy: 23.62%
# Path cost mean this epoch: 239.75, Total path cost mean : 245.88
#
# Epoch [166/250]
# Train Accuracy: 66.10%, Testing Accuracy: 23.47%
# Path cost mean this epoch: 261.55, Total path cost mean : 245.98
#
# Epoch [167/250]
# Train Accuracy: 66.92%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 263.23, Total path cost mean : 246.08
#
# Epoch [168/250]
# Train Accuracy: 67.19%, Testing Accuracy: 23.26%
# Path cost mean this epoch: 248.84, Total path cost mean : 246.10
#
# Epoch [169/250]
# Train Accuracy: 67.42%, Testing Accuracy: 24.60%
# Path cost mean this epoch: 248.78, Total path cost mean : 246.11
#
# Epoch [170/250]
# Train Accuracy: 67.67%, Testing Accuracy: 23.47%
# Path cost mean this epoch: 250.09, Total path cost mean : 246.14
#
# Epoch [171/250]
# Train Accuracy: 67.50%, Testing Accuracy: 24.49%
# Path cost mean this epoch: 274.83, Total path cost mean : 246.31
#
# Epoch [172/250]
# Train Accuracy: 68.21%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 211.45, Total path cost mean : 246.10
#
# Epoch [173/250]
# Train Accuracy: 67.53%, Testing Accuracy: 24.31%
# Path cost mean this epoch: 278.56, Total path cost mean : 246.29
#
# Epoch [174/250]
# Train Accuracy: 67.95%, Testing Accuracy: 23.73%
# Path cost mean this epoch: 275.00, Total path cost mean : 246.46
#
# Epoch [175/250]
# Train Accuracy: 68.53%, Testing Accuracy: 24.20%
# Path cost mean this epoch: 311.91, Total path cost mean : 246.83
#
# Epoch [176/250]
# Train Accuracy: 67.95%, Testing Accuracy: 23.15%
# Path cost mean this epoch: 300.06, Total path cost mean : 247.13
#
# Epoch [177/250]
# Train Accuracy: 69.02%, Testing Accuracy: 24.49%
# Path cost mean this epoch: 269.31, Total path cost mean : 247.26
#
# Epoch [178/250]
# Train Accuracy: 68.37%, Testing Accuracy: 23.58%
# Path cost mean this epoch: 267.73, Total path cost mean : 247.37
#
# Epoch [179/250]
# Train Accuracy: 69.31%, Testing Accuracy: 23.69%
# Path cost mean this epoch: 226.06, Total path cost mean : 247.25
#
# Epoch [180/250]
# Train Accuracy: 69.61%, Testing Accuracy: 24.31%
# Path cost mean this epoch: 239.11, Total path cost mean : 247.21
#
# Epoch [181/250]
# Train Accuracy: 69.55%, Testing Accuracy: 24.02%
# Path cost mean this epoch: 268.88, Total path cost mean : 247.33
#
# Epoch [182/250]
# Train Accuracy: 69.34%, Testing Accuracy: 24.20%
# Path cost mean this epoch: 210.64, Total path cost mean : 247.13
#
# Epoch [183/250]
# Train Accuracy: 70.01%, Testing Accuracy: 23.91%
# Path cost mean this epoch: 230.19, Total path cost mean : 247.03
#
# Epoch [184/250]
# Train Accuracy: 70.27%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 205.97, Total path cost mean : 246.81
#
# Epoch [185/250]
# Train Accuracy: 69.54%, Testing Accuracy: 23.87%
# Path cost mean this epoch: 242.08, Total path cost mean : 246.78
#
# Epoch [186/250]
# Train Accuracy: 70.05%, Testing Accuracy: 24.35%
# Path cost mean this epoch: 231.61, Total path cost mean : 246.70
#
# Epoch [187/250]
# Train Accuracy: 70.15%, Testing Accuracy: 23.84%
# Path cost mean this epoch: 247.20, Total path cost mean : 246.71
#
# Epoch [188/250]
# Train Accuracy: 70.66%, Testing Accuracy: 24.27%
# Path cost mean this epoch: 219.66, Total path cost mean : 246.56
#
# Epoch [189/250]
# Train Accuracy: 70.84%, Testing Accuracy: 23.47%
# Path cost mean this epoch: 245.14, Total path cost mean : 246.55
#
# Epoch [190/250]
# Train Accuracy: 70.04%, Testing Accuracy: 23.87%
# Path cost mean this epoch: 229.88, Total path cost mean : 246.47
#
# Epoch [191/250]
# Train Accuracy: 70.80%, Testing Accuracy: 24.13%
# Path cost mean this epoch: 229.59, Total path cost mean : 246.38
#
# Epoch [192/250]
# Train Accuracy: 71.13%, Testing Accuracy: 23.22%
# Path cost mean this epoch: 248.98, Total path cost mean : 246.39
#
# Epoch [193/250]
# Train Accuracy: 71.75%, Testing Accuracy: 24.38%
# Path cost mean this epoch: 235.06, Total path cost mean : 246.33
#
# Epoch [194/250]
# Train Accuracy: 71.49%, Testing Accuracy: 24.09%
# Path cost mean this epoch: 225.86, Total path cost mean : 246.23
#
# Epoch [195/250]
# Train Accuracy: 71.38%, Testing Accuracy: 24.45%
# Path cost mean this epoch: 236.34, Total path cost mean : 246.18
#
# Epoch [196/250]
# Train Accuracy: 71.71%, Testing Accuracy: 23.91%
# Path cost mean this epoch: 250.86, Total path cost mean : 246.20
#
# Epoch [197/250]
# Train Accuracy: 72.13%, Testing Accuracy: 23.69%
# Path cost mean this epoch: 259.58, Total path cost mean : 246.27
#
# Epoch [198/250]
# Train Accuracy: 72.32%, Testing Accuracy: 22.89%
# Path cost mean this epoch: 235.44, Total path cost mean : 246.21
#
# Epoch [199/250]
# Train Accuracy: 72.40%, Testing Accuracy: 23.15%
# Path cost mean this epoch: 216.14, Total path cost mean : 246.06
#
# Epoch [200/250]
# Train Accuracy: 71.41%, Testing Accuracy: 23.95%
# Path cost mean this epoch: 265.69, Total path cost mean : 246.16
#
# Epoch [201/250]
# Train Accuracy: 72.62%, Testing Accuracy: 23.55%
# Path cost mean this epoch: 322.05, Total path cost mean : 246.54
#
# Epoch [202/250]
# Train Accuracy: 73.05%, Testing Accuracy: 22.78%
# Path cost mean this epoch: 262.55, Total path cost mean : 246.62
#
# Epoch [203/250]
# Train Accuracy: 73.00%, Testing Accuracy: 24.02%
# Path cost mean this epoch: 273.22, Total path cost mean : 246.75
#
# Epoch [204/250]
# Train Accuracy: 72.38%, Testing Accuracy: 24.06%
# Path cost mean this epoch: 258.27, Total path cost mean : 246.80
#
# Epoch [205/250]
# Train Accuracy: 73.85%, Testing Accuracy: 23.58%
# Path cost mean this epoch: 272.97, Total path cost mean : 246.93
#
# Epoch [206/250]
# Train Accuracy: 73.06%, Testing Accuracy: 23.36%
# Path cost mean this epoch: 253.38, Total path cost mean : 246.96
#
# Epoch [207/250]
# Train Accuracy: 73.53%, Testing Accuracy: 23.51%
# Path cost mean this epoch: 239.12, Total path cost mean : 246.93
#
# Epoch [208/250]
# Train Accuracy: 73.12%, Testing Accuracy: 24.02%
# Path cost mean this epoch: 237.94, Total path cost mean : 246.88
#
# Epoch [209/250]
# Train Accuracy: 73.04%, Testing Accuracy: 24.16%
# Path cost mean this epoch: 225.41, Total path cost mean : 246.78
#
# Epoch [210/250]
# Train Accuracy: 73.72%, Testing Accuracy: 23.00%
# Path cost mean this epoch: 265.05, Total path cost mean : 246.87
#
# Epoch [211/250]
# Train Accuracy: 73.68%, Testing Accuracy: 23.33%
# Path cost mean this epoch: 278.41, Total path cost mean : 247.02
#
# Epoch [212/250]
# Train Accuracy: 74.04%, Testing Accuracy: 22.75%
# Path cost mean this epoch: 285.95, Total path cost mean : 247.20
#
# Epoch [213/250]
# Train Accuracy: 73.54%, Testing Accuracy: 23.58%
# Path cost mean this epoch: 248.78, Total path cost mean : 247.21
#
# Epoch [214/250]
# Train Accuracy: 74.25%, Testing Accuracy: 23.73%
# Path cost mean this epoch: 225.77, Total path cost mean : 247.11
#
# Epoch [215/250]
# Train Accuracy: 74.47%, Testing Accuracy: 22.93%
# Path cost mean this epoch: 259.84, Total path cost mean : 247.17
#
# Epoch [216/250]
# Train Accuracy: 74.72%, Testing Accuracy: 23.62%
# Path cost mean this epoch: 244.73, Total path cost mean : 247.16
#
# Epoch [217/250]
# Train Accuracy: 74.92%, Testing Accuracy: 23.33%
# Path cost mean this epoch: 229.19, Total path cost mean : 247.07
#
# Epoch [218/250]
# Train Accuracy: 74.71%, Testing Accuracy: 23.51%
# Path cost mean this epoch: 241.05, Total path cost mean : 247.04
#
# Epoch [219/250]
# Train Accuracy: 74.73%, Testing Accuracy: 22.71%
# Path cost mean this epoch: 265.42, Total path cost mean : 247.13
#
# Epoch [220/250]
# Train Accuracy: 74.75%, Testing Accuracy: 23.29%
# Path cost mean this epoch: 277.06, Total path cost mean : 247.26
#
# Epoch [221/250]
# Train Accuracy: 75.39%, Testing Accuracy: 22.93%
# Path cost mean this epoch: 220.80, Total path cost mean : 247.15
#
# Epoch [222/250]
# Train Accuracy: 74.67%, Testing Accuracy: 23.36%
# Path cost mean this epoch: 253.31, Total path cost mean : 247.17
#
# Epoch [223/250]
# Train Accuracy: 75.71%, Testing Accuracy: 23.40%
# Path cost mean this epoch: 240.94, Total path cost mean : 247.14
#
# Epoch [224/250]
# Train Accuracy: 75.87%, Testing Accuracy: 23.40%
# Path cost mean this epoch: 229.22, Total path cost mean : 247.06
#
# Epoch [225/250]
# Train Accuracy: 75.94%, Testing Accuracy: 22.57%
# Path cost mean this epoch: 235.47, Total path cost mean : 247.01
#
# Epoch [226/250]
# Train Accuracy: 76.19%, Testing Accuracy: 23.47%
# Path cost mean this epoch: 266.48, Total path cost mean : 247.10
#
# Epoch [227/250]
# Train Accuracy: 75.68%, Testing Accuracy: 22.64%
# Path cost mean this epoch: 260.20, Total path cost mean : 247.16
#
# Epoch [228/250]
# Train Accuracy: 76.00%, Testing Accuracy: 22.64%
# Path cost mean this epoch: 256.83, Total path cost mean : 247.20
#
# Epoch [229/250]
# Train Accuracy: 77.09%, Testing Accuracy: 23.29%
# Path cost mean this epoch: 231.78, Total path cost mean : 247.13
#
# Epoch [230/250]
# Train Accuracy: 76.72%, Testing Accuracy: 23.66%
# Path cost mean this epoch: 236.02, Total path cost mean : 247.08
#
# Epoch [231/250]
# Train Accuracy: 75.33%, Testing Accuracy: 23.11%
# Path cost mean this epoch: 231.70, Total path cost mean : 247.02
#
# Epoch [232/250]
# Train Accuracy: 75.84%, Testing Accuracy: 22.97%
# Path cost mean this epoch: 258.52, Total path cost mean : 247.07
#
# Epoch [233/250]
# Train Accuracy: 75.96%, Testing Accuracy: 22.78%
# Path cost mean this epoch: 259.02, Total path cost mean : 247.12
#
# Epoch [234/250]
# Train Accuracy: 76.62%, Testing Accuracy: 22.27%
# Path cost mean this epoch: 257.55, Total path cost mean : 247.16
#
# Epoch [235/250]
# Train Accuracy: 77.38%, Testing Accuracy: 22.17%
# Path cost mean this epoch: 267.94, Total path cost mean : 247.25
#
# Epoch [236/250]
# Train Accuracy: 77.28%, Testing Accuracy: 22.60%
# Path cost mean this epoch: 241.39, Total path cost mean : 247.23
#
# Epoch [237/250]
# Train Accuracy: 77.31%, Testing Accuracy: 23.40%
# Path cost mean this epoch: 244.83, Total path cost mean : 247.22
#
# Epoch [238/250]
# Train Accuracy: 76.86%, Testing Accuracy: 22.75%
# Path cost mean this epoch: 235.88, Total path cost mean : 247.17
#
# Epoch [239/250]
# Train Accuracy: 76.56%, Testing Accuracy: 23.29%
# Path cost mean this epoch: 252.03, Total path cost mean : 247.19
#
# Epoch [240/250]
# Train Accuracy: 76.21%, Testing Accuracy: 22.97%
# Path cost mean this epoch: 232.91, Total path cost mean : 247.13
#
# Epoch [241/250]
# Train Accuracy: 76.96%, Testing Accuracy: 23.00%
# Path cost mean this epoch: 236.23, Total path cost mean : 247.08
#
# Epoch [242/250]
# Train Accuracy: 78.17%, Testing Accuracy: 22.71%
# Path cost mean this epoch: 258.48, Total path cost mean : 247.13
#
# Epoch [243/250]
# Train Accuracy: 77.93%, Testing Accuracy: 23.07%
# Path cost mean this epoch: 267.20, Total path cost mean : 247.21
#
# Epoch [244/250]
# Train Accuracy: 78.41%, Testing Accuracy: 23.40%
# Path cost mean this epoch: 271.66, Total path cost mean : 247.31
#
# Epoch [245/250]
# Train Accuracy: 77.24%, Testing Accuracy: 22.86%
# Path cost mean this epoch: 257.42, Total path cost mean : 247.36
#
# Epoch [246/250]
# Train Accuracy: 77.88%, Testing Accuracy: 22.67%
# Path cost mean this epoch: 248.39, Total path cost mean : 247.36
#
# Epoch [247/250]
# Train Accuracy: 78.32%, Testing Accuracy: 22.82%
# Path cost mean this epoch: 248.05, Total path cost mean : 247.36
#
# Epoch [248/250]
# Train Accuracy: 77.44%, Testing Accuracy: 22.89%
# Path cost mean this epoch: 239.19, Total path cost mean : 247.33
#
# Epoch [249/250]
# Train Accuracy: 77.84%, Testing Accuracy: 22.82%
# Path cost mean this epoch: 262.34, Total path cost mean : 247.39
#
# Epoch [250/250]
# Train Accuracy: 78.64%, Testing Accuracy: 22.42%
# Path cost mean this epoch: 286.48, Total path cost mean : 247.55
